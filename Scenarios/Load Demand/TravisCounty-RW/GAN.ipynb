# %%
import tensorflow as tf
from keras import layers, Model
import numpy as np
import datetime
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
from keras.callbacks import Callback
from keras.utils import array_to_img
from keras import Sequential
from keras.layers import Conv2D, Dense, Flatten, Reshape, LeakyReLU, Dropout, UpSampling1D
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from keras.models import Model

gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.reset_memory_stats(gpu, True)
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Prepare data to feed into GAN

# %%
month_name='JanFeb'
day_type = 'w'
my_data = pd.read_csv(f'ForGAN/{month_name}.csv')
ds = []
if day_type == 'w':
    for c in my_data.columns:
        if 'weekday' in c:
            ds.append([my_data[c].values])
else:
    for c in my_data.columns:
        if 'weekend' in c:
            ds.append([my_data[c].values])

max = np.max(ds)
ds = np.divide(ds, max)

ds = tf.data.Dataset.from_tensor_slices(ds)
batch_size = 12
ds = ds.cache()
ds = ds.shuffle(1000)
ds = ds.batch(batch_size)
ds = ds.prefetch(64)

# %% [markdown]
# ## Generator Discriminator Training

# %%
g_relu = 0.2
if day_type == 'w':
    def build_generator():
        model = Sequential()

        model.add(Dense(1*96*batch_size, input_dim=batch_size))
        model.add(LeakyReLU(g_relu))
        model.add(Reshape((1,96, batch_size)))

        #model.add(UpSamplingD())
        model.add(Conv2D(batch_size, 3, padding='same'))
        model.add(LeakyReLU(g_relu))

        model.add(Conv2D(batch_size, 3, padding='same'))
        model.add(LeakyReLU(g_relu))

        model.add(Conv2D(batch_size, 3, padding='same'))
        model.add(LeakyReLU(g_relu))

        model.add(Conv2D(batch_size, 3, padding='same'))
        model.add(LeakyReLU(g_relu))


        model.add(Conv2D(1, 5, padding='same', activation='sigmoid'))
        return model
    generator = build_generator()
else:
    def build_generator():
            model = Sequential()

            model.add(Dense(1*96*batch_size, input_dim=batch_size))
            model.add(LeakyReLU(g_relu))
            model.add(Reshape((1,96, batch_size)))

            #model.add(UpSamplingD())
            model.add(Conv2D(batch_size, 5, padding='same'))
            model.add(LeakyReLU(g_relu))

            model.add(Conv2D(batch_size, 5, padding='same'))
            model.add(LeakyReLU(g_relu))

            model.add(Conv2D(batch_size, 5, padding='same'))
            model.add(LeakyReLU(g_relu))

            model.add(Conv2D(1, 5, padding='same', activation='sigmoid'))
            return model
generator = build_generator()

d_relu = 0.2
d_dropout = 0.2
if day_type == 'w':
    def build_discriminator():
        model = Sequential()

        model.add(Dense(200, input_shape=(1, 96, 1)))
        model.add(LeakyReLU(d_relu))
        model.add(Dropout(d_dropout))

        model.add(Dense(150))
        model.add(LeakyReLU(d_relu))
        model.add(Dropout(d_dropout))

        model.add(Flatten())
        model.add(Dropout(d_dropout))
        model.add(Dense(1, activation='sigmoid'))
        # 1: fake series, 0: real series

        return model
    discriminator = build_discriminator()
else:
    def build_discriminator():
            model = Sequential()

            model.add(Dense(100, input_shape=(1, 96, 1)))
            model.add(LeakyReLU(d_relu))
            model.add(Dropout(d_dropout))

            model.add(Dense(120))
            model.add(LeakyReLU(d_relu))
            model.add(Dropout(d_dropout))

            model.add(Flatten())
            model.add(Dropout(d_dropout))
            model.add(Dense(1, activation='sigmoid'))
            # 1: fake series, 0: real series

            return model
discriminator = build_discriminator()

g_a, d_a = 0.0001, 0.00001
g_opt = Adam(learning_rate=g_a)
d_opt = Adam(learning_rate=d_a)  # Does not learn too fast
g_loss = BinaryCrossentropy()
d_loss = BinaryCrossentropy()
class LoadGAN(Model):
    def __init__(self, generator, discriminator, *args, **kwargs):
        # pass through args and kwargs to base class
        super().__init__(*args, **kwargs)
        # Create attributes for gen and disc
        self.generator = generator
        self.discriminator = discriminator

    def compilee(self, g_opt, d_opt, g_loss, d_loss, *args, **kwargs):
        # Compile with base class
        super().compile(*args, **kwargs)

        self.g_opt = g_opt
        self.d_opt = d_opt
        self.g_loss = g_loss
        self.d_loss = d_loss

    def train_step(self, batch):
        real_series = batch
        fake_series = self.generator(tf.random.normal((batch_size, batch_size, 1)), training=False)

        # train the discriminator
        with tf.GradientTape() as d_tape:
            # pass the real and fake images
            yhat_real = self.discriminator(real_series, training=True)
            yhat_fake = self.discriminator(fake_series, training=True)
            yhat_realfake = tf.concat([yhat_real, yhat_fake], axis=0)

            # create labels for real and fake series
            y_realfake = tf.concat([tf.zeros_like(yhat_real), tf.ones_like(yhat_fake)], axis=0)


            # pass through and add some noise to the outputs
            noise_real = 0.15*tf.random.uniform(tf.shape(yhat_real))
            noise_fake = 0.15*tf.random.uniform(tf.shape(yhat_fake))
            y_realfake += tf.concat([noise_real, noise_fake], axis=0)

            # calculate the loss
            total_d_loss = self.d_loss(y_realfake, yhat_realfake)

        # apply backpropagation
        dgrad = d_tape.gradient(total_d_loss, self.discriminator.trainable_variables)
        self.d_opt.apply_gradients(zip(dgrad, self.discriminator.trainable_variables))

        # Generator training
        with tf.GradientTape() as g_tape:
            # generate same new images
            gen_series = self.generator(tf.random.normal((batch_size, batch_size, 1)), training=True)

            # create the predicted labels
            predicted_labels = self.discriminator(gen_series, training=False)

            # calculate loss
            total_g_loss = self.g_loss(tf.zeros_like(predicted_labels), predicted_labels)

        # apply backpropagation
        ggrad = g_tape.gradient(total_g_loss, self.generator.trainable_variables)
        self.g_opt.apply_gradients(zip(ggrad, self.generator.trainable_variables))

        return {"d_loss":total_d_loss, "g_loss":total_g_loss}
loadgan = LoadGAN(generator, discriminator)
loadgan.compilee(g_opt, d_opt, g_loss, d_loss)

# %% [markdown]
# #### Train

# %%
hist = loadgan.fit(ds, epochs=500)
# Out:
# Epoch 1/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6896 - g_loss: 0.7133
# Epoch 2/500
# 20/20 [==============================] - 2s 91ms/step - d_loss: 0.6860 - g_loss: 0.7314
# Epoch 3/500
# 20/20 [==============================] - 2s 97ms/step - d_loss: 0.6821 - g_loss: 0.7485
# Epoch 4/500
# 20/20 [==============================] - 2s 120ms/step - d_loss: 0.6798 - g_loss: 0.7641
# Epoch 5/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6809 - g_loss: 0.7776
# Epoch 6/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6810 - g_loss: 0.7864
# Epoch 7/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6821 - g_loss: 0.7880
# Epoch 8/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6895 - g_loss: 0.7784
# Epoch 9/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6987 - g_loss: 0.7582
# Epoch 10/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.7070 - g_loss: 0.7328
# Epoch 11/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.7107 - g_loss: 0.7152
# Epoch 12/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.7075 - g_loss: 0.7061
# Epoch 13/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6975 - g_loss: 0.7016
# Epoch 14/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6893 - g_loss: 0.6985
# Epoch 15/500
# 20/20 [==============================] - 4s 181ms/step - d_loss: 0.6828 - g_loss: 0.6949
# Epoch 16/500
# 20/20 [==============================] - 3s 167ms/step - d_loss: 0.6775 - g_loss: 0.6894
# Epoch 17/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6773 - g_loss: 0.6804
# Epoch 18/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6807 - g_loss: 0.6678
# Epoch 19/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6878 - g_loss: 0.6526
# Epoch 20/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6953 - g_loss: 0.6418
# Epoch 21/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6989 - g_loss: 0.6404
# Epoch 22/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6993 - g_loss: 0.6461
# Epoch 23/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6979 - g_loss: 0.6570
# Epoch 24/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6946 - g_loss: 0.6706
# Epoch 25/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6920 - g_loss: 0.6853
# Epoch 26/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6891 - g_loss: 0.7003
# Epoch 27/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6867 - g_loss: 0.7153
# Epoch 28/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6835 - g_loss: 0.7294
# Epoch 29/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6821 - g_loss: 0.7425
# Epoch 30/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6798 - g_loss: 0.7537
# Epoch 31/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6794 - g_loss: 0.7624
# Epoch 32/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6844 - g_loss: 0.7661
# Epoch 33/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6849 - g_loss: 0.7636
# Epoch 34/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6884 - g_loss: 0.7558
# Epoch 35/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6939 - g_loss: 0.7434
# Epoch 36/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6960 - g_loss: 0.7316
# Epoch 37/500
# 20/20 [==============================] - 3s 125ms/step - d_loss: 0.6933 - g_loss: 0.7230
# Epoch 38/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6918 - g_loss: 0.7167
# Epoch 39/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6880 - g_loss: 0.7105
# Epoch 40/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6854 - g_loss: 0.7046
# Epoch 41/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6846 - g_loss: 0.6994
# Epoch 42/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6830 - g_loss: 0.6938
# Epoch 43/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6858 - g_loss: 0.6895
# Epoch 44/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6880 - g_loss: 0.6862
# Epoch 45/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6897 - g_loss: 0.6886
# Epoch 46/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6894 - g_loss: 0.6956
# Epoch 47/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6889 - g_loss: 0.7065
# Epoch 48/500
# 20/20 [==============================] - 2s 124ms/step - d_loss: 0.6883 - g_loss: 0.7212
# Epoch 49/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6855 - g_loss: 0.7377
# Epoch 50/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6822 - g_loss: 0.7554
# Epoch 51/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6820 - g_loss: 0.7718
# Epoch 52/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6800 - g_loss: 0.7871
# Epoch 53/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6789 - g_loss: 0.7992
# Epoch 54/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6778 - g_loss: 0.8083
# Epoch 55/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6790 - g_loss: 0.8137
# Epoch 56/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6830 - g_loss: 0.8143
# Epoch 57/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6833 - g_loss: 0.8118
# Epoch 58/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6833 - g_loss: 0.8073
# Epoch 59/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6843 - g_loss: 0.8025
# Epoch 60/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6832 - g_loss: 0.7972
# Epoch 61/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6789 - g_loss: 0.7926
# Epoch 62/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6785 - g_loss: 0.7882
# Epoch 63/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6740 - g_loss: 0.7825
# Epoch 64/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6759 - g_loss: 0.7746
# Epoch 65/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6795 - g_loss: 0.7663
# Epoch 66/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6806 - g_loss: 0.7644
# Epoch 67/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6832 - g_loss: 0.7711
# Epoch 68/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6844 - g_loss: 0.7844
# Epoch 69/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6821 - g_loss: 0.8019
# Epoch 70/500
# 20/20 [==============================] - 3s 146ms/step - d_loss: 0.6804 - g_loss: 0.8201
# Epoch 71/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6797 - g_loss: 0.8366
# Epoch 72/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6773 - g_loss: 0.8504
# Epoch 73/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6780 - g_loss: 0.8622
# Epoch 74/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6748 - g_loss: 0.8728
# Epoch 75/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6760 - g_loss: 0.8794
# Epoch 76/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6758 - g_loss: 0.8830
# Epoch 77/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6770 - g_loss: 0.8832
# Epoch 78/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6781 - g_loss: 0.8804
# Epoch 79/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6785 - g_loss: 0.8750
# Epoch 80/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6821 - g_loss: 0.8649
# Epoch 81/500
# 20/20 [==============================] - 3s 147ms/step - d_loss: 0.6834 - g_loss: 0.8516
# Epoch 82/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6850 - g_loss: 0.8385
# Epoch 83/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6836 - g_loss: 0.8272
# Epoch 84/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6794 - g_loss: 0.8178
# Epoch 85/500
# 20/20 [==============================] - 2s 124ms/step - d_loss: 0.6776 - g_loss: 0.8090
# Epoch 86/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6789 - g_loss: 0.7974
# Epoch 87/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6799 - g_loss: 0.7861
# Epoch 88/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6834 - g_loss: 0.7828
# Epoch 89/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6826 - g_loss: 0.7876
# Epoch 90/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6822 - g_loss: 0.7988
# Epoch 91/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6802 - g_loss: 0.8133
# Epoch 92/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6803 - g_loss: 0.8299
# Epoch 93/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6773 - g_loss: 0.8465
# Epoch 94/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6790 - g_loss: 0.8619
# Epoch 95/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6773 - g_loss: 0.8727
# Epoch 96/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6778 - g_loss: 0.8792
# Epoch 97/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6790 - g_loss: 0.8805
# Epoch 98/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6824 - g_loss: 0.8768
# Epoch 99/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6834 - g_loss: 0.8682
# Epoch 100/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6844 - g_loss: 0.8592
# Epoch 101/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6833 - g_loss: 0.8495
# Epoch 102/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6830 - g_loss: 0.8413
# Epoch 103/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6819 - g_loss: 0.8338
# Epoch 104/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6824 - g_loss: 0.8290
# Epoch 105/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6815 - g_loss: 0.8281
# Epoch 106/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6793 - g_loss: 0.8350
# Epoch 107/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6772 - g_loss: 0.8512
# Epoch 108/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6757 - g_loss: 0.8693
# Epoch 109/500
# 20/20 [==============================] - 3s 146ms/step - d_loss: 0.6736 - g_loss: 0.8789
# Epoch 110/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6760 - g_loss: 0.8801
# Epoch 111/500
# 20/20 [==============================] - 3s 146ms/step - d_loss: 0.6775 - g_loss: 0.8753
# Epoch 112/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6780 - g_loss: 0.8675
# Epoch 113/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6748 - g_loss: 0.8593
# Epoch 114/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6765 - g_loss: 0.8510
# Epoch 115/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6742 - g_loss: 0.8439
# Epoch 116/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6782 - g_loss: 0.8428
# Epoch 117/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6780 - g_loss: 0.8530
# Epoch 118/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6747 - g_loss: 0.8733
# Epoch 119/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6737 - g_loss: 0.8912
# Epoch 120/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6754 - g_loss: 0.8971
# Epoch 121/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6811 - g_loss: 0.8920
# Epoch 122/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6809 - g_loss: 0.8808
# Epoch 123/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6815 - g_loss: 0.8671
# Epoch 124/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6812 - g_loss: 0.8547
# Epoch 125/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6810 - g_loss: 0.8426
# Epoch 126/500
# 20/20 [==============================] - 3s 125ms/step - d_loss: 0.6784 - g_loss: 0.8296
# Epoch 127/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6820 - g_loss: 0.8199
# Epoch 128/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6834 - g_loss: 0.8207
# Epoch 129/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6812 - g_loss: 0.8362
# Epoch 130/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6759 - g_loss: 0.8602
# Epoch 131/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6763 - g_loss: 0.8806
# Epoch 132/500
# 20/20 [==============================] - 3s 140ms/step - d_loss: 0.6819 - g_loss: 0.8887
# Epoch 133/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6825 - g_loss: 0.8870
# Epoch 134/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6834 - g_loss: 0.8778
# Epoch 135/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6866 - g_loss: 0.8677
# Epoch 136/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6838 - g_loss: 0.8580
# Epoch 137/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6838 - g_loss: 0.8499
# Epoch 138/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6828 - g_loss: 0.8422
# Epoch 139/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6791 - g_loss: 0.8366
# Epoch 140/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6777 - g_loss: 0.8369
# Epoch 141/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6758 - g_loss: 0.8406
# Epoch 142/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6759 - g_loss: 0.8467
# Epoch 143/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6755 - g_loss: 0.8531
# Epoch 144/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6721 - g_loss: 0.8595
# Epoch 145/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6751 - g_loss: 0.8656
# Epoch 146/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6731 - g_loss: 0.8688
# Epoch 147/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6734 - g_loss: 0.8705
# Epoch 148/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6752 - g_loss: 0.8697
# Epoch 149/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6767 - g_loss: 0.8664
# Epoch 150/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6763 - g_loss: 0.8609
# Epoch 151/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6735 - g_loss: 0.8563
# Epoch 152/500
# 20/20 [==============================] - 3s 125ms/step - d_loss: 0.6781 - g_loss: 0.8527
# Epoch 153/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6755 - g_loss: 0.8475
# Epoch 154/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6766 - g_loss: 0.8441
# Epoch 155/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6799 - g_loss: 0.8413
# Epoch 156/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6789 - g_loss: 0.8400
# Epoch 157/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6783 - g_loss: 0.8404
# Epoch 158/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6780 - g_loss: 0.8414
# Epoch 159/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6790 - g_loss: 0.8433
# Epoch 160/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6805 - g_loss: 0.8440
# Epoch 161/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6820 - g_loss: 0.8438
# Epoch 162/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6829 - g_loss: 0.8424
# Epoch 163/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6831 - g_loss: 0.8404
# Epoch 164/500
# 20/20 [==============================] - 3s 140ms/step - d_loss: 0.6860 - g_loss: 0.8391
# Epoch 165/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6865 - g_loss: 0.8388
# Epoch 166/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6862 - g_loss: 0.8398
# Epoch 167/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6872 - g_loss: 0.8415
# Epoch 168/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6890 - g_loss: 0.8421
# Epoch 169/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6887 - g_loss: 0.8432
# Epoch 170/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6882 - g_loss: 0.8464
# Epoch 171/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6870 - g_loss: 0.8524
# Epoch 172/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6824 - g_loss: 0.8593
# Epoch 173/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6839 - g_loss: 0.8669
# Epoch 174/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6797 - g_loss: 0.8736
# Epoch 175/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6778 - g_loss: 0.8801
# Epoch 176/500
# 20/20 [==============================] - 3s 146ms/step - d_loss: 0.6758 - g_loss: 0.8868
# Epoch 177/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6739 - g_loss: 0.8923
# Epoch 178/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6718 - g_loss: 0.9003
# Epoch 179/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6705 - g_loss: 0.9043
# Epoch 180/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6716 - g_loss: 0.9041
# Epoch 181/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6731 - g_loss: 0.9004
# Epoch 182/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6750 - g_loss: 0.8948
# Epoch 183/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6735 - g_loss: 0.8900
# Epoch 184/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6744 - g_loss: 0.8866
# Epoch 185/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6759 - g_loss: 0.8835
# Epoch 186/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6788 - g_loss: 0.8791
# Epoch 187/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6778 - g_loss: 0.8734
# Epoch 188/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6788 - g_loss: 0.8685
# Epoch 189/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6787 - g_loss: 0.8639
# Epoch 190/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6798 - g_loss: 0.8602
# Epoch 191/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6804 - g_loss: 0.8572
# Epoch 192/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6797 - g_loss: 0.8543
# Epoch 193/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6810 - g_loss: 0.8517
# Epoch 194/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6799 - g_loss: 0.8493
# Epoch 195/500
# 20/20 [==============================] - 3s 146ms/step - d_loss: 0.6812 - g_loss: 0.8472
# Epoch 196/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6823 - g_loss: 0.8453
# Epoch 197/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6801 - g_loss: 0.8433
# Epoch 198/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6794 - g_loss: 0.8423
# Epoch 199/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6813 - g_loss: 0.8414
# Epoch 200/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6804 - g_loss: 0.8402
# Epoch 201/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6816 - g_loss: 0.8405
# Epoch 202/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6808 - g_loss: 0.8402
# Epoch 203/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6812 - g_loss: 0.8401
# Epoch 204/500
# 20/20 [==============================] - 3s 140ms/step - d_loss: 0.6816 - g_loss: 0.8390
# Epoch 205/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6798 - g_loss: 0.8388
# Epoch 206/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6809 - g_loss: 0.8392
# Epoch 207/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6792 - g_loss: 0.8391
# Epoch 208/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6803 - g_loss: 0.8393
# Epoch 209/500
# 20/20 [==============================] - 3s 140ms/step - d_loss: 0.6819 - g_loss: 0.8386
# Epoch 210/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6806 - g_loss: 0.8378
# Epoch 211/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6810 - g_loss: 0.8379
# Epoch 212/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6804 - g_loss: 0.8389
# Epoch 213/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6813 - g_loss: 0.8391
# Epoch 214/500
# 20/20 [==============================] - 3s 140ms/step - d_loss: 0.6836 - g_loss: 0.8388
# Epoch 215/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6819 - g_loss: 0.8388
# Epoch 216/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6822 - g_loss: 0.8389
# Epoch 217/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6822 - g_loss: 0.8395
# Epoch 218/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6843 - g_loss: 0.8425
# Epoch 219/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6826 - g_loss: 0.8451
# Epoch 220/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6803 - g_loss: 0.8469
# Epoch 221/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6813 - g_loss: 0.8496
# Epoch 222/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6809 - g_loss: 0.8519
# Epoch 223/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6813 - g_loss: 0.8557
# Epoch 224/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6793 - g_loss: 0.8585
# Epoch 225/500
# 20/20 [==============================] - 3s 146ms/step - d_loss: 0.6788 - g_loss: 0.8616
# Epoch 226/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6769 - g_loss: 0.8644
# Epoch 227/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6792 - g_loss: 0.8663
# Epoch 228/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6800 - g_loss: 0.8669
# Epoch 229/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6799 - g_loss: 0.8668
# Epoch 230/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6799 - g_loss: 0.8652
# Epoch 231/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6788 - g_loss: 0.8641
# Epoch 232/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6792 - g_loss: 0.8633
# Epoch 233/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6769 - g_loss: 0.8627
# Epoch 234/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6780 - g_loss: 0.8623
# Epoch 235/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6793 - g_loss: 0.8609
# Epoch 236/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6800 - g_loss: 0.8595
# Epoch 237/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6806 - g_loss: 0.8581
# Epoch 238/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6786 - g_loss: 0.8570
# Epoch 239/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6811 - g_loss: 0.8555
# Epoch 240/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6801 - g_loss: 0.8534
# Epoch 241/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6801 - g_loss: 0.8525
# Epoch 242/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6805 - g_loss: 0.8514
# Epoch 243/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6805 - g_loss: 0.8509
# Epoch 244/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6785 - g_loss: 0.8503
# Epoch 245/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6807 - g_loss: 0.8504
# Epoch 246/500
# 20/20 [==============================] - 3s 147ms/step - d_loss: 0.6793 - g_loss: 0.8504
# Epoch 247/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6796 - g_loss: 0.8502
# Epoch 248/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6789 - g_loss: 0.8505
# Epoch 249/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6808 - g_loss: 0.8511
# Epoch 250/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6787 - g_loss: 0.8507
# Epoch 251/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6795 - g_loss: 0.8516
# Epoch 252/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6797 - g_loss: 0.8521
# Epoch 253/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6815 - g_loss: 0.8537
# Epoch 254/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6802 - g_loss: 0.8537
# Epoch 255/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6781 - g_loss: 0.8529
# Epoch 256/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6796 - g_loss: 0.8536
# Epoch 257/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6802 - g_loss: 0.8544
# Epoch 258/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6794 - g_loss: 0.8555
# Epoch 259/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6795 - g_loss: 0.8558
# Epoch 260/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6799 - g_loss: 0.8561
# Epoch 261/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6790 - g_loss: 0.8563
# Epoch 262/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6783 - g_loss: 0.8567
# Epoch 263/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6788 - g_loss: 0.8567
# Epoch 264/500
# 20/20 [==============================] - 3s 147ms/step - d_loss: 0.6770 - g_loss: 0.8576
# Epoch 265/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6783 - g_loss: 0.8580
# Epoch 266/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6792 - g_loss: 0.8574
# Epoch 267/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6762 - g_loss: 0.8572
# Epoch 268/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6796 - g_loss: 0.8574
# Epoch 269/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6779 - g_loss: 0.8561
# Epoch 270/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6763 - g_loss: 0.8545
# Epoch 271/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6785 - g_loss: 0.8525
# Epoch 272/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6773 - g_loss: 0.8518
# Epoch 273/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6788 - g_loss: 0.8519
# Epoch 274/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6810 - g_loss: 0.8504
# Epoch 275/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6786 - g_loss: 0.8483
# Epoch 276/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6802 - g_loss: 0.8477
# Epoch 277/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6800 - g_loss: 0.8471
# Epoch 278/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6772 - g_loss: 0.8464
# Epoch 279/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6789 - g_loss: 0.8470
# Epoch 280/500
# 20/20 [==============================] - 2s 109ms/step - d_loss: 0.6787 - g_loss: 0.8473
# Epoch 281/500
# 20/20 [==============================] - 2s 91ms/step - d_loss: 0.6800 - g_loss: 0.8470
# Epoch 282/500
# 20/20 [==============================] - 2s 92ms/step - d_loss: 0.6804 - g_loss: 0.8462
# Epoch 283/500
# 20/20 [==============================] - 2s 91ms/step - d_loss: 0.6801 - g_loss: 0.8458
# Epoch 284/500
# 20/20 [==============================] - 2s 92ms/step - d_loss: 0.6804 - g_loss: 0.8451
# Epoch 285/500
# 20/20 [==============================] - 2s 91ms/step - d_loss: 0.6804 - g_loss: 0.8461
# Epoch 286/500
# 20/20 [==============================] - 2s 92ms/step - d_loss: 0.6781 - g_loss: 0.8486
# Epoch 287/500
# 20/20 [==============================] - 2s 91ms/step - d_loss: 0.6806 - g_loss: 0.8516
# Epoch 288/500
# 20/20 [==============================] - 2s 93ms/step - d_loss: 0.6817 - g_loss: 0.8544
# Epoch 289/500
# 20/20 [==============================] - 2s 91ms/step - d_loss: 0.6799 - g_loss: 0.8553
# Epoch 290/500
# 20/20 [==============================] - 2s 93ms/step - d_loss: 0.6808 - g_loss: 0.8585
# Epoch 291/500
# 20/20 [==============================] - 2s 102ms/step - d_loss: 0.6808 - g_loss: 0.8601
# Epoch 292/500
# 20/20 [==============================] - 2s 101ms/step - d_loss: 0.6791 - g_loss: 0.8604
# Epoch 293/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6793 - g_loss: 0.8598
# Epoch 294/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6782 - g_loss: 0.8595
# Epoch 295/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6807 - g_loss: 0.8581
# Epoch 296/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6799 - g_loss: 0.8563
# Epoch 297/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6774 - g_loss: 0.8536
# Epoch 298/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6781 - g_loss: 0.8526
# Epoch 299/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6777 - g_loss: 0.8526
# Epoch 300/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6791 - g_loss: 0.8518
# Epoch 301/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6806 - g_loss: 0.8496
# Epoch 302/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6788 - g_loss: 0.8480
# Epoch 303/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6793 - g_loss: 0.8470
# Epoch 304/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6777 - g_loss: 0.8456
# Epoch 305/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6776 - g_loss: 0.8455
# Epoch 306/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6777 - g_loss: 0.8463
# Epoch 307/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6804 - g_loss: 0.8466
# Epoch 308/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6778 - g_loss: 0.8468
# Epoch 309/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6792 - g_loss: 0.8471
# Epoch 310/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6811 - g_loss: 0.8475
# Epoch 311/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6789 - g_loss: 0.8483
# Epoch 312/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6791 - g_loss: 0.8496
# Epoch 313/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6792 - g_loss: 0.8509
# Epoch 314/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6787 - g_loss: 0.8519
# Epoch 315/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6803 - g_loss: 0.8530
# Epoch 316/500
# 20/20 [==============================] - 2s 109ms/step - d_loss: 0.6817 - g_loss: 0.8542
# Epoch 317/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6777 - g_loss: 0.8553
# Epoch 318/500
# 20/20 [==============================] - 2s 121ms/step - d_loss: 0.6784 - g_loss: 0.8571
# Epoch 319/500
# 20/20 [==============================] - 3s 155ms/step - d_loss: 0.6788 - g_loss: 0.8590
# Epoch 320/500
# 20/20 [==============================] - 6s 290ms/step - d_loss: 0.6809 - g_loss: 0.8596
# Epoch 321/500
# 20/20 [==============================] - 3s 163ms/step - d_loss: 0.6781 - g_loss: 0.8594
# Epoch 322/500
# 20/20 [==============================] - 4s 208ms/step - d_loss: 0.6793 - g_loss: 0.8600
# Epoch 323/500
# 20/20 [==============================] - 9s 454ms/step - d_loss: 0.6810 - g_loss: 0.8592
# Epoch 324/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6795 - g_loss: 0.8582
# Epoch 325/500
# 20/20 [==============================] - 4s 187ms/step - d_loss: 0.6805 - g_loss: 0.8583
# Epoch 326/500
# 20/20 [==============================] - 4s 182ms/step - d_loss: 0.6787 - g_loss: 0.8578
# Epoch 327/500
# 20/20 [==============================] - 4s 179ms/step - d_loss: 0.6787 - g_loss: 0.8568
# Epoch 328/500
# 20/20 [==============================] - 4s 188ms/step - d_loss: 0.6790 - g_loss: 0.8573
# Epoch 329/500
# 20/20 [==============================] - 4s 220ms/step - d_loss: 0.6821 - g_loss: 0.8574
# Epoch 330/500
# 20/20 [==============================] - 5s 230ms/step - d_loss: 0.6799 - g_loss: 0.8565
# Epoch 331/500
# 20/20 [==============================] - 3s 168ms/step - d_loss: 0.6776 - g_loss: 0.8562
# Epoch 332/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6797 - g_loss: 0.8564
# Epoch 333/500
# 20/20 [==============================] - 4s 217ms/step - d_loss: 0.6799 - g_loss: 0.8559
# Epoch 334/500
# 20/20 [==============================] - 4s 183ms/step - d_loss: 0.6792 - g_loss: 0.8551
# Epoch 335/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6800 - g_loss: 0.8536
# Epoch 336/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6792 - g_loss: 0.8523
# Epoch 337/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6788 - g_loss: 0.8506
# Epoch 338/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6801 - g_loss: 0.8512
# Epoch 339/500
# 20/20 [==============================] - 4s 179ms/step - d_loss: 0.6797 - g_loss: 0.8515
# Epoch 340/500
# 20/20 [==============================] - 5s 233ms/step - d_loss: 0.6787 - g_loss: 0.8516
# Epoch 341/500
# 20/20 [==============================] - 3s 159ms/step - d_loss: 0.6804 - g_loss: 0.8517
# Epoch 342/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6806 - g_loss: 0.8518
# Epoch 343/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6800 - g_loss: 0.8517
# Epoch 344/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6783 - g_loss: 0.8517
# Epoch 345/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6802 - g_loss: 0.8530
# Epoch 346/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6801 - g_loss: 0.8543
# Epoch 347/500
# 20/20 [==============================] - 3s 168ms/step - d_loss: 0.6797 - g_loss: 0.8555
# Epoch 348/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6791 - g_loss: 0.8559
# Epoch 349/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6786 - g_loss: 0.8565
# Epoch 350/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6798 - g_loss: 0.8572
# Epoch 351/500
# 20/20 [==============================] - 3s 125ms/step - d_loss: 0.6781 - g_loss: 0.8570
# Epoch 352/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6789 - g_loss: 0.8573
# Epoch 353/500
# 20/20 [==============================] - 3s 149ms/step - d_loss: 0.6790 - g_loss: 0.8560
# Epoch 354/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6781 - g_loss: 0.8540
# Epoch 355/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6796 - g_loss: 0.8521
# Epoch 356/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6818 - g_loss: 0.8497
# Epoch 357/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6791 - g_loss: 0.8483
# Epoch 358/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6788 - g_loss: 0.8487
# Epoch 359/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6814 - g_loss: 0.8482
# Epoch 360/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6778 - g_loss: 0.8470
# Epoch 361/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6810 - g_loss: 0.8467
# Epoch 362/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6803 - g_loss: 0.8464
# Epoch 363/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6781 - g_loss: 0.8460
# Epoch 364/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6782 - g_loss: 0.8461
# Epoch 365/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6803 - g_loss: 0.8459
# Epoch 366/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6782 - g_loss: 0.8460
# Epoch 367/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6786 - g_loss: 0.8469
# Epoch 368/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6789 - g_loss: 0.8470
# Epoch 369/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6796 - g_loss: 0.8464
# Epoch 370/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6791 - g_loss: 0.8469
# Epoch 371/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6801 - g_loss: 0.8477
# Epoch 372/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6789 - g_loss: 0.8493
# Epoch 373/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6805 - g_loss: 0.8523
# Epoch 374/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6778 - g_loss: 0.8551
# Epoch 375/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6790 - g_loss: 0.8580
# Epoch 376/500
# 20/20 [==============================] - 2s 125ms/step - d_loss: 0.6802 - g_loss: 0.8608
# Epoch 377/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6793 - g_loss: 0.8618
# Epoch 378/500
# 20/20 [==============================] - 4s 186ms/step - d_loss: 0.6805 - g_loss: 0.8611
# Epoch 379/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6812 - g_loss: 0.8604
# Epoch 380/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6802 - g_loss: 0.8586
# Epoch 381/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6788 - g_loss: 0.8580
# Epoch 382/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6803 - g_loss: 0.8573
# Epoch 383/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6804 - g_loss: 0.8549
# Epoch 384/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6799 - g_loss: 0.8524
# Epoch 385/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6784 - g_loss: 0.8520
# Epoch 386/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6795 - g_loss: 0.8528
# Epoch 387/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6803 - g_loss: 0.8530
# Epoch 388/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6799 - g_loss: 0.8518
# Epoch 389/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6776 - g_loss: 0.8508
# Epoch 390/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6796 - g_loss: 0.8512
# Epoch 391/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6796 - g_loss: 0.8520
# Epoch 392/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6799 - g_loss: 0.8511
# Epoch 393/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6798 - g_loss: 0.8505
# Epoch 394/500
# 20/20 [==============================] - 3s 140ms/step - d_loss: 0.6790 - g_loss: 0.8501
# Epoch 395/500
# 20/20 [==============================] - 2s 123ms/step - d_loss: 0.6793 - g_loss: 0.8511
# Epoch 396/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6785 - g_loss: 0.8527
# Epoch 397/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6780 - g_loss: 0.8542
# Epoch 398/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6783 - g_loss: 0.8547
# Epoch 399/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6780 - g_loss: 0.8558
# Epoch 400/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6791 - g_loss: 0.8566
# Epoch 401/500
# 20/20 [==============================] - 3s 147ms/step - d_loss: 0.6777 - g_loss: 0.8563
# Epoch 402/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6796 - g_loss: 0.8563
# Epoch 403/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6778 - g_loss: 0.8555
# Epoch 404/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6800 - g_loss: 0.8548
# Epoch 405/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6776 - g_loss: 0.8539
# Epoch 406/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6784 - g_loss: 0.8533
# Epoch 407/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6799 - g_loss: 0.8522
# Epoch 408/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6788 - g_loss: 0.8510
# Epoch 409/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6779 - g_loss: 0.8505
# Epoch 410/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6797 - g_loss: 0.8502
# Epoch 411/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6779 - g_loss: 0.8491
# Epoch 412/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6783 - g_loss: 0.8490
# Epoch 413/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6791 - g_loss: 0.8495
# Epoch 414/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6793 - g_loss: 0.8494
# Epoch 415/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6807 - g_loss: 0.8484
# Epoch 416/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6771 - g_loss: 0.8478
# Epoch 417/500
# 20/20 [==============================] - 3s 125ms/step - d_loss: 0.6793 - g_loss: 0.8480
# Epoch 418/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6796 - g_loss: 0.8493
# Epoch 419/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6806 - g_loss: 0.8498
# Epoch 420/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6784 - g_loss: 0.8503
# Epoch 421/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6796 - g_loss: 0.8514
# Epoch 422/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6797 - g_loss: 0.8524
# Epoch 423/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6786 - g_loss: 0.8530
# Epoch 424/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6789 - g_loss: 0.8546
# Epoch 425/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6793 - g_loss: 0.8559
# Epoch 426/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6805 - g_loss: 0.8563
# Epoch 427/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6807 - g_loss: 0.8556
# Epoch 428/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6798 - g_loss: 0.8552
# Epoch 429/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6803 - g_loss: 0.8540
# Epoch 430/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6789 - g_loss: 0.8539
# Epoch 431/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6805 - g_loss: 0.8539
# Epoch 432/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6773 - g_loss: 0.8547
# Epoch 433/500
# 20/20 [==============================] - 3s 125ms/step - d_loss: 0.6783 - g_loss: 0.8556
# Epoch 434/500
# 20/20 [==============================] - 2s 123ms/step - d_loss: 0.6809 - g_loss: 0.8550
# Epoch 435/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6785 - g_loss: 0.8548
# Epoch 436/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6777 - g_loss: 0.8556
# Epoch 437/500
# 20/20 [==============================] - 3s 140ms/step - d_loss: 0.6774 - g_loss: 0.8561
# Epoch 438/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6795 - g_loss: 0.8560
# Epoch 439/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6799 - g_loss: 0.8554
# Epoch 440/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6801 - g_loss: 0.8555
# Epoch 441/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6782 - g_loss: 0.8551
# Epoch 442/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6778 - g_loss: 0.8562
# Epoch 443/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6801 - g_loss: 0.8568
# Epoch 444/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6790 - g_loss: 0.8563
# Epoch 445/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6798 - g_loss: 0.8568
# Epoch 446/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6771 - g_loss: 0.8579
# Epoch 447/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6805 - g_loss: 0.8593
# Epoch 448/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6783 - g_loss: 0.8592
# Epoch 449/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6794 - g_loss: 0.8594
# Epoch 450/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6797 - g_loss: 0.8593
# Epoch 451/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6783 - g_loss: 0.8590
# Epoch 452/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6777 - g_loss: 0.8588
# Epoch 453/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6815 - g_loss: 0.8587
# Epoch 454/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6773 - g_loss: 0.8578
# Epoch 455/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6773 - g_loss: 0.8578
# Epoch 456/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6807 - g_loss: 0.8577
# Epoch 457/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6786 - g_loss: 0.8573
# Epoch 458/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6798 - g_loss: 0.8571
# Epoch 459/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6788 - g_loss: 0.8572
# Epoch 460/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6799 - g_loss: 0.8561
# Epoch 461/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6803 - g_loss: 0.8550
# Epoch 462/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6797 - g_loss: 0.8536
# Epoch 463/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6789 - g_loss: 0.8531
# Epoch 464/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6786 - g_loss: 0.8542
# Epoch 465/500
# 20/20 [==============================] - 3s 124ms/step - d_loss: 0.6781 - g_loss: 0.8540
# Epoch 466/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6804 - g_loss: 0.8533
# Epoch 467/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6775 - g_loss: 0.8530
# Epoch 468/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6783 - g_loss: 0.8527
# Epoch 469/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6785 - g_loss: 0.8534
# Epoch 470/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6788 - g_loss: 0.8539
# Epoch 471/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6771 - g_loss: 0.8546
# Epoch 472/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6779 - g_loss: 0.8552
# Epoch 473/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6783 - g_loss: 0.8560
# Epoch 474/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6791 - g_loss: 0.8568
# Epoch 475/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6778 - g_loss: 0.8577
# Epoch 476/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6786 - g_loss: 0.8584
# Epoch 477/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6794 - g_loss: 0.8572
# Epoch 478/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6781 - g_loss: 0.8570
# Epoch 479/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6800 - g_loss: 0.8571
# Epoch 480/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6794 - g_loss: 0.8565
# Epoch 481/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6793 - g_loss: 0.8557
# Epoch 482/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6796 - g_loss: 0.8541
# Epoch 483/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6779 - g_loss: 0.8539
# Epoch 484/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6800 - g_loss: 0.8550
# Epoch 485/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6785 - g_loss: 0.8554
# Epoch 486/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6795 - g_loss: 0.8543
# Epoch 487/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6754 - g_loss: 0.8536
# Epoch 488/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6791 - g_loss: 0.8547
# Epoch 489/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6812 - g_loss: 0.8559
# Epoch 490/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6798 - g_loss: 0.8555
# Epoch 491/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6798 - g_loss: 0.8555
# Epoch 492/500
# 20/20 [==============================] - 2s 124ms/step - d_loss: 0.6792 - g_loss: 0.8572
# Epoch 493/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6792 - g_loss: 0.8603
# Epoch 494/500
# 20/20 [==============================] - 3s 167ms/step - d_loss: 0.6791 - g_loss: 0.8606
# Epoch 495/500
# 20/20 [==============================] - 4s 218ms/step - d_loss: 0.6808 - g_loss: 0.8595
# Epoch 496/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6790 - g_loss: 0.8580
# Epoch 497/500
# 20/20 [==============================] - 3s 124ms/step - d_loss: 0.6807 - g_loss: 0.8569
# Epoch 498/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6798 - g_loss: 0.8564
# Epoch 499/500
# 20/20 [==============================] - 2s 124ms/step - d_loss: 0.6798 - g_loss: 0.8560
# Epoch 500/500
# 20/20 [==============================] - 3s 164ms/step - d_loss: 0.6781 - g_loss: 0.8553

# %%
if True:
    scenario_size = 30
    normal_noise = tf.random.normal((scenario_size, batch_size, 1))
    n = [np.random.normal() for _ in range(scenario_size)]
    series = np.multiply(generator.predict(normal_noise), max)
    resolution = 96

    probabilities = []
    ranges = np.linspace(-3.5, 3.5, 8)
    intervals = np.linspace(-3, 3, 7)
    probs = [stats.norm.cdf(i) for i in n]
    prob_ranges = {intervals[i]: [stats.norm.cdf(ranges[i]), stats.norm.cdf(ranges[i+1])] for i in range(len(intervals))}
    for i in probs:
        for key in intervals:
            if prob_ranges[key][0]<= i <=prob_ranges[key][1]:
                probabilities.append(prob_ranges[key][1]-prob_ranges[key][0])
                break
    scenarios = {'probs': probabilities}
    for j in range(resolution):
        scenarios[j] = []
    for i in range(scenario_size):
        s = series[i].reshape([resolution])
        for j in range(resolution):
            scenarios[j].append(s[j])
pd.DataFrame(scenarios).to_csv(f'LoadScenarios-{month_name}-{day_type}.csv')
if True:
    ticks = [i for i in range(resolution) if i%4 == 0]
    fig, ax = plt.subplots(1, 2, figsize=(15, 4), dpi=200)
    for s in series[:3]:
        ax[0].plot(range(resolution), s.reshape([resolution]), linewidth=1)
    ax[0].set_xlabel('Timestamp (15 min)')
    ax[0].set_ylabel('Generated Power Consumption')
    ax[0].set_xticks(ticks, ticks)
    ax[0].grid(color='#666362', linestyle='-', linewidth=0.1)

    if day_type == 'w':
        ax[1].plot(my_data[[c for c in my_data.columns if 'weekday' in c][:3]], linewidth=1)
    else:
        ax[1].plot(my_data[[c for c in my_data.columns if 'weekend' in c][:3]], linewidth=1)
    ax[1].set_xlabel('Timestamp (15 min)')
    ax[1].set_ylabel('Historical Power Consumption')
    ax[1].set_xticks(ticks, ticks)
    ax[1].grid(color='#666362', linestyle='-', linewidth=0.1)
    plt.subplots_adjust(wspace=0.1)
# plt.savefig(f'IMG/{month_name}-{day_type}.jpg', bbox_inches='tight')
# Out:
# 1/1 [==============================] - 0s 43ms/step

# %% [markdown]
# ### Save models

# %%
generator.save(f'HarrisCounty/GAN Models/generator-{month_name}-{day_type}.h5')
discriminator.save(f'HarrisCounty/GAN Models/discriminator-{month_name}-{day_type}.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
plt.figure(figsize=(7, 3), dpi=300)
plt.plot(hist.history['d_loss'], label='Generator Loss')
plt.plot(hist.history['g_loss'], label='Discriminator Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(color='#666362', linestyle='-', linewidth=0.1)
plt.savefig(f'IMG/{month_name}-{day_type}-loss.jpg', bbox_inches='tight')

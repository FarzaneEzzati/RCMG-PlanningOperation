# %%
import tensorflow as tf
from keras import layers, Model
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from tensorflow.python.framework.ops import enable_eager_execution
enable_eager_execution()
import random
from scipy import stats
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.reset_memory_stats(gpu, True)
tf.config.run_functions_eagerly(True)

from keras.callbacks import Callback
from keras.utils import img_to_array, array_to_img
from keras import Sequential
from keras.layers import Conv2D, Dense, Flatten, Reshape, LeakyReLU, Dropout, UpSampling2D

from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from keras.models import Model

import warnings
warnings.filterwarnings('ignore')

c = pd.read_csv('../../../Visualizations/color.csv')['color']

# %%
month_name='MarApr'
day_type = 'w'
my_data = pd.read_csv(f'ForGAN/{month_name}.csv')
ds = []
if day_type == 'w':
    for c in my_data.columns:
        if 'weekday' in c:
            last = my_data[c].values[-1]
            ds.append(np.concatenate([my_data[c].values, [last, last, last, last]]).reshape([1, 100]))
else:
    for c in my_data.columns:
        if 'weekend' in c:
            last = my_data[c].values[-1]
            ds.append(np.concatenate([my_data[c].values, [last, last, last, last]]).reshape([1, 100]))

max = np.max(ds)
ds = np.divide(ds, max)

# %% [markdown]
# ### Prepare data to feed into GAN

# %%
ds = tf.data.Dataset.from_tensor_slices(ds)
batch_size = 8
ds = ds.cache()
ds = ds.shuffle(1000)
ds = ds.batch(batch_size)
ds = ds.prefetch(64)

# %% [markdown]
# ## Generator

# %%
g_relu = 0.2
def build_generator():
    model = Sequential()

    model.add(Dense(1*100*batch_size, input_dim=batch_size))
    model.add(LeakyReLU(g_relu))
    model.add(Reshape((1,100, batch_size)))

    #model.add(UpSamplingD())
    model.add(Conv2D(batch_size, 5, padding='same'))
    model.add(LeakyReLU(g_relu))

    model.add(Conv2D(batch_size, 5, padding='same'))
    model.add(LeakyReLU(g_relu))

    model.add(Conv2D(batch_size, 5, padding='same'))
    model.add(LeakyReLU(g_relu))

    model.add(Conv2D(batch_size, 5, padding='same'))
    model.add(LeakyReLU(g_relu))

    model.add(Conv2D(1, 5, padding='same', activation='sigmoid'))
    return model
generator = build_generator()
generator.summary()
# series = generator.predict(np.random.randn(4, 6, 1))
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_26 (Dense)            (None, 800)               7200
#
#  leaky_re_lu_57 (LeakyReLU)  (None, 800)               0
#
#  reshape_9 (Reshape)         (None, 1, 100, 8)         0
#
#  conv2d_47 (Conv2D)          (None, 1, 100, 8)         1608
#
#  leaky_re_lu_58 (LeakyReLU)  (None, 1, 100, 8)         0
#
#  conv2d_48 (Conv2D)          (None, 1, 100, 8)         1608
#
#  leaky_re_lu_59 (LeakyReLU)  (None, 1, 100, 8)         0
#
#  conv2d_49 (Conv2D)          (None, 1, 100, 8)         1608
#
#  leaky_re_lu_60 (LeakyReLU)  (None, 1, 100, 8)         0
#
#  conv2d_50 (Conv2D)          (None, 1, 100, 8)         1608
#
#  leaky_re_lu_61 (LeakyReLU)  (None, 1, 100, 8)         0
#
#  conv2d_51 (Conv2D)          (None, 1, 100, 1)         201
#
# =================================================================
# Total params: 13,833
# Trainable params: 13,833
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Discriminator

# %%
d_relu = 0.2
d_dropout = 0.2
def build_discriminator():
    model = Sequential()

    model.add(Dense(200, input_shape=(1, 100, 1)))
    model.add(LeakyReLU(d_relu))
    model.add(Dropout(d_dropout))

    model.add(Dense(150))
    model.add(LeakyReLU(d_relu))
    model.add(Dropout(d_dropout))

    model.add(Flatten())
    model.add(Dropout(d_dropout))
    model.add(Dense(1, activation='sigmoid'))
    # 1: fake series, 0: real series

    return model
discriminator = build_discriminator()
discriminator.summary()
# Single prediction needs np.expand_dims(series[0], 0)
# discriminator.predict(np.expand_dims(series[0], 0))
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_27 (Dense)            (None, 1, 100, 200)       400
#
#  leaky_re_lu_62 (LeakyReLU)  (None, 1, 100, 200)       0
#
#  dropout_22 (Dropout)        (None, 1, 100, 200)       0
#
#  dense_28 (Dense)            (None, 1, 100, 150)       30150
#
#  leaky_re_lu_63 (LeakyReLU)  (None, 1, 100, 150)       0
#
#  dropout_23 (Dropout)        (None, 1, 100, 150)       0
#
#  flatten_7 (Flatten)         (None, 15000)             0
#
#  dropout_24 (Dropout)        (None, 15000)             0
#
#  dense_29 (Dense)            (None, 1)                 15001
#
# =================================================================
# Total params: 45,551
# Trainable params: 45,551
# Non-trainable params: 0
# _________________________________________________________________

# %%
g_a, d_a = 0.0001, 0.00001
g_opt = Adam(learning_rate=g_a)
d_opt = Adam(learning_rate=d_a)  # Does not learn too fast
g_loss = BinaryCrossentropy()
d_loss = BinaryCrossentropy()
class LoadGAN(Model):
    def __init__(self, generator, discriminator, *args, **kwargs):
        # pass through args and kwargs to base class
        super().__init__(*args, **kwargs)
        # Create attributes for gen and disc
        self.generator = generator
        self.discriminator = discriminator

    def compilee(self, g_opt, d_opt, g_loss, d_loss, *args, **kwargs):
        # Compile with base class
        super().compile(*args, **kwargs)

        self.g_opt = g_opt
        self.d_opt = d_opt
        self.g_loss = g_loss
        self.d_loss = d_loss

    def train_step(self, batch):
        real_series = batch
        fake_series = self.generator(tf.random.normal((batch_size, batch_size, 1)), training=False)

        # train the discriminator
        with tf.GradientTape() as d_tape:
            # pass the real and fake images
            yhat_real = self.discriminator(real_series, training=True)
            yhat_fake = self.discriminator(fake_series, training=True)
            yhat_realfake = tf.concat([yhat_real, yhat_fake], axis=0)

            # create labels for real and fake series
            y_realfake = tf.concat([tf.zeros_like(yhat_real), tf.ones_like(yhat_fake)], axis=0)


            # pass through and add some noise to the outputs
            noise_real = 0.15*tf.random.uniform(tf.shape(yhat_real))
            noise_fake = 0.15*tf.random.uniform(tf.shape(yhat_fake))
            y_realfake += tf.concat([noise_real, noise_fake], axis=0)

            # calculate the loss
            total_d_loss = self.d_loss(y_realfake, yhat_realfake)

        # apply backpropagation
        dgrad = d_tape.gradient(total_d_loss, self.discriminator.trainable_variables)
        self.d_opt.apply_gradients(zip(dgrad, self.discriminator.trainable_variables))

        # Generator training
        with tf.GradientTape() as g_tape:
            # generate same new images
            gen_series = self.generator(tf.random.normal((batch_size, batch_size, 1)), training=True)

            # create the predicted labels
            predicted_labels = self.discriminator(gen_series, training=False)

            # calculate loss
            total_g_loss = self.g_loss(tf.zeros_like(predicted_labels), predicted_labels)

        # apply backpropagation
        ggrad = g_tape.gradient(total_g_loss, self.generator.trainable_variables)
        self.g_opt.apply_gradients(zip(ggrad, self.generator.trainable_variables))

        return {"d_loss":total_d_loss, "g_loss":total_g_loss}
loadgan = LoadGAN(generator, discriminator)
loadgan.compilee(g_opt, d_opt, g_loss, d_loss)

# %% [markdown]
# #### Call Back

# %%
class ModelMonitor(Callback):
    def __init__(self, num_img=3, latent_dim=batch_size):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vector = tf.random.uniform((self.num_img, self.latent_dim, 1))
        generated_series = self.model.generator(random_latent_vector)
        generated_series *= max
        generated_series.numpy()
        for i in range(self.num_img):
            serie = array_to_img(generated_series[i])

# %% [markdown]
# #### Train

# %%
hist = loadgan.fit(ds, epochs=400, callbacks=[ModelMonitor()])
# Out:
# Epoch 1/400
# 24/24 [==============================] - 6s 246ms/step - d_loss: 0.6909 - g_loss: 0.7055
# Epoch 2/400
# 24/24 [==============================] - 6s 261ms/step - d_loss: 0.6858 - g_loss: 0.7268
# Epoch 3/400
# 24/24 [==============================] - 6s 258ms/step - d_loss: 0.6801 - g_loss: 0.7472
# Epoch 4/400
# 24/24 [==============================] - 5s 228ms/step - d_loss: 0.6731 - g_loss: 0.7653
# Epoch 5/400
# 24/24 [==============================] - 5s 228ms/step - d_loss: 0.6712 - g_loss: 0.7812
# Epoch 6/400
# 24/24 [==============================] - 6s 249ms/step - d_loss: 0.6674 - g_loss: 0.7947
# Epoch 7/400
# 24/24 [==============================] - 7s 281ms/step - d_loss: 0.6624 - g_loss: 0.8055
# Epoch 8/400
# 24/24 [==============================] - 6s 265ms/step - d_loss: 0.6628 - g_loss: 0.8115
# Epoch 9/400
# 24/24 [==============================] - 6s 258ms/step - d_loss: 0.6662 - g_loss: 0.8092
# Epoch 10/400
# 24/24 [==============================] - 5s 228ms/step - d_loss: 0.6707 - g_loss: 0.7947
# Epoch 11/400
# 24/24 [==============================] - 6s 231ms/step - d_loss: 0.6797 - g_loss: 0.7677
# Epoch 12/400
# 24/24 [==============================] - 6s 233ms/step - d_loss: 0.6883 - g_loss: 0.7367
# Epoch 13/400
# 24/24 [==============================] - 6s 232ms/step - d_loss: 0.6899 - g_loss: 0.7127
# Epoch 14/400
# 24/24 [==============================] - 6s 247ms/step - d_loss: 0.6853 - g_loss: 0.6979
# Epoch 15/400
# 24/24 [==============================] - 7s 275ms/step - d_loss: 0.6787 - g_loss: 0.6863
# Epoch 16/400
# 24/24 [==============================] - 6s 244ms/step - d_loss: 0.6725 - g_loss: 0.6752
# Epoch 17/400
# 24/24 [==============================] - 6s 240ms/step - d_loss: 0.6705 - g_loss: 0.6620
# Epoch 18/400
# 24/24 [==============================] - 6s 228ms/step - d_loss: 0.6735 - g_loss: 0.6484
# Epoch 19/400
# 24/24 [==============================] - 5s 226ms/step - d_loss: 0.6756 - g_loss: 0.6364
# Epoch 20/400
# 24/24 [==============================] - 6s 243ms/step - d_loss: 0.6794 - g_loss: 0.6276
# Epoch 21/400
# 24/24 [==============================] - 6s 268ms/step - d_loss: 0.6833 - g_loss: 0.6237
# Epoch 22/400
# 24/24 [==============================] - 6s 255ms/step - d_loss: 0.6855 - g_loss: 0.6242
# Epoch 23/400
# 24/24 [==============================] - 6s 242ms/step - d_loss: 0.6850 - g_loss: 0.6267
# Epoch 24/400
# 24/24 [==============================] - 6s 237ms/step - d_loss: 0.6874 - g_loss: 0.6322
# Epoch 25/400
# 24/24 [==============================] - 6s 257ms/step - d_loss: 0.6856 - g_loss: 0.6398
# Epoch 26/400
# 24/24 [==============================] - 6s 266ms/step - d_loss: 0.6857 - g_loss: 0.6469
# Epoch 27/400
# 24/24 [==============================] - 6s 262ms/step - d_loss: 0.6858 - g_loss: 0.6555
# Epoch 28/400
# 24/24 [==============================] - 6s 231ms/step - d_loss: 0.6885 - g_loss: 0.6632
# Epoch 29/400
# 24/24 [==============================] - 6s 235ms/step - d_loss: 0.6881 - g_loss: 0.6697
# Epoch 30/400
# 24/24 [==============================] - 5s 226ms/step - d_loss: 0.6893 - g_loss: 0.6736
# Epoch 31/400
# 24/24 [==============================] - 6s 232ms/step - d_loss: 0.6923 - g_loss: 0.6796
# Epoch 32/400
# 24/24 [==============================] - 6s 233ms/step - d_loss: 0.6902 - g_loss: 0.6880
# Epoch 33/400
# 24/24 [==============================] - 6s 231ms/step - d_loss: 0.6900 - g_loss: 0.6997
# Epoch 34/400
# 24/24 [==============================] - 5s 224ms/step - d_loss: 0.6878 - g_loss: 0.7189
# Epoch 35/400
# 24/24 [==============================] - 6s 234ms/step - d_loss: 0.6784 - g_loss: 0.7414
# Epoch 36/400
# 24/24 [==============================] - 6s 230ms/step - d_loss: 0.6749 - g_loss: 0.7700
# Epoch 37/400
# 24/24 [==============================] - 5s 228ms/step - d_loss: 0.6693 - g_loss: 0.7986
# Epoch 38/400
# 24/24 [==============================] - 5s 224ms/step - d_loss: 0.6627 - g_loss: 0.8272
# Epoch 39/400
# 24/24 [==============================] - 6s 231ms/step - d_loss: 0.6628 - g_loss: 0.8450
# Epoch 40/400
# 24/24 [==============================] - 6s 229ms/step - d_loss: 0.6646 - g_loss: 0.8542
# Epoch 41/400
# 24/24 [==============================] - 5s 227ms/step - d_loss: 0.6702 - g_loss: 0.8575
# Epoch 42/400
# 24/24 [==============================] - 5s 225ms/step - d_loss: 0.6769 - g_loss: 0.8664
# Epoch 43/400
# 24/24 [==============================] - 5s 228ms/step - d_loss: 0.6780 - g_loss: 0.8809
# Epoch 44/400
# 24/24 [==============================] - 6s 241ms/step - d_loss: 0.6808 - g_loss: 0.8936
# Epoch 45/400
# 24/24 [==============================] - 5s 226ms/step - d_loss: 0.6781 - g_loss: 0.9048
# Epoch 46/400
# 24/24 [==============================] - 5s 226ms/step - d_loss: 0.6771 - g_loss: 0.9143
# Epoch 47/400
# 24/24 [==============================] - 5s 228ms/step - d_loss: 0.6769 - g_loss: 0.9205
# Epoch 48/400
# 24/24 [==============================] - 6s 229ms/step - d_loss: 0.6689 - g_loss: 0.9267
# Epoch 49/400
# 24/24 [==============================] - 5s 228ms/step - d_loss: 0.6682 - g_loss: 0.9323
# Epoch 50/400
# 24/24 [==============================] - 6s 230ms/step - d_loss: 0.6687 - g_loss: 0.9350
# Epoch 51/400
# 24/24 [==============================] - 6s 237ms/step - d_loss: 0.6672 - g_loss: 0.9336
# Epoch 52/400
# 24/24 [==============================] - 6s 237ms/step - d_loss: 0.6655 - g_loss: 0.9303
# Epoch 53/400
# 24/24 [==============================] - 6s 237ms/step - d_loss: 0.6614 - g_loss: 0.9246
# Epoch 54/400
# 24/24 [==============================] - 5s 227ms/step - d_loss: 0.6668 - g_loss: 0.9142
# Epoch 55/400
# 24/24 [==============================] - 5s 227ms/step - d_loss: 0.6712 - g_loss: 0.8954
# Epoch 56/400
# 24/24 [==============================] - 6s 234ms/step - d_loss: 0.6772 - g_loss: 0.8671
# Epoch 57/400
# 24/24 [==============================] - 5s 223ms/step - d_loss: 0.6849 - g_loss: 0.8383
# Epoch 58/400
# 24/24 [==============================] - 6s 231ms/step - d_loss: 0.6894 - g_loss: 0.8086
# Epoch 59/400
# 24/24 [==============================] - 6s 231ms/step - d_loss: 0.6897 - g_loss: 0.7900
# Epoch 60/400
# 24/24 [==============================] - 6s 232ms/step - d_loss: 0.6827 - g_loss: 0.7801
# Epoch 61/400
# 24/24 [==============================] - 5s 225ms/step - d_loss: 0.6757 - g_loss: 0.7787
# Epoch 62/400
# 24/24 [==============================] - 6s 233ms/step - d_loss: 0.6681 - g_loss: 0.7799
# Epoch 63/400
# 24/24 [==============================] - 6s 232ms/step - d_loss: 0.6605 - g_loss: 0.7811
# Epoch 64/400
# 24/24 [==============================] - 6s 231ms/step - d_loss: 0.6615 - g_loss: 0.7796
# Epoch 65/400
# 24/24 [==============================] - 5s 226ms/step - d_loss: 0.6655 - g_loss: 0.7764
# Epoch 66/400
# 24/24 [==============================] - 5s 228ms/step - d_loss: 0.6708 - g_loss: 0.7774
# Epoch 67/400
# 24/24 [==============================] - 6s 231ms/step - d_loss: 0.6775 - g_loss: 0.7839
# Epoch 68/400
# 24/24 [==============================] - 5s 225ms/step - d_loss: 0.6819 - g_loss: 0.8097
# Epoch 69/400
# 24/24 [==============================] - 5s 224ms/step - d_loss: 0.6777 - g_loss: 0.8436
# Epoch 70/400
# 24/24 [==============================] - 6s 237ms/step - d_loss: 0.6742 - g_loss: 0.8793
# Epoch 71/400
# 24/24 [==============================] - 6s 232ms/step - d_loss: 0.6740 - g_loss: 0.9114
# Epoch 72/400
# 24/24 [==============================] - 5s 228ms/step - d_loss: 0.6709 - g_loss: 0.9348
# Epoch 73/400
# 24/24 [==============================] - 5s 225ms/step - d_loss: 0.6706 - g_loss: 0.9505
# Epoch 74/400
# 24/24 [==============================] - 5s 229ms/step - d_loss: 0.6682 - g_loss: 0.9591
# Epoch 75/400
# 24/24 [==============================] - 6s 230ms/step - d_loss: 0.6670 - g_loss: 0.9633
# Epoch 76/400
# 24/24 [==============================] - 5s 226ms/step - d_loss: 0.6669 - g_loss: 0.9636
# Epoch 77/400
# 24/24 [==============================] - 5s 224ms/step - d_loss: 0.6657 - g_loss: 0.9616
# Epoch 78/400
# 24/24 [==============================] - 6s 241ms/step - d_loss: 0.6654 - g_loss: 0.9546
# Epoch 79/400
# 24/24 [==============================] - 6s 243ms/step - d_loss: 0.6673 - g_loss: 0.9463
# Epoch 80/400
# 24/24 [==============================] - 5s 221ms/step - d_loss: 0.6682 - g_loss: 0.9365
# Epoch 81/400
# 24/24 [==============================] - 6s 233ms/step - d_loss: 0.6667 - g_loss: 0.9245
# Epoch 82/400
# 24/24 [==============================] - 6s 230ms/step - d_loss: 0.6750 - g_loss: 0.9099
# Epoch 83/400
# 24/24 [==============================] - 5s 227ms/step - d_loss: 0.6740 - g_loss: 0.8941
# Epoch 84/400
# 24/24 [==============================] - 5s 225ms/step - d_loss: 0.6756 - g_loss: 0.8780
# Epoch 85/400
# 24/24 [==============================] - 5s 229ms/step - d_loss: 0.6750 - g_loss: 0.8676
# Epoch 86/400
# 24/24 [==============================] - 5s 229ms/step - d_loss: 0.6761 - g_loss: 0.8561
# Epoch 87/400
# 24/24 [==============================] - 6s 231ms/step - d_loss: 0.6733 - g_loss: 0.8501
# Epoch 88/400
# 24/24 [==============================] - 5s 226ms/step - d_loss: 0.6737 - g_loss: 0.8468
# Epoch 89/400
# 24/24 [==============================] - 6s 234ms/step - d_loss: 0.6741 - g_loss: 0.8455
# Epoch 90/400
# 24/24 [==============================] - 6s 230ms/step - d_loss: 0.6750 - g_loss: 0.8458
# Epoch 91/400
# 24/24 [==============================] - 6s 229ms/step - d_loss: 0.6720 - g_loss: 0.8476
# Epoch 92/400
# 24/24 [==============================] - 5s 222ms/step - d_loss: 0.6762 - g_loss: 0.8528
# Epoch 93/400
# 24/24 [==============================] - 6s 235ms/step - d_loss: 0.6726 - g_loss: 0.8586
# Epoch 94/400
# 24/24 [==============================] - 6s 232ms/step - d_loss: 0.6704 - g_loss: 0.8667
# Epoch 95/400
# 24/24 [==============================] - 5s 229ms/step - d_loss: 0.6730 - g_loss: 0.8776
# Epoch 96/400
# 24/24 [==============================] - 5s 227ms/step - d_loss: 0.6687 - g_loss: 0.8859
# Epoch 97/400
# 24/24 [==============================] - 6s 230ms/step - d_loss: 0.6688 - g_loss: 0.8971
# Epoch 98/400
# 24/24 [==============================] - 6s 239ms/step - d_loss: 0.6721 - g_loss: 0.9060
# Epoch 99/400
# 24/24 [==============================] - 6s 244ms/step - d_loss: 0.6690 - g_loss: 0.9120
# Epoch 100/400
# 24/24 [==============================] - 6s 236ms/step - d_loss: 0.6691 - g_loss: 0.9154
# Epoch 101/400
# 24/24 [==============================] - 6s 233ms/step - d_loss: 0.6671 - g_loss: 0.9165
# Epoch 102/400
# 24/24 [==============================] - 6s 229ms/step - d_loss: 0.6671 - g_loss: 0.9152
# Epoch 103/400
# 24/24 [==============================] - 5s 226ms/step - d_loss: 0.6699 - g_loss: 0.9116
# Epoch 104/400
# 24/24 [==============================] - 6s 245ms/step - d_loss: 0.6689 - g_loss: 0.9064
# Epoch 105/400
# 24/24 [==============================] - 5s 205ms/step - d_loss: 0.6716 - g_loss: 0.9012
# Epoch 106/400
# 24/24 [==============================] - 5s 198ms/step - d_loss: 0.6691 - g_loss: 0.8965
# Epoch 107/400
# 24/24 [==============================] - 5s 200ms/step - d_loss: 0.6699 - g_loss: 0.8946
# Epoch 108/400
# 24/24 [==============================] - 5s 196ms/step - d_loss: 0.6679 - g_loss: 0.8928
# Epoch 109/400
# 24/24 [==============================] - 5s 199ms/step - d_loss: 0.6683 - g_loss: 0.8912
# Epoch 110/400
# 24/24 [==============================] - 5s 200ms/step - d_loss: 0.6697 - g_loss: 0.8893
# Epoch 111/400
# 24/24 [==============================] - 5s 203ms/step - d_loss: 0.6686 - g_loss: 0.8860
# Epoch 112/400
# 24/24 [==============================] - 4s 166ms/step - d_loss: 0.6691 - g_loss: 0.8830
# Epoch 113/400
# 24/24 [==============================] - 4s 167ms/step - d_loss: 0.6712 - g_loss: 0.8807
# Epoch 114/400
# 24/24 [==============================] - 4s 166ms/step - d_loss: 0.6690 - g_loss: 0.8790
# Epoch 115/400
# 24/24 [==============================] - 4s 167ms/step - d_loss: 0.6690 - g_loss: 0.8796
# Epoch 116/400
# 24/24 [==============================] - 4s 165ms/step - d_loss: 0.6686 - g_loss: 0.8822
# Epoch 117/400
# 24/24 [==============================] - 4s 167ms/step - d_loss: 0.6696 - g_loss: 0.8832
# Epoch 118/400
# 24/24 [==============================] - 4s 168ms/step - d_loss: 0.6732 - g_loss: 0.8853
# Epoch 119/400
# 24/24 [==============================] - 4s 167ms/step - d_loss: 0.6735 - g_loss: 0.8878
# Epoch 120/400
# 24/24 [==============================] - 4s 161ms/step - d_loss: 0.6730 - g_loss: 0.8907
# Epoch 121/400
# 24/24 [==============================] - 4s 163ms/step - d_loss: 0.6718 - g_loss: 0.8934
# Epoch 122/400
# 24/24 [==============================] - 4s 162ms/step - d_loss: 0.6705 - g_loss: 0.8978
# Epoch 123/400
# 24/24 [==============================] - 4s 162ms/step - d_loss: 0.6718 - g_loss: 0.9035
# Epoch 124/400
# 24/24 [==============================] - 4s 167ms/step - d_loss: 0.6745 - g_loss: 0.9065
# Epoch 125/400
# 24/24 [==============================] - 4s 167ms/step - d_loss: 0.6747 - g_loss: 0.9080
# Epoch 126/400
# 24/24 [==============================] - 5s 219ms/step - d_loss: 0.6744 - g_loss: 0.9083
# Epoch 127/400
# 24/24 [==============================] - 5s 215ms/step - d_loss: 0.6693 - g_loss: 0.9100
# Epoch 128/400
# 24/24 [==============================] - 5s 218ms/step - d_loss: 0.6692 - g_loss: 0.9121
# Epoch 129/400
# 24/24 [==============================] - 5s 212ms/step - d_loss: 0.6719 - g_loss: 0.9131
# Epoch 130/400
# 24/24 [==============================] - 5s 209ms/step - d_loss: 0.6741 - g_loss: 0.9113
# Epoch 131/400
# 24/24 [==============================] - 5s 203ms/step - d_loss: 0.6706 - g_loss: 0.9079
# Epoch 132/400
# 24/24 [==============================] - 5s 211ms/step - d_loss: 0.6723 - g_loss: 0.9059
# Epoch 133/400
# 24/24 [==============================] - 5s 214ms/step - d_loss: 0.6706 - g_loss: 0.9026
# Epoch 134/400
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6734 - g_loss: 0.8988
# Epoch 135/400
# 24/24 [==============================] - 5s 186ms/step - d_loss: 0.6698 - g_loss: 0.8934
# Epoch 136/400
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6710 - g_loss: 0.8893
# Epoch 137/400
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6707 - g_loss: 0.8870
# Epoch 138/400
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6684 - g_loss: 0.8857
# Epoch 139/400
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6702 - g_loss: 0.8833
# Epoch 140/400
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6719 - g_loss: 0.8799
# Epoch 141/400
# 24/24 [==============================] - 5s 189ms/step - d_loss: 0.6707 - g_loss: 0.8776
# Epoch 142/400
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6696 - g_loss: 0.8760
# Epoch 143/400
# 24/24 [==============================] - 4s 167ms/step - d_loss: 0.6699 - g_loss: 0.8762
# Epoch 144/400
# 24/24 [==============================] - 4s 174ms/step - d_loss: 0.6713 - g_loss: 0.8763
# Epoch 145/400
# 24/24 [==============================] - 5s 187ms/step - d_loss: 0.6725 - g_loss: 0.8760
# Epoch 146/400
# 24/24 [==============================] - 4s 171ms/step - d_loss: 0.6691 - g_loss: 0.8789
# Epoch 147/400
# 24/24 [==============================] - 4s 168ms/step - d_loss: 0.6697 - g_loss: 0.8823
# Epoch 148/400
# 24/24 [==============================] - 4s 172ms/step - d_loss: 0.6692 - g_loss: 0.8853
# Epoch 149/400
# 24/24 [==============================] - 4s 172ms/step - d_loss: 0.6721 - g_loss: 0.8898
# Epoch 150/400
# 24/24 [==============================] - 4s 171ms/step - d_loss: 0.6710 - g_loss: 0.8919
# Epoch 151/400
# 24/24 [==============================] - 4s 171ms/step - d_loss: 0.6739 - g_loss: 0.8963
# Epoch 152/400
# 24/24 [==============================] - 4s 172ms/step - d_loss: 0.6730 - g_loss: 0.9007
# Epoch 153/400
# 24/24 [==============================] - 4s 170ms/step - d_loss: 0.6721 - g_loss: 0.9036
# Epoch 154/400
# 24/24 [==============================] - 4s 171ms/step - d_loss: 0.6696 - g_loss: 0.9040
# Epoch 155/400
# 24/24 [==============================] - 4s 169ms/step - d_loss: 0.6718 - g_loss: 0.9029
# Epoch 156/400
# 24/24 [==============================] - 4s 176ms/step - d_loss: 0.6745 - g_loss: 0.9004
# Epoch 157/400
# 24/24 [==============================] - 4s 170ms/step - d_loss: 0.6752 - g_loss: 0.8986
# Epoch 158/400
# 24/24 [==============================] - 4s 172ms/step - d_loss: 0.6697 - g_loss: 0.8958
# Epoch 159/400
# 24/24 [==============================] - 4s 173ms/step - d_loss: 0.6727 - g_loss: 0.8919
# Epoch 160/400
# 24/24 [==============================] - 4s 171ms/step - d_loss: 0.6736 - g_loss: 0.8871
# Epoch 161/400
# 24/24 [==============================] - 4s 170ms/step - d_loss: 0.6724 - g_loss: 0.8837
# Epoch 162/400
# 24/24 [==============================] - 4s 174ms/step - d_loss: 0.6736 - g_loss: 0.8815
# Epoch 163/400
# 24/24 [==============================] - 4s 173ms/step - d_loss: 0.6710 - g_loss: 0.8780
# Epoch 164/400
# 24/24 [==============================] - 4s 174ms/step - d_loss: 0.6736 - g_loss: 0.8748
# Epoch 165/400
# 24/24 [==============================] - 4s 175ms/step - d_loss: 0.6724 - g_loss: 0.8730
# Epoch 166/400
# 24/24 [==============================] - 4s 170ms/step - d_loss: 0.6734 - g_loss: 0.8730
# Epoch 167/400
# 24/24 [==============================] - 4s 171ms/step - d_loss: 0.6739 - g_loss: 0.8732
# Epoch 168/400
# 24/24 [==============================] - 4s 177ms/step - d_loss: 0.6752 - g_loss: 0.8739
# Epoch 169/400
# 24/24 [==============================] - 5s 205ms/step - d_loss: 0.6721 - g_loss: 0.8742
# Epoch 170/400
# 24/24 [==============================] - 4s 178ms/step - d_loss: 0.6752 - g_loss: 0.8762
# Epoch 171/400
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6759 - g_loss: 0.8768
# Epoch 172/400
# 24/24 [==============================] - 4s 177ms/step - d_loss: 0.6712 - g_loss: 0.8780
# Epoch 173/400
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6721 - g_loss: 0.8806
# Epoch 174/400
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6760 - g_loss: 0.8811
# Epoch 175/400
# 24/24 [==============================] - 4s 178ms/step - d_loss: 0.6745 - g_loss: 0.8810
# Epoch 176/400
# 24/24 [==============================] - 4s 175ms/step - d_loss: 0.6761 - g_loss: 0.8798
# Epoch 177/400
# 24/24 [==============================] - 4s 176ms/step - d_loss: 0.6731 - g_loss: 0.8779
# Epoch 178/400
# 24/24 [==============================] - 4s 177ms/step - d_loss: 0.6751 - g_loss: 0.8764
# Epoch 179/400
# 24/24 [==============================] - 4s 179ms/step - d_loss: 0.6743 - g_loss: 0.8746
# Epoch 180/400
# 24/24 [==============================] - 5s 207ms/step - d_loss: 0.6773 - g_loss: 0.8753
# Epoch 181/400
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6748 - g_loss: 0.8752
# Epoch 182/400
# 24/24 [==============================] - 4s 175ms/step - d_loss: 0.6711 - g_loss: 0.8766
# Epoch 183/400
# 24/24 [==============================] - 5s 225ms/step - d_loss: 0.6713 - g_loss: 0.8782
# Epoch 184/400
# 24/24 [==============================] - 5s 208ms/step - d_loss: 0.6722 - g_loss: 0.8795
# Epoch 185/400
# 24/24 [==============================] - 5s 217ms/step - d_loss: 0.6745 - g_loss: 0.8807
# Epoch 186/400
# 24/24 [==============================] - 5s 216ms/step - d_loss: 0.6744 - g_loss: 0.8824
# Epoch 187/400
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6748 - g_loss: 0.8829
# Epoch 188/400
# 24/24 [==============================] - 5s 189ms/step - d_loss: 0.6739 - g_loss: 0.8839
# Epoch 189/400
# 24/24 [==============================] - 4s 177ms/step - d_loss: 0.6731 - g_loss: 0.8842
# Epoch 190/400
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6744 - g_loss: 0.8834
# Epoch 191/400
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6747 - g_loss: 0.8816
# Epoch 192/400
# 24/24 [==============================] - 5s 196ms/step - d_loss: 0.6723 - g_loss: 0.8788
# Epoch 193/400
# 24/24 [==============================] - 5s 199ms/step - d_loss: 0.6728 - g_loss: 0.8775
# Epoch 194/400
# 24/24 [==============================] - 4s 155ms/step - d_loss: 0.6751 - g_loss: 0.8751
# Epoch 195/400
# 24/24 [==============================] - 3s 135ms/step - d_loss: 0.6770 - g_loss: 0.8720
# Epoch 196/400
# 24/24 [==============================] - 4s 149ms/step - d_loss: 0.6758 - g_loss: 0.8710
# Epoch 197/400
# 24/24 [==============================] - 3s 137ms/step - d_loss: 0.6770 - g_loss: 0.8728
# Epoch 198/400
# 24/24 [==============================] - 3s 139ms/step - d_loss: 0.6791 - g_loss: 0.8761
# Epoch 199/400
# 24/24 [==============================] - 3s 131ms/step - d_loss: 0.6802 - g_loss: 0.8774
# Epoch 200/400
# 24/24 [==============================] - 3s 133ms/step - d_loss: 0.6821 - g_loss: 0.8812
# Epoch 201/400
# 24/24 [==============================] - 3s 137ms/step - d_loss: 0.6770 - g_loss: 0.8875
# Epoch 202/400
# 24/24 [==============================] - 3s 136ms/step - d_loss: 0.6771 - g_loss: 0.8923
# Epoch 203/400
# 24/24 [==============================] - 3s 133ms/step - d_loss: 0.6745 - g_loss: 0.8962
# Epoch 204/400
# 24/24 [==============================] - 3s 132ms/step - d_loss: 0.6764 - g_loss: 0.8985
# Epoch 205/400
# 24/24 [==============================] - 3s 136ms/step - d_loss: 0.6780 - g_loss: 0.8962
# Epoch 206/400
# 24/24 [==============================] - 3s 135ms/step - d_loss: 0.6773 - g_loss: 0.8925
# Epoch 207/400
# 24/24 [==============================] - 3s 136ms/step - d_loss: 0.6764 - g_loss: 0.8875
# Epoch 208/400
# 24/24 [==============================] - 3s 132ms/step - d_loss: 0.6761 - g_loss: 0.8832
# Epoch 209/400
# 24/24 [==============================] - 3s 141ms/step - d_loss: 0.6764 - g_loss: 0.8794
# Epoch 210/400
# 24/24 [==============================] - 3s 132ms/step - d_loss: 0.6731 - g_loss: 0.8760
# Epoch 211/400
# 24/24 [==============================] - 3s 129ms/step - d_loss: 0.6743 - g_loss: 0.8736
# Epoch 212/400
# 24/24 [==============================] - 3s 136ms/step - d_loss: 0.6751 - g_loss: 0.8719
# Epoch 213/400
# 24/24 [==============================] - 3s 133ms/step - d_loss: 0.6757 - g_loss: 0.8722
# Epoch 214/400
# 24/24 [==============================] - 3s 133ms/step - d_loss: 0.6741 - g_loss: 0.8736
# Epoch 215/400
# 24/24 [==============================] - 3s 130ms/step - d_loss: 0.6747 - g_loss: 0.8771
# Epoch 216/400
# 24/24 [==============================] - 3s 136ms/step - d_loss: 0.6759 - g_loss: 0.8815
# Epoch 217/400
# 24/24 [==============================] - 3s 138ms/step - d_loss: 0.6771 - g_loss: 0.8860
# Epoch 218/400
# 24/24 [==============================] - 3s 131ms/step - d_loss: 0.6751 - g_loss: 0.8895
# Epoch 219/400
# 24/24 [==============================] - 3s 133ms/step - d_loss: 0.6791 - g_loss: 0.8932
# Epoch 220/400
# 24/24 [==============================] - 3s 136ms/step - d_loss: 0.6763 - g_loss: 0.8934
# Epoch 221/400
# 24/24 [==============================] - 3s 136ms/step - d_loss: 0.6772 - g_loss: 0.8951
# Epoch 222/400
# 24/24 [==============================] - 3s 129ms/step - d_loss: 0.6770 - g_loss: 0.8957
# Epoch 223/400
# 24/24 [==============================] - 3s 130ms/step - d_loss: 0.6764 - g_loss: 0.8963
# Epoch 224/400
# 24/24 [==============================] - 3s 132ms/step - d_loss: 0.6760 - g_loss: 0.8969
# Epoch 225/400
# 24/24 [==============================] - 3s 129ms/step - d_loss: 0.6737 - g_loss: 0.8968
# Epoch 226/400
# 24/24 [==============================] - 3s 127ms/step - d_loss: 0.6733 - g_loss: 0.8962
# Epoch 227/400
# 24/24 [==============================] - 3s 131ms/step - d_loss: 0.6715 - g_loss: 0.8920
# Epoch 228/400
# 24/24 [==============================] - 3s 135ms/step - d_loss: 0.6738 - g_loss: 0.8885
# Epoch 229/400
# 24/24 [==============================] - 3s 127ms/step - d_loss: 0.6731 - g_loss: 0.8839
# Epoch 230/400
# 24/24 [==============================] - 3s 127ms/step - d_loss: 0.6707 - g_loss: 0.8803
# Epoch 231/400
# 24/24 [==============================] - 3s 133ms/step - d_loss: 0.6716 - g_loss: 0.8770
# Epoch 232/400
# 24/24 [==============================] - 3s 126ms/step - d_loss: 0.6738 - g_loss: 0.8755
# Epoch 233/400
# 24/24 [==============================] - 3s 126ms/step - d_loss: 0.6738 - g_loss: 0.8749
# Epoch 234/400
# 24/24 [==============================] - 3s 129ms/step - d_loss: 0.6727 - g_loss: 0.8763
# Epoch 235/400
# 24/24 [==============================] - 3s 128ms/step - d_loss: 0.6722 - g_loss: 0.8774
# Epoch 236/400
# 24/24 [==============================] - 3s 128ms/step - d_loss: 0.6732 - g_loss: 0.8791
# Epoch 237/400
# 24/24 [==============================] - 3s 127ms/step - d_loss: 0.6738 - g_loss: 0.8814
# Epoch 238/400
# 24/24 [==============================] - 3s 136ms/step - d_loss: 0.6724 - g_loss: 0.8835
# Epoch 239/400
# 24/24 [==============================] - 3s 131ms/step - d_loss: 0.6757 - g_loss: 0.8844
# Epoch 240/400
# 24/24 [==============================] - 3s 131ms/step - d_loss: 0.6748 - g_loss: 0.8826
# Epoch 241/400
# 24/24 [==============================] - 3s 135ms/step - d_loss: 0.6736 - g_loss: 0.8798
# Epoch 242/400
# 24/24 [==============================] - 3s 139ms/step - d_loss: 0.6747 - g_loss: 0.8760
# Epoch 243/400
# 24/24 [==============================] - 3s 132ms/step - d_loss: 0.6740 - g_loss: 0.8709
# Epoch 244/400
# 24/24 [==============================] - 3s 135ms/step - d_loss: 0.6754 - g_loss: 0.8676
# Epoch 245/400
# 24/24 [==============================] - 3s 134ms/step - d_loss: 0.6771 - g_loss: 0.8659
# Epoch 246/400
# 24/24 [==============================] - 3s 131ms/step - d_loss: 0.6754 - g_loss: 0.8665
# Epoch 247/400
# 24/24 [==============================] - 3s 127ms/step - d_loss: 0.6728 - g_loss: 0.8713
# Epoch 248/400
# 24/24 [==============================] - 3s 130ms/step - d_loss: 0.6726 - g_loss: 0.8782
# Epoch 249/400
# 24/24 [==============================] - 3s 145ms/step - d_loss: 0.6699 - g_loss: 0.8854
# Epoch 250/400
# 24/24 [==============================] - 3s 136ms/step - d_loss: 0.6719 - g_loss: 0.8893
# Epoch 251/400
# 24/24 [==============================] - 3s 132ms/step - d_loss: 0.6737 - g_loss: 0.8884
# Epoch 252/400
# 24/24 [==============================] - 3s 133ms/step - d_loss: 0.6730 - g_loss: 0.8842
# Epoch 253/400
# 24/24 [==============================] - 3s 138ms/step - d_loss: 0.6767 - g_loss: 0.8765
# Epoch 254/400
# 24/24 [==============================] - 3s 132ms/step - d_loss: 0.6748 - g_loss: 0.8686
# Epoch 255/400
# 24/24 [==============================] - 3s 130ms/step - d_loss: 0.6760 - g_loss: 0.8636
# Epoch 256/400
# 24/24 [==============================] - 3s 132ms/step - d_loss: 0.6744 - g_loss: 0.8649
# Epoch 257/400
# 24/24 [==============================] - 4s 156ms/step - d_loss: 0.6746 - g_loss: 0.8741
# Epoch 258/400
# 24/24 [==============================] - 3s 144ms/step - d_loss: 0.6740 - g_loss: 0.8856
# Epoch 259/400
# 24/24 [==============================] - 3s 141ms/step - d_loss: 0.6702 - g_loss: 0.8944
# Epoch 260/400
# 24/24 [==============================] - 3s 136ms/step - d_loss: 0.6736 - g_loss: 0.8983
# Epoch 261/400
# 24/24 [==============================] - 3s 139ms/step - d_loss: 0.6726 - g_loss: 0.8950
# Epoch 262/400
# 24/24 [==============================] - 3s 143ms/step - d_loss: 0.6758 - g_loss: 0.8870
# Epoch 263/400
# 24/24 [==============================] - 3s 134ms/step - d_loss: 0.6755 - g_loss: 0.8770
# Epoch 264/400
# 24/24 [==============================] - 4s 175ms/step - d_loss: 0.6718 - g_loss: 0.8682
# Epoch 265/400
# 24/24 [==============================] - 4s 176ms/step - d_loss: 0.6753 - g_loss: 0.8648
# Epoch 266/400
# 24/24 [==============================] - 4s 171ms/step - d_loss: 0.6723 - g_loss: 0.8689
# Epoch 267/400
# 24/24 [==============================] - 4s 176ms/step - d_loss: 0.6748 - g_loss: 0.8823
# Epoch 268/400
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6714 - g_loss: 0.8957
# Epoch 269/400
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6717 - g_loss: 0.9049
# Epoch 270/400
# 24/24 [==============================] - 5s 203ms/step - d_loss: 0.6736 - g_loss: 0.9077
# Epoch 271/400
# 24/24 [==============================] - 5s 196ms/step - d_loss: 0.6761 - g_loss: 0.9035
# Epoch 272/400
# 24/24 [==============================] - 4s 168ms/step - d_loss: 0.6759 - g_loss: 0.8940
# Epoch 273/400
# 24/24 [==============================] - 5s 216ms/step - d_loss: 0.6718 - g_loss: 0.8840
# Epoch 274/400
# 24/24 [==============================] - 4s 174ms/step - d_loss: 0.6732 - g_loss: 0.8757
# Epoch 275/400
# 24/24 [==============================] - 4s 158ms/step - d_loss: 0.6751 - g_loss: 0.8692
# Epoch 276/400
# 24/24 [==============================] - 4s 164ms/step - d_loss: 0.6737 - g_loss: 0.8675
# Epoch 277/400
# 24/24 [==============================] - 4s 163ms/step - d_loss: 0.6719 - g_loss: 0.8738
# Epoch 278/400
# 24/24 [==============================] - 4s 169ms/step - d_loss: 0.6723 - g_loss: 0.8851
# Epoch 279/400
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6681 - g_loss: 0.8955
# Epoch 280/400
# 24/24 [==============================] - 4s 170ms/step - d_loss: 0.6729 - g_loss: 0.9007
# Epoch 281/400
# 24/24 [==============================] - 4s 158ms/step - d_loss: 0.6721 - g_loss: 0.8987
# Epoch 282/400
# 24/24 [==============================] - 4s 160ms/step - d_loss: 0.6724 - g_loss: 0.8923
# Epoch 283/400
# 24/24 [==============================] - 4s 160ms/step - d_loss: 0.6712 - g_loss: 0.8824
# Epoch 284/400
# 24/24 [==============================] - 4s 163ms/step - d_loss: 0.6720 - g_loss: 0.8739
# Epoch 285/400
# 24/24 [==============================] - 4s 160ms/step - d_loss: 0.6739 - g_loss: 0.8641
# Epoch 286/400
# 24/24 [==============================] - 4s 157ms/step - d_loss: 0.6718 - g_loss: 0.8579
# Epoch 287/400
# 24/24 [==============================] - 4s 158ms/step - d_loss: 0.6730 - g_loss: 0.8604
# Epoch 288/400
# 24/24 [==============================] - 4s 159ms/step - d_loss: 0.6710 - g_loss: 0.8696
# Epoch 289/400
# 24/24 [==============================] - 4s 158ms/step - d_loss: 0.6739 - g_loss: 0.8813
# Epoch 290/400
# 24/24 [==============================] - 4s 154ms/step - d_loss: 0.6714 - g_loss: 0.8892
# Epoch 291/400
# 24/24 [==============================] - 4s 152ms/step - d_loss: 0.6732 - g_loss: 0.8936
# Epoch 292/400
# 24/24 [==============================] - 4s 155ms/step - d_loss: 0.6741 - g_loss: 0.8915
# Epoch 293/400
# 24/24 [==============================] - 4s 155ms/step - d_loss: 0.6771 - g_loss: 0.8856
# Epoch 294/400
# 24/24 [==============================] - 4s 157ms/step - d_loss: 0.6745 - g_loss: 0.8769
# Epoch 295/400
# 24/24 [==============================] - 4s 160ms/step - d_loss: 0.6755 - g_loss: 0.8707
# Epoch 296/400
# 24/24 [==============================] - 4s 162ms/step - d_loss: 0.6744 - g_loss: 0.8728
# Epoch 297/400
# 24/24 [==============================] - 4s 163ms/step - d_loss: 0.6749 - g_loss: 0.8821
# Epoch 298/400
# 24/24 [==============================] - 4s 159ms/step - d_loss: 0.6770 - g_loss: 0.8923
# Epoch 299/400
# 24/24 [==============================] - 4s 157ms/step - d_loss: 0.6745 - g_loss: 0.8987
# Epoch 300/400
# 24/24 [==============================] - 4s 157ms/step - d_loss: 0.6726 - g_loss: 0.9005
# Epoch 301/400
# 24/24 [==============================] - 4s 157ms/step - d_loss: 0.6753 - g_loss: 0.8954
# Epoch 302/400
# 24/24 [==============================] - 4s 157ms/step - d_loss: 0.6727 - g_loss: 0.8878
# Epoch 303/400
# 24/24 [==============================] - 4s 155ms/step - d_loss: 0.6729 - g_loss: 0.8831
# Epoch 304/400
# 24/24 [==============================] - 4s 155ms/step - d_loss: 0.6740 - g_loss: 0.8820
# Epoch 305/400
# 24/24 [==============================] - 4s 155ms/step - d_loss: 0.6722 - g_loss: 0.8861
# Epoch 306/400
# 24/24 [==============================] - 4s 155ms/step - d_loss: 0.6711 - g_loss: 0.8930
# Epoch 307/400
# 24/24 [==============================] - 4s 156ms/step - d_loss: 0.6727 - g_loss: 0.8954
# Epoch 308/400
# 24/24 [==============================] - 4s 154ms/step - d_loss: 0.6712 - g_loss: 0.8926
# Epoch 309/400
# 24/24 [==============================] - 4s 155ms/step - d_loss: 0.6769 - g_loss: 0.8860
# Epoch 310/400
# 24/24 [==============================] - 4s 155ms/step - d_loss: 0.6759 - g_loss: 0.8770
# Epoch 311/400
# 24/24 [==============================] - 4s 153ms/step - d_loss: 0.6744 - g_loss: 0.8712
# Epoch 312/400
# 24/24 [==============================] - 4s 153ms/step - d_loss: 0.6748 - g_loss: 0.8722
# Epoch 313/400
# 24/24 [==============================] - 4s 153ms/step - d_loss: 0.6749 - g_loss: 0.8778
# Epoch 314/400
# 24/24 [==============================] - 4s 153ms/step - d_loss: 0.6744 - g_loss: 0.8839
# Epoch 315/400
# 24/24 [==============================] - 4s 154ms/step - d_loss: 0.6728 - g_loss: 0.8850
# Epoch 316/400
# 24/24 [==============================] - 4s 157ms/step - d_loss: 0.6753 - g_loss: 0.8835
# Epoch 317/400
# 24/24 [==============================] - 4s 161ms/step - d_loss: 0.6777 - g_loss: 0.8783
# Epoch 318/400
# 24/24 [==============================] - 4s 161ms/step - d_loss: 0.6745 - g_loss: 0.8735
# Epoch 319/400
# 24/24 [==============================] - 4s 159ms/step - d_loss: 0.6730 - g_loss: 0.8732
# Epoch 320/400
# 24/24 [==============================] - 4s 156ms/step - d_loss: 0.6739 - g_loss: 0.8779
# Epoch 321/400
# 24/24 [==============================] - 4s 157ms/step - d_loss: 0.6724 - g_loss: 0.8822
# Epoch 322/400
# 24/24 [==============================] - 4s 156ms/step - d_loss: 0.6761 - g_loss: 0.8843
# Epoch 323/400
# 24/24 [==============================] - 4s 155ms/step - d_loss: 0.6734 - g_loss: 0.8845
# Epoch 324/400
# 24/24 [==============================] - 4s 153ms/step - d_loss: 0.6755 - g_loss: 0.8825
# Epoch 325/400
# 24/24 [==============================] - 4s 154ms/step - d_loss: 0.6746 - g_loss: 0.8798
# Epoch 326/400
# 24/24 [==============================] - 4s 153ms/step - d_loss: 0.6744 - g_loss: 0.8780
# Epoch 327/400
# 24/24 [==============================] - 4s 154ms/step - d_loss: 0.6742 - g_loss: 0.8772
# Epoch 328/400
# 24/24 [==============================] - 4s 155ms/step - d_loss: 0.6724 - g_loss: 0.8791
# Epoch 329/400
# 24/24 [==============================] - 4s 162ms/step - d_loss: 0.6759 - g_loss: 0.8809
# Epoch 330/400
# 24/24 [==============================] - 4s 153ms/step - d_loss: 0.6764 - g_loss: 0.8808
# Epoch 331/400
# 24/24 [==============================] - 4s 152ms/step - d_loss: 0.6754 - g_loss: 0.8812
# Epoch 332/400
# 24/24 [==============================] - 4s 160ms/step - d_loss: 0.6741 - g_loss: 0.8829
# Epoch 333/400
# 24/24 [==============================] - 4s 158ms/step - d_loss: 0.6744 - g_loss: 0.8828
# Epoch 334/400
# 24/24 [==============================] - 4s 157ms/step - d_loss: 0.6767 - g_loss: 0.8813
# Epoch 335/400
# 24/24 [==============================] - 4s 156ms/step - d_loss: 0.6763 - g_loss: 0.8789
# Epoch 336/400
# 24/24 [==============================] - 4s 160ms/step - d_loss: 0.6781 - g_loss: 0.8769
# Epoch 337/400
# 24/24 [==============================] - 4s 154ms/step - d_loss: 0.6766 - g_loss: 0.8750
# Epoch 338/400
# 24/24 [==============================] - 4s 153ms/step - d_loss: 0.6746 - g_loss: 0.8769
# Epoch 339/400
# 24/24 [==============================] - 4s 155ms/step - d_loss: 0.6728 - g_loss: 0.8807
# Epoch 340/400
# 24/24 [==============================] - 4s 189ms/step - d_loss: 0.6772 - g_loss: 0.8829
# Epoch 341/400
# 24/24 [==============================] - 4s 156ms/step - d_loss: 0.6772 - g_loss: 0.8817
# Epoch 342/400
# 24/24 [==============================] - 4s 153ms/step - d_loss: 0.6755 - g_loss: 0.8803
# Epoch 343/400
# 24/24 [==============================] - 4s 156ms/step - d_loss: 0.6745 - g_loss: 0.8802
# Epoch 344/400
# 24/24 [==============================] - 4s 154ms/step - d_loss: 0.6772 - g_loss: 0.8796
# Epoch 345/400
# 24/24 [==============================] - 4s 154ms/step - d_loss: 0.6749 - g_loss: 0.8789
# Epoch 346/400
# 24/24 [==============================] - 4s 163ms/step - d_loss: 0.6745 - g_loss: 0.8781
# Epoch 347/400
# 24/24 [==============================] - 4s 169ms/step - d_loss: 0.6730 - g_loss: 0.8779
# Epoch 348/400
# 24/24 [==============================] - 4s 159ms/step - d_loss: 0.6731 - g_loss: 0.8782
# Epoch 349/400
# 24/24 [==============================] - 4s 160ms/step - d_loss: 0.6729 - g_loss: 0.8791
# Epoch 350/400
# 24/24 [==============================] - 4s 160ms/step - d_loss: 0.6734 - g_loss: 0.8799
# Epoch 351/400
# 24/24 [==============================] - 4s 158ms/step - d_loss: 0.6744 - g_loss: 0.8797
# Epoch 352/400
# 24/24 [==============================] - 4s 154ms/step - d_loss: 0.6750 - g_loss: 0.8774
# Epoch 353/400
# 24/24 [==============================] - 4s 154ms/step - d_loss: 0.6731 - g_loss: 0.8760
# Epoch 354/400
# 24/24 [==============================] - 4s 154ms/step - d_loss: 0.6723 - g_loss: 0.8763
# Epoch 355/400
# 24/24 [==============================] - 4s 154ms/step - d_loss: 0.6739 - g_loss: 0.8778
# Epoch 356/400
# 24/24 [==============================] - 4s 153ms/step - d_loss: 0.6719 - g_loss: 0.8785
# Epoch 357/400
# 24/24 [==============================] - 4s 153ms/step - d_loss: 0.6743 - g_loss: 0.8794
# Epoch 358/400
# 24/24 [==============================] - 4s 155ms/step - d_loss: 0.6728 - g_loss: 0.8790
# Epoch 359/400
# 24/24 [==============================] - 4s 154ms/step - d_loss: 0.6723 - g_loss: 0.8767
# Epoch 360/400
# 24/24 [==============================] - 4s 162ms/step - d_loss: 0.6739 - g_loss: 0.8732
# Epoch 361/400
# 24/24 [==============================] - 4s 161ms/step - d_loss: 0.6720 - g_loss: 0.8691
# Epoch 362/400
# 24/24 [==============================] - 4s 156ms/step - d_loss: 0.6739 - g_loss: 0.8658
# Epoch 363/400
# 24/24 [==============================] - 4s 158ms/step - d_loss: 0.6739 - g_loss: 0.8629
# Epoch 364/400
# 24/24 [==============================] - 4s 157ms/step - d_loss: 0.6748 - g_loss: 0.8612
# Epoch 365/400
# 24/24 [==============================] - 4s 156ms/step - d_loss: 0.6731 - g_loss: 0.8645
# Epoch 366/400
# 24/24 [==============================] - 4s 154ms/step - d_loss: 0.6712 - g_loss: 0.8698
# Epoch 367/400
# 24/24 [==============================] - 4s 152ms/step - d_loss: 0.6721 - g_loss: 0.8778
# Epoch 368/400
# 24/24 [==============================] - 4s 152ms/step - d_loss: 0.6725 - g_loss: 0.8837
# Epoch 369/400
# 24/24 [==============================] - 4s 153ms/step - d_loss: 0.6773 - g_loss: 0.8843
# Epoch 370/400
# 24/24 [==============================] - 4s 153ms/step - d_loss: 0.6712 - g_loss: 0.8807
# Epoch 371/400
# 24/24 [==============================] - 4s 154ms/step - d_loss: 0.6758 - g_loss: 0.8750
# Epoch 372/400
# 24/24 [==============================] - 4s 153ms/step - d_loss: 0.6763 - g_loss: 0.8675
# Epoch 373/400
# 24/24 [==============================] - 4s 155ms/step - d_loss: 0.6728 - g_loss: 0.8651
# Epoch 374/400
# 24/24 [==============================] - 4s 158ms/step - d_loss: 0.6767 - g_loss: 0.8711
# Epoch 375/400
# 24/24 [==============================] - 4s 161ms/step - d_loss: 0.6779 - g_loss: 0.8829
# Epoch 376/400
# 24/24 [==============================] - 4s 160ms/step - d_loss: 0.6726 - g_loss: 0.8980
# Epoch 377/400
# 24/24 [==============================] - 4s 157ms/step - d_loss: 0.6749 - g_loss: 0.9113
# Epoch 378/400
# 24/24 [==============================] - 4s 158ms/step - d_loss: 0.6738 - g_loss: 0.9161
# Epoch 379/400
# 24/24 [==============================] - 4s 157ms/step - d_loss: 0.6744 - g_loss: 0.9066
# Epoch 380/400
# 24/24 [==============================] - 4s 155ms/step - d_loss: 0.6789 - g_loss: 0.8942
# Epoch 381/400
# 24/24 [==============================] - 4s 153ms/step - d_loss: 0.6748 - g_loss: 0.8805
# Epoch 382/400
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6774 - g_loss: 0.8746
# Epoch 383/400
# 24/24 [==============================] - 7s 300ms/step - d_loss: 0.6718 - g_loss: 0.8768
# Epoch 384/400
# 24/24 [==============================] - 6s 255ms/step - d_loss: 0.6736 - g_loss: 0.8856
# Epoch 385/400
# 24/24 [==============================] - 5s 202ms/step - d_loss: 0.6750 - g_loss: 0.8936
# Epoch 386/400
# 24/24 [==============================] - 4s 170ms/step - d_loss: 0.6731 - g_loss: 0.8952
# Epoch 387/400
# 24/24 [==============================] - 4s 161ms/step - d_loss: 0.6763 - g_loss: 0.8922
# Epoch 388/400
# 24/24 [==============================] - 4s 164ms/step - d_loss: 0.6767 - g_loss: 0.8836
# Epoch 389/400
# 24/24 [==============================] - 4s 172ms/step - d_loss: 0.6757 - g_loss: 0.8752
# Epoch 390/400
# 24/24 [==============================] - 4s 159ms/step - d_loss: 0.6772 - g_loss: 0.8698
# Epoch 391/400
# 24/24 [==============================] - 4s 159ms/step - d_loss: 0.6738 - g_loss: 0.8721
# Epoch 392/400
# 24/24 [==============================] - 4s 158ms/step - d_loss: 0.6732 - g_loss: 0.8798
# Epoch 393/400
# 24/24 [==============================] - 4s 157ms/step - d_loss: 0.6752 - g_loss: 0.8875
# Epoch 394/400
# 24/24 [==============================] - 4s 159ms/step - d_loss: 0.6731 - g_loss: 0.8925
# Epoch 395/400
# 24/24 [==============================] - 4s 163ms/step - d_loss: 0.6753 - g_loss: 0.8926
# Epoch 396/400
# 24/24 [==============================] - 4s 163ms/step - d_loss: 0.6749 - g_loss: 0.8891
# Epoch 397/400
# 24/24 [==============================] - 4s 168ms/step - d_loss: 0.6696 - g_loss: 0.8843
# Epoch 398/400
# 24/24 [==============================] - 4s 161ms/step - d_loss: 0.6722 - g_loss: 0.8807
# Epoch 399/400
# 24/24 [==============================] - 4s 162ms/step - d_loss: 0.6744 - g_loss: 0.8783
# Epoch 400/400
# 24/24 [==============================] - 4s 161ms/step - d_loss: 0.6709 - g_loss: 0.8782

# %%
scenario_size = 30
normal_noise = tf.random.normal((scenario_size, batch_size, 1))
n = [np.random.normal() for _ in range(scenario_size)]
series = np.multiply(generator.predict(normal_noise), max)
resolution = 100
ticks = []
for i in range(resolution):
    if i%4 == 0:
        ticks.append(i)


probabilities = []
ranges = np.linspace(-3.5, 3.5, 8)
intervals = np.linspace(-3, 3, 7)
probs = [stats.norm.cdf(i) for i in n]
prob_ranges = {intervals[i]: [stats.norm.cdf(ranges[i]), stats.norm.cdf(ranges[i+1])] for i in range(len(intervals))}
for i in probs:
    for key in intervals:
        if prob_ranges[key][0]<= i <=prob_ranges[key][1]:
            probabilities.append(prob_ranges[key][1]-prob_ranges[key][0])
            break
scenarios = {'probs': probabilities}
for j in range(resolution):
    scenarios[j] = []
for i in range(scenario_size):
    s = np.multiply(series[i].reshape([resolution]), max)
    for j in range(resolution):
        scenarios[j].append(s[j])
pd.DataFrame(scenarios).to_csv(f'LoadScenarios-{month_name}-{day_type}.csv')
# Out:
# 1/1 [==============================] - 0s 63ms/step

# %%
ticks = [i for i in range(resolution) if i%4 == 0]

fig, ax = plt.subplots(1, 2, figsize=(15, 4), dpi=200)
for s in series[:5]:
    ax[0].plot(range(resolution), s.reshape([resolution]), linewidth=1)
ax[0].set_xlabel('Timestamp (15 min)')
ax[0].set_ylabel('Generated Power Consumption')
ax[0].set_xticks(ticks, ticks)
ax[0].grid(color='#666362', linestyle='-', linewidth=0.1)

if day_type == 'w':
    ax[1].plot(my_data[[c for c in my_data.columns if 'weekday' in c][:5]], linewidth=1)
else:
    ax[1].plot(my_data[[c for c in my_data.columns if 'weekend' in c][:5]], linewidth=1)
ax[1].set_xlabel('Timestamp (15 min)')
ax[1].set_ylabel('Historical Power Consumption')
ax[1].set_xticks(ticks, ticks)
ax[1].grid(color='#666362', linestyle='-', linewidth=0.1)
plt.subplots_adjust(wspace=0.1)

plt.savefig(f'IMG/{month_name}-{day_type}.jpg', bbox_inches='tight')

# %% [markdown]
# ### Save models

# %%
generator.save(f'HarrisCounty/GAN Models/generator-{month_name}-{day_type}.h5')
discriminator.save(f'HarrisCounty/GAN Models/discriminator-{month_name}-{day_type}.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
plt.figure(figsize=(7, 3), dpi=300)
plt.plot(hist.history['d_loss'], label='Generator Loss')
plt.plot(hist.history['g_loss'], label='Discriminator Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss Value')
plt.legend()
plt.savefig(f'IMG/{month_name}-{day_type}-loss.jpg', bbox_inches='tight')

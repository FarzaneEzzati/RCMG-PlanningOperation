# %%
import tensorflow as tf
from keras import layers, Model
import numpy as np
import datetime
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
from keras.callbacks import Callback
from keras.utils import array_to_img
from keras import Sequential
from keras.layers import Conv2D, Dense, Flatten, Reshape, LeakyReLU, Dropout, UpSampling1D
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from keras.models import Model

gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.reset_memory_stats(gpu, True)
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('ignore')

c = pd.read_csv('../../../Visualizations/color.csv')['color']

# %%
month_name='NovDec'
day_type = 'w'
my_data = pd.read_csv(f'ForGAN/{month_name}.csv')
ds = []
if day_type == 'w':
    for c in my_data.columns:
        if 'weekday' in c:
            last = my_data[c].values[-1]
            ds.append(np.concatenate([my_data[c].values, [last, last, last, last]]).reshape([1, 100]))
else:
    for c in my_data.columns:
        if 'weekend' in c:
            last = my_data[c].values[-1]
            ds.append(np.concatenate([my_data[c].values, [last, last, last, last]]).reshape([1, 100]))

max = np.max(ds)
ds = np.divide(ds, max)

# %% [markdown]
# ### Prepare data to feed into GAN

# %%
ds = tf.data.Dataset.from_tensor_slices(ds)
batch_size = 12
ds = ds.cache()
ds = ds.shuffle(1000)
ds = ds.batch(batch_size)
ds = ds.prefetch(64)

# %% [markdown]
# ## Generator

# %%
g_relu = 0.1
def build_generator():
    model = Sequential()

    model.add(Dense(1*100*batch_size, input_dim=batch_size))
    model.add(LeakyReLU(g_relu))
    model.add(Reshape((1,100, batch_size)))

    #model.add(UpSamplingD())
    model.add(Conv2D(batch_size, 3, padding='same'))
    model.add(LeakyReLU(g_relu))

    model.add(Conv2D(batch_size, 3, padding='same'))
    model.add(LeakyReLU(g_relu))

    model.add(Conv2D(batch_size, 3, padding='same'))
    model.add(LeakyReLU(g_relu))

    model.add(Conv2D(batch_size, 3, padding='same'))
    model.add(LeakyReLU(g_relu))

    model.add(Conv2D(1, 5, padding='same', activation='sigmoid'))
    return model
generator = build_generator()
generator.summary()
# series = generator.predict(np.random.randn(4, 6, 1))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1200)              15600
#
#  leaky_re_lu (LeakyReLU)     (None, 1200)              0
#
#  reshape (Reshape)           (None, 1, 100, 12)        0
#
#  conv2d (Conv2D)             (None, 1, 100, 12)        1308
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 1, 100, 12)        0
#
#  conv2d_1 (Conv2D)           (None, 1, 100, 12)        1308
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 1, 100, 12)        0
#
#  conv2d_2 (Conv2D)           (None, 1, 100, 12)        1308
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 1, 100, 12)        0
#
#  conv2d_3 (Conv2D)           (None, 1, 100, 12)        1308
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 1, 100, 12)        0
#
#  conv2d_4 (Conv2D)           (None, 1, 100, 1)         301
#
# =================================================================
# Total params: 21,133
# Trainable params: 21,133
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Discriminator

# %%
d_relu = 0.1
d_dropout = 0.2
def build_discriminator():
    model = Sequential()

    model.add(Dense(200, input_shape=(1, 100, 1)))
    model.add(LeakyReLU(d_relu))
    model.add(Dropout(d_dropout))

    model.add(Dense(150))
    model.add(LeakyReLU(d_relu))
    model.add(Dropout(d_dropout))

    model.add(Flatten())
    model.add(Dropout(d_dropout))
    model.add(Dense(1, activation='sigmoid'))
    # 1: fake series, 0: real series

    return model
discriminator = build_discriminator()
discriminator.summary()
# Single prediction needs np.expand_dims(series[0], 0)
# discriminator.predict(np.expand_dims(series[0], 0))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1, 100, 200)       400
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 1, 100, 200)       0
#
#  dropout (Dropout)           (None, 1, 100, 200)       0
#
#  dense_2 (Dense)             (None, 1, 100, 150)       30150
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 1, 100, 150)       0
#
#  dropout_1 (Dropout)         (None, 1, 100, 150)       0
#
#  flatten (Flatten)           (None, 15000)             0
#
#  dropout_2 (Dropout)         (None, 15000)             0
#
#  dense_3 (Dense)             (None, 1)                 15001
#
# =================================================================
# Total params: 45,551
# Trainable params: 45,551
# Non-trainable params: 0
# _________________________________________________________________

# %%
g_a, d_a = 0.0001, 0.00001
g_opt = Adam(learning_rate=g_a)
d_opt = Adam(learning_rate=d_a)  # Does not learn too fast
g_loss = BinaryCrossentropy()
d_loss = BinaryCrossentropy()
class LoadGAN(Model):
    def __init__(self, generator, discriminator, *args, **kwargs):
        # pass through args and kwargs to base class
        super().__init__(*args, **kwargs)
        # Create attributes for gen and disc
        self.generator = generator
        self.discriminator = discriminator

    def compilee(self, g_opt, d_opt, g_loss, d_loss, *args, **kwargs):
        # Compile with base class
        super().compile(*args, **kwargs)

        self.g_opt = g_opt
        self.d_opt = d_opt
        self.g_loss = g_loss
        self.d_loss = d_loss

    def train_step(self, batch):
        real_series = batch
        fake_series = self.generator(tf.random.normal((batch_size, batch_size, 1)), training=False)

        # train the discriminator
        with tf.GradientTape() as d_tape:
            # pass the real and fake images
            yhat_real = self.discriminator(real_series, training=True)
            yhat_fake = self.discriminator(fake_series, training=True)
            yhat_realfake = tf.concat([yhat_real, yhat_fake], axis=0)

            # create labels for real and fake series
            y_realfake = tf.concat([tf.zeros_like(yhat_real), tf.ones_like(yhat_fake)], axis=0)


            # pass through and add some noise to the outputs
            noise_real = 0.15*tf.random.uniform(tf.shape(yhat_real))
            noise_fake = 0.15*tf.random.uniform(tf.shape(yhat_fake))
            y_realfake += tf.concat([noise_real, noise_fake], axis=0)

            # calculate the loss
            total_d_loss = self.d_loss(y_realfake, yhat_realfake)

        # apply backpropagation
        dgrad = d_tape.gradient(total_d_loss, self.discriminator.trainable_variables)
        self.d_opt.apply_gradients(zip(dgrad, self.discriminator.trainable_variables))

        # Generator training
        with tf.GradientTape() as g_tape:
            # generate same new images
            gen_series = self.generator(tf.random.normal((batch_size, batch_size, 1)), training=True)

            # create the predicted labels
            predicted_labels = self.discriminator(gen_series, training=False)

            # calculate loss
            total_g_loss = self.g_loss(tf.zeros_like(predicted_labels), predicted_labels)

        # apply backpropagation
        ggrad = g_tape.gradient(total_g_loss, self.generator.trainable_variables)
        self.g_opt.apply_gradients(zip(ggrad, self.generator.trainable_variables))

        return {"d_loss":total_d_loss, "g_loss":total_g_loss}
loadgan = LoadGAN(generator, discriminator)
loadgan.compilee(g_opt, d_opt, g_loss, d_loss)

# %% [markdown]
# #### Call Back

# %%
class ModelMonitor(Callback):
    def __init__(self, num_img=3, latent_dim=batch_size):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vector = tf.random.uniform((self.num_img, self.latent_dim, 1))
        generated_series = self.model.generator(random_latent_vector)
        generated_series *= max
        generated_series.numpy()
        for i in range(self.num_img):
            serie = array_to_img(generated_series[i])

# %% [markdown]
# #### Train

# %%
hist = loadgan.fit(ds, epochs=600, callbacks=[ModelMonitor()])
# Out:
# Epoch 1/600
# 24/24 [==============================] - 6s 238ms/step - d_loss: 0.7016 - g_loss: 0.6490
# Epoch 2/600
# 24/24 [==============================] - 6s 239ms/step - d_loss: 0.6990 - g_loss: 0.6663
# Epoch 3/600
# 24/24 [==============================] - 5s 206ms/step - d_loss: 0.6941 - g_loss: 0.6820
# Epoch 4/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6932 - g_loss: 0.6961
# Epoch 5/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6886 - g_loss: 0.7082
# Epoch 6/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6860 - g_loss: 0.7194
# Epoch 7/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6822 - g_loss: 0.7294
# Epoch 8/600
# 24/24 [==============================] - 4s 179ms/step - d_loss: 0.6800 - g_loss: 0.7365
# Epoch 9/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6782 - g_loss: 0.7405
# Epoch 10/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6796 - g_loss: 0.7397
# Epoch 11/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6802 - g_loss: 0.7301
# Epoch 12/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6836 - g_loss: 0.7124
# Epoch 13/600
# 24/24 [==============================] - 5s 194ms/step - d_loss: 0.6860 - g_loss: 0.6904
# Epoch 14/600
# 24/24 [==============================] - 5s 196ms/step - d_loss: 0.6844 - g_loss: 0.6668
# Epoch 15/600
# 24/24 [==============================] - 4s 179ms/step - d_loss: 0.6925 - g_loss: 0.6435
# Epoch 16/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6965 - g_loss: 0.6283
# Epoch 17/600
# 24/24 [==============================] - 4s 178ms/step - d_loss: 0.6998 - g_loss: 0.6224
# Epoch 18/600
# 24/24 [==============================] - 4s 180ms/step - d_loss: 0.7030 - g_loss: 0.6214
# Epoch 19/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.7029 - g_loss: 0.6249
# Epoch 20/600
# 24/24 [==============================] - 4s 180ms/step - d_loss: 0.7045 - g_loss: 0.6316
# Epoch 21/600
# 24/24 [==============================] - 4s 178ms/step - d_loss: 0.7027 - g_loss: 0.6429
# Epoch 22/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.7012 - g_loss: 0.6579
# Epoch 23/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6979 - g_loss: 0.6776
# Epoch 24/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6947 - g_loss: 0.6990
# Epoch 25/600
# 24/24 [==============================] - 4s 175ms/step - d_loss: 0.6911 - g_loss: 0.7145
# Epoch 26/600
# 24/24 [==============================] - 4s 178ms/step - d_loss: 0.6869 - g_loss: 0.7257
# Epoch 27/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6819 - g_loss: 0.7321
# Epoch 28/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6863 - g_loss: 0.7334
# Epoch 29/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6819 - g_loss: 0.7788
# Epoch 30/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6632 - g_loss: 0.8767
# Epoch 31/600
# 24/24 [==============================] - 5s 187ms/step - d_loss: 0.6631 - g_loss: 0.9231
# Epoch 32/600
# 24/24 [==============================] - 4s 180ms/step - d_loss: 0.6974 - g_loss: 0.8540
# Epoch 33/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.7107 - g_loss: 0.7870
# Epoch 34/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6963 - g_loss: 0.7678
# Epoch 35/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6767 - g_loss: 0.7611
# Epoch 36/600
# 24/24 [==============================] - 4s 177ms/step - d_loss: 0.6602 - g_loss: 0.7541
# Epoch 37/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6490 - g_loss: 0.7486
# Epoch 38/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6463 - g_loss: 0.7359
# Epoch 39/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6783 - g_loss: 0.6710
# Epoch 40/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.7211 - g_loss: 0.6243
# Epoch 41/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6991 - g_loss: 0.7014
# Epoch 42/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6744 - g_loss: 0.8036
# Epoch 43/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6551 - g_loss: 0.8922
# Epoch 44/600
# 24/24 [==============================] - 5s 200ms/step - d_loss: 0.6445 - g_loss: 0.9573
# Epoch 45/600
# 24/24 [==============================] - 5s 204ms/step - d_loss: 0.6416 - g_loss: 0.9923
# Epoch 46/600
# 24/24 [==============================] - 5s 198ms/step - d_loss: 0.6519 - g_loss: 0.9904
# Epoch 47/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6650 - g_loss: 0.9464
# Epoch 48/600
# 24/24 [==============================] - 4s 180ms/step - d_loss: 0.6809 - g_loss: 0.8853
# Epoch 49/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6881 - g_loss: 0.8465
# Epoch 50/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6856 - g_loss: 0.8250
# Epoch 51/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6799 - g_loss: 0.8056
# Epoch 52/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6784 - g_loss: 0.7870
# Epoch 53/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6809 - g_loss: 0.7726
# Epoch 54/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6800 - g_loss: 0.7686
# Epoch 55/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6807 - g_loss: 0.7721
# Epoch 56/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6808 - g_loss: 0.7777
# Epoch 57/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6766 - g_loss: 0.7855
# Epoch 58/600
# 24/24 [==============================] - 4s 174ms/step - d_loss: 0.6770 - g_loss: 0.7963
# Epoch 59/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6777 - g_loss: 0.8054
# Epoch 60/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6763 - g_loss: 0.8130
# Epoch 61/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6774 - g_loss: 0.8188
# Epoch 62/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6742 - g_loss: 0.8248
# Epoch 63/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6753 - g_loss: 0.8302
# Epoch 64/600
# 24/24 [==============================] - 5s 187ms/step - d_loss: 0.6729 - g_loss: 0.8350
# Epoch 65/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6742 - g_loss: 0.8409
# Epoch 66/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6755 - g_loss: 0.8460
# Epoch 67/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6763 - g_loss: 0.8486
# Epoch 68/600
# 24/24 [==============================] - 5s 192ms/step - d_loss: 0.6781 - g_loss: 0.8519
# Epoch 69/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6734 - g_loss: 0.8530
# Epoch 70/600
# 24/24 [==============================] - 5s 195ms/step - d_loss: 0.6759 - g_loss: 0.8541
# Epoch 71/600
# 24/24 [==============================] - 5s 199ms/step - d_loss: 0.6790 - g_loss: 0.8567
# Epoch 72/600
# 24/24 [==============================] - 5s 191ms/step - d_loss: 0.6771 - g_loss: 0.8579
# Epoch 73/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6787 - g_loss: 0.8583
# Epoch 74/600
# 24/24 [==============================] - 4s 180ms/step - d_loss: 0.6798 - g_loss: 0.8593
# Epoch 75/600
# 24/24 [==============================] - 4s 179ms/step - d_loss: 0.6793 - g_loss: 0.8585
# Epoch 76/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6794 - g_loss: 0.8582
# Epoch 77/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6807 - g_loss: 0.8598
# Epoch 78/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6829 - g_loss: 0.8611
# Epoch 79/600
# 24/24 [==============================] - 4s 180ms/step - d_loss: 0.6818 - g_loss: 0.8615
# Epoch 80/600
# 24/24 [==============================] - 4s 175ms/step - d_loss: 0.6828 - g_loss: 0.8611
# Epoch 81/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6822 - g_loss: 0.8596
# Epoch 82/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6806 - g_loss: 0.8608
# Epoch 83/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6826 - g_loss: 0.8600
# Epoch 84/600
# 24/24 [==============================] - 4s 174ms/step - d_loss: 0.6819 - g_loss: 0.8598
# Epoch 85/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6843 - g_loss: 0.8595
# Epoch 86/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6818 - g_loss: 0.8596
# Epoch 87/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6796 - g_loss: 0.8611
# Epoch 88/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6825 - g_loss: 0.8622
# Epoch 89/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6807 - g_loss: 0.8626
# Epoch 90/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6798 - g_loss: 0.8627
# Epoch 91/600
# 24/24 [==============================] - 5s 190ms/step - d_loss: 0.6793 - g_loss: 0.8610
# Epoch 92/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6793 - g_loss: 0.8600
# Epoch 93/600
# 24/24 [==============================] - 5s 192ms/step - d_loss: 0.6792 - g_loss: 0.8590
# Epoch 94/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6796 - g_loss: 0.8596
# Epoch 95/600
# 24/24 [==============================] - 5s 197ms/step - d_loss: 0.6789 - g_loss: 0.8592
# Epoch 96/600
# 24/24 [==============================] - 5s 189ms/step - d_loss: 0.6784 - g_loss: 0.8572
# Epoch 97/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6780 - g_loss: 0.8556
# Epoch 98/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6799 - g_loss: 0.8536
# Epoch 99/600
# 24/24 [==============================] - 5s 189ms/step - d_loss: 0.6785 - g_loss: 0.8503
# Epoch 100/600
# 24/24 [==============================] - 5s 199ms/step - d_loss: 0.6780 - g_loss: 0.8474
# Epoch 101/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6798 - g_loss: 0.8456
# Epoch 102/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6783 - g_loss: 0.8455
# Epoch 103/600
# 24/24 [==============================] - 5s 212ms/step - d_loss: 0.6794 - g_loss: 0.8454
# Epoch 104/600
# 24/24 [==============================] - 5s 199ms/step - d_loss: 0.6805 - g_loss: 0.8455
# Epoch 105/600
# 24/24 [==============================] - 5s 205ms/step - d_loss: 0.6790 - g_loss: 0.8444
# Epoch 106/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6784 - g_loss: 0.8430
# Epoch 107/600
# 24/24 [==============================] - 4s 165ms/step - d_loss: 0.6787 - g_loss: 0.8421
# Epoch 108/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6806 - g_loss: 0.8416
# Epoch 109/600
# 24/24 [==============================] - 4s 180ms/step - d_loss: 0.6792 - g_loss: 0.8416
# Epoch 110/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6803 - g_loss: 0.8418
# Epoch 111/600
# 24/24 [==============================] - 5s 187ms/step - d_loss: 0.6795 - g_loss: 0.8418
# Epoch 112/600
# 24/24 [==============================] - 5s 187ms/step - d_loss: 0.6819 - g_loss: 0.8418
# Epoch 113/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6814 - g_loss: 0.8414
# Epoch 114/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6801 - g_loss: 0.8414
# Epoch 115/600
# 24/24 [==============================] - 5s 190ms/step - d_loss: 0.6820 - g_loss: 0.8414
# Epoch 116/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6780 - g_loss: 0.8407
# Epoch 117/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6789 - g_loss: 0.8427
# Epoch 118/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6816 - g_loss: 0.8439
# Epoch 119/600
# 24/24 [==============================] - 5s 189ms/step - d_loss: 0.6814 - g_loss: 0.8429
# Epoch 120/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6816 - g_loss: 0.8415
# Epoch 121/600
# 24/24 [==============================] - 5s 190ms/step - d_loss: 0.6811 - g_loss: 0.8415
# Epoch 122/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6819 - g_loss: 0.8419
# Epoch 123/600
# 24/24 [==============================] - 5s 189ms/step - d_loss: 0.6801 - g_loss: 0.8412
# Epoch 124/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6803 - g_loss: 0.8423
# Epoch 125/600
# 24/24 [==============================] - 5s 207ms/step - d_loss: 0.6816 - g_loss: 0.8440
# Epoch 126/600
# 24/24 [==============================] - 5s 216ms/step - d_loss: 0.6800 - g_loss: 0.8449
# Epoch 127/600
# 24/24 [==============================] - 5s 221ms/step - d_loss: 0.6822 - g_loss: 0.8451
# Epoch 128/600
# 24/24 [==============================] - 5s 216ms/step - d_loss: 0.6791 - g_loss: 0.8442
# Epoch 129/600
# 24/24 [==============================] - 5s 215ms/step - d_loss: 0.6808 - g_loss: 0.8435
# Epoch 130/600
# 24/24 [==============================] - 5s 207ms/step - d_loss: 0.6814 - g_loss: 0.8409
# Epoch 131/600
# 24/24 [==============================] - 5s 219ms/step - d_loss: 0.6827 - g_loss: 0.8391
# Epoch 132/600
# 24/24 [==============================] - 5s 217ms/step - d_loss: 0.6831 - g_loss: 0.8379
# Epoch 133/600
# 24/24 [==============================] - 5s 206ms/step - d_loss: 0.6821 - g_loss: 0.8377
# Epoch 134/600
# 24/24 [==============================] - 5s 214ms/step - d_loss: 0.6811 - g_loss: 0.8383
# Epoch 135/600
# 24/24 [==============================] - 5s 209ms/step - d_loss: 0.6806 - g_loss: 0.8392
# Epoch 136/600
# 24/24 [==============================] - 5s 221ms/step - d_loss: 0.6803 - g_loss: 0.8400
# Epoch 137/600
# 24/24 [==============================] - 5s 216ms/step - d_loss: 0.6819 - g_loss: 0.8407
# Epoch 138/600
# 24/24 [==============================] - 5s 215ms/step - d_loss: 0.6816 - g_loss: 0.8409
# Epoch 139/600
# 24/24 [==============================] - 5s 224ms/step - d_loss: 0.6803 - g_loss: 0.8428
# Epoch 140/600
# 24/24 [==============================] - 5s 219ms/step - d_loss: 0.6792 - g_loss: 0.8446
# Epoch 141/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6798 - g_loss: 0.8464
# Epoch 142/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6813 - g_loss: 0.8482
# Epoch 143/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6819 - g_loss: 0.8485
# Epoch 144/600
# 24/24 [==============================] - 4s 176ms/step - d_loss: 0.6816 - g_loss: 0.8488
# Epoch 145/600
# 24/24 [==============================] - 4s 170ms/step - d_loss: 0.6774 - g_loss: 0.8523
# Epoch 146/600
# 24/24 [==============================] - 4s 171ms/step - d_loss: 0.6799 - g_loss: 0.8561
# Epoch 147/600
# 24/24 [==============================] - 4s 175ms/step - d_loss: 0.6788 - g_loss: 0.8598
# Epoch 148/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6796 - g_loss: 0.8620
# Epoch 149/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6814 - g_loss: 0.8630
# Epoch 150/600
# 24/24 [==============================] - 5s 189ms/step - d_loss: 0.6812 - g_loss: 0.8626
# Epoch 151/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6795 - g_loss: 0.8599
# Epoch 152/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6797 - g_loss: 0.8569
# Epoch 153/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6791 - g_loss: 0.8547
# Epoch 154/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6796 - g_loss: 0.8540
# Epoch 155/600
# 24/24 [==============================] - 5s 194ms/step - d_loss: 0.6788 - g_loss: 0.8526
# Epoch 156/600
# 24/24 [==============================] - 5s 205ms/step - d_loss: 0.6809 - g_loss: 0.8509
# Epoch 157/600
# 24/24 [==============================] - 5s 186ms/step - d_loss: 0.6814 - g_loss: 0.8479
# Epoch 158/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6794 - g_loss: 0.8422
# Epoch 159/600
# 24/24 [==============================] - 5s 191ms/step - d_loss: 0.6812 - g_loss: 0.8388
# Epoch 160/600
# 24/24 [==============================] - 5s 196ms/step - d_loss: 0.6796 - g_loss: 0.8384
# Epoch 161/600
# 24/24 [==============================] - 5s 194ms/step - d_loss: 0.6812 - g_loss: 0.8372
# Epoch 162/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6804 - g_loss: 0.8346
# Epoch 163/600
# 24/24 [==============================] - 4s 179ms/step - d_loss: 0.6809 - g_loss: 0.8336
# Epoch 164/600
# 24/24 [==============================] - 4s 174ms/step - d_loss: 0.6819 - g_loss: 0.8319
# Epoch 165/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6821 - g_loss: 0.8307
# Epoch 166/600
# 24/24 [==============================] - 5s 198ms/step - d_loss: 0.6815 - g_loss: 0.8307
# Epoch 167/600
# 24/24 [==============================] - 5s 203ms/step - d_loss: 0.6813 - g_loss: 0.8335
# Epoch 168/600
# 24/24 [==============================] - 5s 192ms/step - d_loss: 0.6820 - g_loss: 0.8344
# Epoch 169/600
# 24/24 [==============================] - 5s 190ms/step - d_loss: 0.6806 - g_loss: 0.8378
# Epoch 170/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6835 - g_loss: 0.8422
# Epoch 171/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6828 - g_loss: 0.8423
# Epoch 172/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6830 - g_loss: 0.8420
# Epoch 173/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6819 - g_loss: 0.8432
# Epoch 174/600
# 24/24 [==============================] - 5s 207ms/step - d_loss: 0.6808 - g_loss: 0.8455
# Epoch 175/600
# 24/24 [==============================] - 5s 191ms/step - d_loss: 0.6829 - g_loss: 0.8462
# Epoch 176/600
# 24/24 [==============================] - 4s 174ms/step - d_loss: 0.6803 - g_loss: 0.8459
# Epoch 177/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6832 - g_loss: 0.8471
# Epoch 178/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6813 - g_loss: 0.8473
# Epoch 179/600
# 24/24 [==============================] - 4s 177ms/step - d_loss: 0.6830 - g_loss: 0.8460
# Epoch 180/600
# 24/24 [==============================] - 5s 191ms/step - d_loss: 0.6806 - g_loss: 0.8447
# Epoch 181/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6821 - g_loss: 0.8437
# Epoch 182/600
# 24/24 [==============================] - 5s 187ms/step - d_loss: 0.6788 - g_loss: 0.8447
# Epoch 183/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6815 - g_loss: 0.8465
# Epoch 184/600
# 24/24 [==============================] - 4s 188ms/step - d_loss: 0.6789 - g_loss: 0.8470
# Epoch 185/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6793 - g_loss: 0.8491
# Epoch 186/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6813 - g_loss: 0.8476
# Epoch 187/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6768 - g_loss: 0.8473
# Epoch 188/600
# 24/24 [==============================] - 5s 196ms/step - d_loss: 0.6797 - g_loss: 0.8486
# Epoch 189/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6789 - g_loss: 0.8482
# Epoch 190/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6796 - g_loss: 0.8481
# Epoch 191/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6775 - g_loss: 0.8484
# Epoch 192/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6787 - g_loss: 0.8485
# Epoch 193/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6781 - g_loss: 0.8473
# Epoch 194/600
# 24/24 [==============================] - 4s 179ms/step - d_loss: 0.6786 - g_loss: 0.8475
# Epoch 195/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6781 - g_loss: 0.8466
# Epoch 196/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6810 - g_loss: 0.8452
# Epoch 197/600
# 24/24 [==============================] - 5s 190ms/step - d_loss: 0.6789 - g_loss: 0.8433
# Epoch 198/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6813 - g_loss: 0.8424
# Epoch 199/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6799 - g_loss: 0.8421
# Epoch 200/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6788 - g_loss: 0.8429
# Epoch 201/600
# 24/24 [==============================] - 4s 179ms/step - d_loss: 0.6804 - g_loss: 0.8433
# Epoch 202/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6784 - g_loss: 0.8421
# Epoch 203/600
# 24/24 [==============================] - 5s 194ms/step - d_loss: 0.6790 - g_loss: 0.8428
# Epoch 204/600
# 24/24 [==============================] - 5s 201ms/step - d_loss: 0.6797 - g_loss: 0.8440
# Epoch 205/600
# 24/24 [==============================] - 5s 213ms/step - d_loss: 0.6792 - g_loss: 0.8440
# Epoch 206/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6801 - g_loss: 0.8438
# Epoch 207/600
# 24/24 [==============================] - 4s 178ms/step - d_loss: 0.6806 - g_loss: 0.8451
# Epoch 208/600
# 24/24 [==============================] - 5s 210ms/step - d_loss: 0.6810 - g_loss: 0.8441
# Epoch 209/600
# 24/24 [==============================] - 5s 216ms/step - d_loss: 0.6822 - g_loss: 0.8424
# Epoch 210/600
# 24/24 [==============================] - 5s 218ms/step - d_loss: 0.6807 - g_loss: 0.8415
# Epoch 211/600
# 24/24 [==============================] - 5s 214ms/step - d_loss: 0.6809 - g_loss: 0.8405
# Epoch 212/600
# 24/24 [==============================] - 5s 220ms/step - d_loss: 0.6805 - g_loss: 0.8394
# Epoch 213/600
# 24/24 [==============================] - 5s 215ms/step - d_loss: 0.6785 - g_loss: 0.8392
# Epoch 214/600
# 24/24 [==============================] - 6s 242ms/step - d_loss: 0.6806 - g_loss: 0.8400
# Epoch 215/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6793 - g_loss: 0.8395
# Epoch 216/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6802 - g_loss: 0.8393
# Epoch 217/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6795 - g_loss: 0.8389
# Epoch 218/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6802 - g_loss: 0.8403
# Epoch 219/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6791 - g_loss: 0.8415
# Epoch 220/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6806 - g_loss: 0.8421
# Epoch 221/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6786 - g_loss: 0.8423
# Epoch 222/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6790 - g_loss: 0.8429
# Epoch 223/600
# 24/24 [==============================] - 4s 180ms/step - d_loss: 0.6787 - g_loss: 0.8453
# Epoch 224/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6804 - g_loss: 0.8468
# Epoch 225/600
# 24/24 [==============================] - 4s 179ms/step - d_loss: 0.6810 - g_loss: 0.8457
# Epoch 226/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6808 - g_loss: 0.8450
# Epoch 227/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6797 - g_loss: 0.8444
# Epoch 228/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6821 - g_loss: 0.8440
# Epoch 229/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6800 - g_loss: 0.8433
# Epoch 230/600
# 24/24 [==============================] - 5s 189ms/step - d_loss: 0.6783 - g_loss: 0.8439
# Epoch 231/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6791 - g_loss: 0.8438
# Epoch 232/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6804 - g_loss: 0.8421
# Epoch 233/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6779 - g_loss: 0.8417
# Epoch 234/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6779 - g_loss: 0.8430
# Epoch 235/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6772 - g_loss: 0.8437
# Epoch 236/600
# 24/24 [==============================] - 4s 178ms/step - d_loss: 0.6809 - g_loss: 0.8437
# Epoch 237/600
# 24/24 [==============================] - 5s 209ms/step - d_loss: 0.6818 - g_loss: 0.8429
# Epoch 238/600
# 24/24 [==============================] - 5s 202ms/step - d_loss: 0.6789 - g_loss: 0.8418
# Epoch 239/600
# 24/24 [==============================] - 5s 195ms/step - d_loss: 0.6782 - g_loss: 0.8425
# Epoch 240/600
# 24/24 [==============================] - 5s 190ms/step - d_loss: 0.6814 - g_loss: 0.8421
# Epoch 241/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6812 - g_loss: 0.8421
# Epoch 242/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6780 - g_loss: 0.8424
# Epoch 243/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6759 - g_loss: 0.8436
# Epoch 244/600
# 24/24 [==============================] - 5s 197ms/step - d_loss: 0.6806 - g_loss: 0.8451
# Epoch 245/600
# 24/24 [==============================] - 5s 191ms/step - d_loss: 0.6785 - g_loss: 0.8436
# Epoch 246/600
# 24/24 [==============================] - 4s 176ms/step - d_loss: 0.6811 - g_loss: 0.8411
# Epoch 247/600
# 24/24 [==============================] - 5s 191ms/step - d_loss: 0.6800 - g_loss: 0.8391
# Epoch 248/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6799 - g_loss: 0.8372
# Epoch 249/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6797 - g_loss: 0.8348
# Epoch 250/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6790 - g_loss: 0.8341
# Epoch 251/600
# 24/24 [==============================] - 4s 179ms/step - d_loss: 0.6797 - g_loss: 0.8353
# Epoch 252/600
# 24/24 [==============================] - 4s 179ms/step - d_loss: 0.6786 - g_loss: 0.8368
# Epoch 253/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6799 - g_loss: 0.8391
# Epoch 254/600
# 24/24 [==============================] - 5s 189ms/step - d_loss: 0.6800 - g_loss: 0.8400
# Epoch 255/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6821 - g_loss: 0.8392
# Epoch 256/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6807 - g_loss: 0.8379
# Epoch 257/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6791 - g_loss: 0.8377
# Epoch 258/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6799 - g_loss: 0.8402
# Epoch 259/600
# 24/24 [==============================] - 4s 178ms/step - d_loss: 0.6795 - g_loss: 0.8411
# Epoch 260/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6801 - g_loss: 0.8413
# Epoch 261/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6809 - g_loss: 0.8421
# Epoch 262/600
# 24/24 [==============================] - 4s 179ms/step - d_loss: 0.6792 - g_loss: 0.8424
# Epoch 263/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6801 - g_loss: 0.8428
# Epoch 264/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6799 - g_loss: 0.8427
# Epoch 265/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6805 - g_loss: 0.8441
# Epoch 266/600
# 24/24 [==============================] - 4s 178ms/step - d_loss: 0.6803 - g_loss: 0.8448
# Epoch 267/600
# 24/24 [==============================] - 4s 178ms/step - d_loss: 0.6790 - g_loss: 0.8450
# Epoch 268/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6797 - g_loss: 0.8458
# Epoch 269/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6801 - g_loss: 0.8456
# Epoch 270/600
# 24/24 [==============================] - 4s 189ms/step - d_loss: 0.6768 - g_loss: 0.8464
# Epoch 271/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6782 - g_loss: 0.8455
# Epoch 272/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6806 - g_loss: 0.8433
# Epoch 273/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6790 - g_loss: 0.8403
# Epoch 274/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6787 - g_loss: 0.8417
# Epoch 275/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6804 - g_loss: 0.8443
# Epoch 276/600
# 24/24 [==============================] - 4s 179ms/step - d_loss: 0.6803 - g_loss: 0.8454
# Epoch 277/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6781 - g_loss: 0.8465
# Epoch 278/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6795 - g_loss: 0.8470
# Epoch 279/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6788 - g_loss: 0.8469
# Epoch 280/600
# 24/24 [==============================] - 4s 180ms/step - d_loss: 0.6801 - g_loss: 0.8452
# Epoch 281/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6798 - g_loss: 0.8432
# Epoch 282/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6819 - g_loss: 0.8399
# Epoch 283/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6792 - g_loss: 0.8381
# Epoch 284/600
# 24/24 [==============================] - 4s 176ms/step - d_loss: 0.6789 - g_loss: 0.8406
# Epoch 285/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6784 - g_loss: 0.8434
# Epoch 286/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6796 - g_loss: 0.8460
# Epoch 287/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6789 - g_loss: 0.8488
# Epoch 288/600
# 24/24 [==============================] - 4s 179ms/step - d_loss: 0.6810 - g_loss: 0.8479
# Epoch 289/600
# 24/24 [==============================] - 5s 198ms/step - d_loss: 0.6815 - g_loss: 0.8452
# Epoch 290/600
# 24/24 [==============================] - 4s 176ms/step - d_loss: 0.6801 - g_loss: 0.8435
# Epoch 291/600
# 24/24 [==============================] - 4s 164ms/step - d_loss: 0.6786 - g_loss: 0.8418
# Epoch 292/600
# 24/24 [==============================] - 5s 199ms/step - d_loss: 0.6818 - g_loss: 0.8404
# Epoch 293/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6803 - g_loss: 0.8390
# Epoch 294/600
# 24/24 [==============================] - 5s 190ms/step - d_loss: 0.6814 - g_loss: 0.8402
# Epoch 295/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6799 - g_loss: 0.8421
# Epoch 296/600
# 24/24 [==============================] - 5s 206ms/step - d_loss: 0.6818 - g_loss: 0.8438
# Epoch 297/600
# 24/24 [==============================] - 5s 190ms/step - d_loss: 0.6800 - g_loss: 0.8437
# Epoch 298/600
# 24/24 [==============================] - 5s 207ms/step - d_loss: 0.6832 - g_loss: 0.8422
# Epoch 299/600
# 24/24 [==============================] - 5s 218ms/step - d_loss: 0.6801 - g_loss: 0.8410
# Epoch 300/600
# 24/24 [==============================] - 5s 191ms/step - d_loss: 0.6802 - g_loss: 0.8426
# Epoch 301/600
# 24/24 [==============================] - 5s 195ms/step - d_loss: 0.6809 - g_loss: 0.8426
# Epoch 302/600
# 24/24 [==============================] - 5s 227ms/step - d_loss: 0.6820 - g_loss: 0.8416
# Epoch 303/600
# 24/24 [==============================] - 5s 211ms/step - d_loss: 0.6791 - g_loss: 0.8414
# Epoch 304/600
# 24/24 [==============================] - 5s 213ms/step - d_loss: 0.6811 - g_loss: 0.8432
# Epoch 305/600
# 24/24 [==============================] - 5s 210ms/step - d_loss: 0.6793 - g_loss: 0.8456
# Epoch 306/600
# 24/24 [==============================] - 5s 206ms/step - d_loss: 0.6813 - g_loss: 0.8458
# Epoch 307/600
# 24/24 [==============================] - 5s 205ms/step - d_loss: 0.6818 - g_loss: 0.8443
# Epoch 308/600
# 24/24 [==============================] - 5s 202ms/step - d_loss: 0.6792 - g_loss: 0.8424
# Epoch 309/600
# 24/24 [==============================] - 5s 203ms/step - d_loss: 0.6791 - g_loss: 0.8419
# Epoch 310/600
# 24/24 [==============================] - 5s 203ms/step - d_loss: 0.6802 - g_loss: 0.8421
# Epoch 311/600
# 24/24 [==============================] - 5s 202ms/step - d_loss: 0.6802 - g_loss: 0.8437
# Epoch 312/600
# 24/24 [==============================] - 5s 203ms/step - d_loss: 0.6807 - g_loss: 0.8443
# Epoch 313/600
# 24/24 [==============================] - 5s 191ms/step - d_loss: 0.6801 - g_loss: 0.8424
# Epoch 314/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6789 - g_loss: 0.8424
# Epoch 315/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6833 - g_loss: 0.8412
# Epoch 316/600
# 24/24 [==============================] - 4s 156ms/step - d_loss: 0.6786 - g_loss: 0.8398
# Epoch 317/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6788 - g_loss: 0.8400
# Epoch 318/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6784 - g_loss: 0.8402
# Epoch 319/600
# 24/24 [==============================] - 4s 171ms/step - d_loss: 0.6792 - g_loss: 0.8410
# Epoch 320/600
# 24/24 [==============================] - 4s 180ms/step - d_loss: 0.6795 - g_loss: 0.8405
# Epoch 321/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6797 - g_loss: 0.8402
# Epoch 322/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6792 - g_loss: 0.8429
# Epoch 323/600
# 24/24 [==============================] - 4s 155ms/step - d_loss: 0.6808 - g_loss: 0.8432
# Epoch 324/600
# 24/24 [==============================] - 5s 192ms/step - d_loss: 0.6810 - g_loss: 0.8416
# Epoch 325/600
# 24/24 [==============================] - 4s 163ms/step - d_loss: 0.6797 - g_loss: 0.8405
# Epoch 326/600
# 24/24 [==============================] - 4s 179ms/step - d_loss: 0.6802 - g_loss: 0.8389
# Epoch 327/600
# 24/24 [==============================] - 3s 140ms/step - d_loss: 0.6805 - g_loss: 0.8382
# Epoch 328/600
# 24/24 [==============================] - 3s 145ms/step - d_loss: 0.6793 - g_loss: 0.8394
# Epoch 329/600
# 24/24 [==============================] - 5s 192ms/step - d_loss: 0.6797 - g_loss: 0.8403
# Epoch 330/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6808 - g_loss: 0.8411
# Epoch 331/600
# 24/24 [==============================] - 4s 165ms/step - d_loss: 0.6811 - g_loss: 0.8414
# Epoch 332/600
# 24/24 [==============================] - 4s 161ms/step - d_loss: 0.6803 - g_loss: 0.8417
# Epoch 333/600
# 24/24 [==============================] - 5s 189ms/step - d_loss: 0.6805 - g_loss: 0.8404
# Epoch 334/600
# 24/24 [==============================] - 4s 161ms/step - d_loss: 0.6790 - g_loss: 0.8413
# Epoch 335/600
# 24/24 [==============================] - 4s 165ms/step - d_loss: 0.6784 - g_loss: 0.8419
# Epoch 336/600
# 24/24 [==============================] - 4s 146ms/step - d_loss: 0.6800 - g_loss: 0.8425
# Epoch 337/600
# 24/24 [==============================] - 4s 170ms/step - d_loss: 0.6782 - g_loss: 0.8436
# Epoch 338/600
# 24/24 [==============================] - 4s 173ms/step - d_loss: 0.6806 - g_loss: 0.8434
# Epoch 339/600
# 24/24 [==============================] - 5s 192ms/step - d_loss: 0.6800 - g_loss: 0.8440
# Epoch 340/600
# 24/24 [==============================] - 5s 196ms/step - d_loss: 0.6817 - g_loss: 0.8449
# Epoch 341/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6802 - g_loss: 0.8446
# Epoch 342/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6797 - g_loss: 0.8443
# Epoch 343/600
# 24/24 [==============================] - 5s 194ms/step - d_loss: 0.6799 - g_loss: 0.8440
# Epoch 344/600
# 24/24 [==============================] - 5s 192ms/step - d_loss: 0.6774 - g_loss: 0.8446
# Epoch 345/600
# 24/24 [==============================] - 5s 197ms/step - d_loss: 0.6795 - g_loss: 0.8462
# Epoch 346/600
# 24/24 [==============================] - 5s 200ms/step - d_loss: 0.6807 - g_loss: 0.8466
# Epoch 347/600
# 24/24 [==============================] - 5s 194ms/step - d_loss: 0.6782 - g_loss: 0.8464
# Epoch 348/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6797 - g_loss: 0.8462
# Epoch 349/600
# 24/24 [==============================] - 5s 197ms/step - d_loss: 0.6791 - g_loss: 0.8458
# Epoch 350/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6790 - g_loss: 0.8466
# Epoch 351/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6785 - g_loss: 0.8467
# Epoch 352/600
# 24/24 [==============================] - 5s 191ms/step - d_loss: 0.6800 - g_loss: 0.8468
# Epoch 353/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6796 - g_loss: 0.8457
# Epoch 354/600
# 24/24 [==============================] - 5s 195ms/step - d_loss: 0.6800 - g_loss: 0.8454
# Epoch 355/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6798 - g_loss: 0.8461
# Epoch 356/600
# 24/24 [==============================] - 5s 194ms/step - d_loss: 0.6781 - g_loss: 0.8459
# Epoch 357/600
# 24/24 [==============================] - 5s 194ms/step - d_loss: 0.6789 - g_loss: 0.8463
# Epoch 358/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6806 - g_loss: 0.8455
# Epoch 359/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6788 - g_loss: 0.8427
# Epoch 360/600
# 24/24 [==============================] - 5s 192ms/step - d_loss: 0.6796 - g_loss: 0.8418
# Epoch 361/600
# 24/24 [==============================] - 5s 196ms/step - d_loss: 0.6809 - g_loss: 0.8424
# Epoch 362/600
# 24/24 [==============================] - 5s 190ms/step - d_loss: 0.6788 - g_loss: 0.8438
# Epoch 363/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6769 - g_loss: 0.8459
# Epoch 364/600
# 24/24 [==============================] - 5s 192ms/step - d_loss: 0.6798 - g_loss: 0.8473
# Epoch 365/600
# 24/24 [==============================] - 5s 192ms/step - d_loss: 0.6799 - g_loss: 0.8467
# Epoch 366/600
# 24/24 [==============================] - 5s 191ms/step - d_loss: 0.6803 - g_loss: 0.8441
# Epoch 367/600
# 24/24 [==============================] - 4s 159ms/step - d_loss: 0.6797 - g_loss: 0.8429
# Epoch 368/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6804 - g_loss: 0.8445
# Epoch 369/600
# 24/24 [==============================] - 4s 174ms/step - d_loss: 0.6808 - g_loss: 0.8459
# Epoch 370/600
# 24/24 [==============================] - 4s 152ms/step - d_loss: 0.6786 - g_loss: 0.8469
# Epoch 371/600
# 24/24 [==============================] - 3s 138ms/step - d_loss: 0.6809 - g_loss: 0.8482
# Epoch 372/600
# 24/24 [==============================] - 3s 144ms/step - d_loss: 0.6806 - g_loss: 0.8474
# Epoch 373/600
# 24/24 [==============================] - 5s 190ms/step - d_loss: 0.6810 - g_loss: 0.8468
# Epoch 374/600
# 24/24 [==============================] - 4s 175ms/step - d_loss: 0.6801 - g_loss: 0.8462
# Epoch 375/600
# 24/24 [==============================] - 4s 175ms/step - d_loss: 0.6786 - g_loss: 0.8465
# Epoch 376/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6792 - g_loss: 0.8472
# Epoch 377/600
# 24/24 [==============================] - 5s 194ms/step - d_loss: 0.6806 - g_loss: 0.8456
# Epoch 378/600
# 24/24 [==============================] - 4s 158ms/step - d_loss: 0.6773 - g_loss: 0.8446
# Epoch 379/600
# 24/24 [==============================] - 4s 146ms/step - d_loss: 0.6805 - g_loss: 0.8442
# Epoch 380/600
# 24/24 [==============================] - 3s 143ms/step - d_loss: 0.6787 - g_loss: 0.8433
# Epoch 381/600
# 24/24 [==============================] - 4s 150ms/step - d_loss: 0.6792 - g_loss: 0.8447
# Epoch 382/600
# 24/24 [==============================] - 4s 160ms/step - d_loss: 0.6789 - g_loss: 0.8444
# Epoch 383/600
# 24/24 [==============================] - 5s 190ms/step - d_loss: 0.6797 - g_loss: 0.8454
# Epoch 384/600
# 24/24 [==============================] - 5s 191ms/step - d_loss: 0.6803 - g_loss: 0.8440
# Epoch 385/600
# 24/24 [==============================] - 5s 192ms/step - d_loss: 0.6810 - g_loss: 0.8434
# Epoch 386/600
# 24/24 [==============================] - 5s 195ms/step - d_loss: 0.6794 - g_loss: 0.8425
# Epoch 387/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6802 - g_loss: 0.8425
# Epoch 388/600
# 24/24 [==============================] - 5s 191ms/step - d_loss: 0.6807 - g_loss: 0.8430
# Epoch 389/600
# 24/24 [==============================] - 5s 196ms/step - d_loss: 0.6800 - g_loss: 0.8422
# Epoch 390/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6787 - g_loss: 0.8415
# Epoch 391/600
# 24/24 [==============================] - 5s 194ms/step - d_loss: 0.6781 - g_loss: 0.8413
# Epoch 392/600
# 24/24 [==============================] - 5s 191ms/step - d_loss: 0.6790 - g_loss: 0.8427
# Epoch 393/600
# 24/24 [==============================] - 5s 190ms/step - d_loss: 0.6790 - g_loss: 0.8433
# Epoch 394/600
# 24/24 [==============================] - 5s 191ms/step - d_loss: 0.6779 - g_loss: 0.8437
# Epoch 395/600
# 24/24 [==============================] - 5s 192ms/step - d_loss: 0.6805 - g_loss: 0.8424
# Epoch 396/600
# 24/24 [==============================] - 5s 192ms/step - d_loss: 0.6797 - g_loss: 0.8414
# Epoch 397/600
# 24/24 [==============================] - 5s 190ms/step - d_loss: 0.6792 - g_loss: 0.8404
# Epoch 398/600
# 24/24 [==============================] - 4s 180ms/step - d_loss: 0.6810 - g_loss: 0.8407
# Epoch 399/600
# 24/24 [==============================] - 4s 160ms/step - d_loss: 0.6771 - g_loss: 0.8425
# Epoch 400/600
# 24/24 [==============================] - 5s 190ms/step - d_loss: 0.6800 - g_loss: 0.8439
# Epoch 401/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6810 - g_loss: 0.8421
# Epoch 402/600
# 24/24 [==============================] - 4s 158ms/step - d_loss: 0.6790 - g_loss: 0.8400
# Epoch 403/600
# 24/24 [==============================] - 4s 164ms/step - d_loss: 0.6785 - g_loss: 0.8405
# Epoch 404/600
# 24/24 [==============================] - 4s 152ms/step - d_loss: 0.6794 - g_loss: 0.8414
# Epoch 405/600
# 24/24 [==============================] - 3s 143ms/step - d_loss: 0.6800 - g_loss: 0.8436
# Epoch 406/600
# 24/24 [==============================] - 3s 146ms/step - d_loss: 0.6791 - g_loss: 0.8443
# Epoch 407/600
# 24/24 [==============================] - 4s 154ms/step - d_loss: 0.6801 - g_loss: 0.8450
# Epoch 408/600
# 24/24 [==============================] - 4s 161ms/step - d_loss: 0.6790 - g_loss: 0.8458
# Epoch 409/600
# 24/24 [==============================] - 4s 177ms/step - d_loss: 0.6789 - g_loss: 0.8466
# Epoch 410/600
# 24/24 [==============================] - 5s 195ms/step - d_loss: 0.6772 - g_loss: 0.8464
# Epoch 411/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6808 - g_loss: 0.8455
# Epoch 412/600
# 24/24 [==============================] - 5s 192ms/step - d_loss: 0.6792 - g_loss: 0.8443
# Epoch 413/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6783 - g_loss: 0.8453
# Epoch 414/600
# 24/24 [==============================] - 5s 196ms/step - d_loss: 0.6790 - g_loss: 0.8462
# Epoch 415/600
# 24/24 [==============================] - 5s 195ms/step - d_loss: 0.6792 - g_loss: 0.8450
# Epoch 416/600
# 24/24 [==============================] - 4s 161ms/step - d_loss: 0.6772 - g_loss: 0.8463
# Epoch 417/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6790 - g_loss: 0.8478
# Epoch 418/600
# 24/24 [==============================] - 5s 191ms/step - d_loss: 0.6781 - g_loss: 0.8481
# Epoch 419/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6790 - g_loss: 0.8495
# Epoch 420/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6794 - g_loss: 0.8489
# Epoch 421/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6796 - g_loss: 0.8468
# Epoch 422/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6794 - g_loss: 0.8456
# Epoch 423/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6792 - g_loss: 0.8457
# Epoch 424/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6811 - g_loss: 0.8472
# Epoch 425/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6783 - g_loss: 0.8480
# Epoch 426/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6815 - g_loss: 0.8472
# Epoch 427/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6795 - g_loss: 0.8447
# Epoch 428/600
# 24/24 [==============================] - 4s 170ms/step - d_loss: 0.6811 - g_loss: 0.8432
# Epoch 429/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6796 - g_loss: 0.8430
# Epoch 430/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6807 - g_loss: 0.8442
# Epoch 431/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6802 - g_loss: 0.8457
# Epoch 432/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6811 - g_loss: 0.8447
# Epoch 433/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6790 - g_loss: 0.8411
# Epoch 434/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6800 - g_loss: 0.8401
# Epoch 435/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6798 - g_loss: 0.8411
# Epoch 436/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6793 - g_loss: 0.8444
# Epoch 437/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6785 - g_loss: 0.8463
# Epoch 438/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6807 - g_loss: 0.8445
# Epoch 439/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6792 - g_loss: 0.8400
# Epoch 440/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6800 - g_loss: 0.8391
# Epoch 441/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6786 - g_loss: 0.8430
# Epoch 442/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6795 - g_loss: 0.8452
# Epoch 443/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6799 - g_loss: 0.8438
# Epoch 444/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6789 - g_loss: 0.8404
# Epoch 445/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6805 - g_loss: 0.8399
# Epoch 446/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6798 - g_loss: 0.8414
# Epoch 447/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6795 - g_loss: 0.8427
# Epoch 448/600
# 24/24 [==============================] - 4s 177ms/step - d_loss: 0.6779 - g_loss: 0.8436
# Epoch 449/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6808 - g_loss: 0.8434
# Epoch 450/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6771 - g_loss: 0.8414
# Epoch 451/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6816 - g_loss: 0.8416
# Epoch 452/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6798 - g_loss: 0.8412
# Epoch 453/600
# 24/24 [==============================] - 4s 179ms/step - d_loss: 0.6799 - g_loss: 0.8413
# Epoch 454/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6795 - g_loss: 0.8430
# Epoch 455/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6786 - g_loss: 0.8439
# Epoch 456/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6812 - g_loss: 0.8430
# Epoch 457/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6791 - g_loss: 0.8425
# Epoch 458/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6791 - g_loss: 0.8442
# Epoch 459/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6788 - g_loss: 0.8445
# Epoch 460/600
# 24/24 [==============================] - 5s 191ms/step - d_loss: 0.6797 - g_loss: 0.8449
# Epoch 461/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6809 - g_loss: 0.8458
# Epoch 462/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6813 - g_loss: 0.8460
# Epoch 463/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6778 - g_loss: 0.8464
# Epoch 464/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6794 - g_loss: 0.8477
# Epoch 465/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6802 - g_loss: 0.8471
# Epoch 466/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6781 - g_loss: 0.8452
# Epoch 467/600
# 24/24 [==============================] - 4s 162ms/step - d_loss: 0.6818 - g_loss: 0.8436
# Epoch 468/600
# 24/24 [==============================] - 4s 174ms/step - d_loss: 0.6796 - g_loss: 0.8442
# Epoch 469/600
# 24/24 [==============================] - 4s 181ms/step - d_loss: 0.6806 - g_loss: 0.8454
# Epoch 470/600
# 24/24 [==============================] - 4s 176ms/step - d_loss: 0.6789 - g_loss: 0.8444
# Epoch 471/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6780 - g_loss: 0.8442
# Epoch 472/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6800 - g_loss: 0.8431
# Epoch 473/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6801 - g_loss: 0.8431
# Epoch 474/600
# 24/24 [==============================] - 4s 180ms/step - d_loss: 0.6797 - g_loss: 0.8449
# Epoch 475/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6798 - g_loss: 0.8454
# Epoch 476/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6791 - g_loss: 0.8449
# Epoch 477/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6795 - g_loss: 0.8440
# Epoch 478/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6780 - g_loss: 0.8436
# Epoch 479/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6811 - g_loss: 0.8448
# Epoch 480/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6795 - g_loss: 0.8447
# Epoch 481/600
# 24/24 [==============================] - 4s 178ms/step - d_loss: 0.6809 - g_loss: 0.8440
# Epoch 482/600
# 24/24 [==============================] - 5s 189ms/step - d_loss: 0.6792 - g_loss: 0.8438
# Epoch 483/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6803 - g_loss: 0.8434
# Epoch 484/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6826 - g_loss: 0.8419
# Epoch 485/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6799 - g_loss: 0.8416
# Epoch 486/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6796 - g_loss: 0.8439
# Epoch 487/600
# 24/24 [==============================] - 4s 184ms/step - d_loss: 0.6793 - g_loss: 0.8469
# Epoch 488/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6809 - g_loss: 0.8451
# Epoch 489/600
# 24/24 [==============================] - 4s 176ms/step - d_loss: 0.6805 - g_loss: 0.8421
# Epoch 490/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6788 - g_loss: 0.8409
# Epoch 491/600
# 24/24 [==============================] - 4s 186ms/step - d_loss: 0.6779 - g_loss: 0.8447
# Epoch 492/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6781 - g_loss: 0.8480
# Epoch 493/600
# 24/24 [==============================] - 4s 187ms/step - d_loss: 0.6780 - g_loss: 0.8475
# Epoch 494/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6809 - g_loss: 0.8443
# Epoch 495/600
# 24/24 [==============================] - 4s 170ms/step - d_loss: 0.6815 - g_loss: 0.8415
# Epoch 496/600
# 24/24 [==============================] - 5s 221ms/step - d_loss: 0.6792 - g_loss: 0.8421
# Epoch 497/600
# 24/24 [==============================] - 6s 231ms/step - d_loss: 0.6802 - g_loss: 0.8453
# Epoch 498/600
# 24/24 [==============================] - 6s 238ms/step - d_loss: 0.6798 - g_loss: 0.8471
# Epoch 499/600
# 24/24 [==============================] - 5s 214ms/step - d_loss: 0.6797 - g_loss: 0.8452
# Epoch 500/600
# 24/24 [==============================] - 5s 210ms/step - d_loss: 0.6803 - g_loss: 0.8410
# Epoch 501/600
# 24/24 [==============================] - 5s 200ms/step - d_loss: 0.6790 - g_loss: 0.8396
# Epoch 502/600
# 24/24 [==============================] - 5s 198ms/step - d_loss: 0.6786 - g_loss: 0.8426
# Epoch 503/600
# 24/24 [==============================] - 4s 183ms/step - d_loss: 0.6777 - g_loss: 0.8479
# Epoch 504/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6804 - g_loss: 0.8489
# Epoch 505/600
# 24/24 [==============================] - 5s 204ms/step - d_loss: 0.6794 - g_loss: 0.8452
# Epoch 506/600
# 24/24 [==============================] - 5s 195ms/step - d_loss: 0.6794 - g_loss: 0.8405
# Epoch 507/600
# 24/24 [==============================] - 5s 209ms/step - d_loss: 0.6801 - g_loss: 0.8397
# Epoch 508/600
# 24/24 [==============================] - 5s 217ms/step - d_loss: 0.6797 - g_loss: 0.8433
# Epoch 509/600
# 24/24 [==============================] - 5s 204ms/step - d_loss: 0.6798 - g_loss: 0.8453
# Epoch 510/600
# 24/24 [==============================] - 4s 168ms/step - d_loss: 0.6792 - g_loss: 0.8447
# Epoch 511/600
# 24/24 [==============================] - 4s 147ms/step - d_loss: 0.6808 - g_loss: 0.8428
# Epoch 512/600
# 24/24 [==============================] - 4s 169ms/step - d_loss: 0.6776 - g_loss: 0.8412
# Epoch 513/600
# 24/24 [==============================] - 5s 188ms/step - d_loss: 0.6774 - g_loss: 0.8435
# Epoch 514/600
# 24/24 [==============================] - 5s 226ms/step - d_loss: 0.6797 - g_loss: 0.8462
# Epoch 515/600
# 24/24 [==============================] - 5s 219ms/step - d_loss: 0.6792 - g_loss: 0.8466
# Epoch 516/600
# 24/24 [==============================] - 5s 217ms/step - d_loss: 0.6808 - g_loss: 0.8452
# Epoch 517/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6798 - g_loss: 0.8430
# Epoch 518/600
# 24/24 [==============================] - 5s 193ms/step - d_loss: 0.6808 - g_loss: 0.8417
# Epoch 519/600
# 24/24 [==============================] - 5s 197ms/step - d_loss: 0.6810 - g_loss: 0.8438
# Epoch 520/600
# 24/24 [==============================] - 4s 177ms/step - d_loss: 0.6790 - g_loss: 0.8456
# Epoch 521/600
# 24/24 [==============================] - 4s 185ms/step - d_loss: 0.6792 - g_loss: 0.8467
# Epoch 522/600
# 24/24 [==============================] - 4s 182ms/step - d_loss: 0.6789 - g_loss: 0.8452
# Epoch 523/600
# 24/24 [==============================] - 4s 176ms/step - d_loss: 0.6786 - g_loss: 0.8429
# Epoch 524/600
# 24/24 [==============================] - 5s 198ms/step - d_loss: 0.6811 - g_loss: 0.8423
# Epoch 525/600
# 24/24 [==============================] - 4s 179ms/step - d_loss: 0.6805 - g_loss: 0.8446
# Epoch 526/600
# 24/24 [==============================] - 5s 204ms/step - d_loss: 0.6821 - g_loss: 0.8476
# Epoch 527/600
# 24/24 [==============================] - 5s 212ms/step - d_loss: 0.6794 - g_loss: 0.8487
# Epoch 528/600
# 24/24 [==============================] - 5s 197ms/step - d_loss: 0.6784 - g_loss: 0.8456
# Epoch 529/600
# 24/24 [==============================] - 5s 186ms/step - d_loss: 0.6808 - g_loss: 0.8422
# Epoch 530/600
# 24/24 [==============================] - 5s 221ms/step - d_loss: 0.6806 - g_loss: 0.8422
# Epoch 531/600
# 24/24 [==============================] - 5s 215ms/step - d_loss: 0.6796 - g_loss: 0.8494
# Epoch 532/600
# 24/24 [==============================] - 5s 209ms/step - d_loss: 0.6791 - g_loss: 0.8539
# Epoch 533/600
# 24/24 [==============================] - 5s 216ms/step - d_loss: 0.6793 - g_loss: 0.8501
# Epoch 534/600
# 24/24 [==============================] - 5s 225ms/step - d_loss: 0.6801 - g_loss: 0.8432
# Epoch 535/600
# 24/24 [==============================] - 5s 224ms/step - d_loss: 0.6808 - g_loss: 0.8398
# Epoch 536/600
# 24/24 [==============================] - 5s 222ms/step - d_loss: 0.6773 - g_loss: 0.8453
# Epoch 537/600
# 24/24 [==============================] - 5s 222ms/step - d_loss: 0.6806 - g_loss: 0.8537
# Epoch 538/600
# 24/24 [==============================] - 5s 225ms/step - d_loss: 0.6806 - g_loss: 0.8551
# Epoch 539/600
# 24/24 [==============================] - 5s 219ms/step - d_loss: 0.6799 - g_loss: 0.8487
# Epoch 540/600
# 24/24 [==============================] - 5s 225ms/step - d_loss: 0.6802 - g_loss: 0.8411
# Epoch 541/600
# 24/24 [==============================] - 5s 219ms/step - d_loss: 0.6799 - g_loss: 0.8347
# Epoch 542/600
# 24/24 [==============================] - 5s 224ms/step - d_loss: 0.6785 - g_loss: 0.8352
# Epoch 543/600
# 24/24 [==============================] - 5s 229ms/step - d_loss: 0.6787 - g_loss: 0.8456
# Epoch 544/600
# 24/24 [==============================] - 6s 233ms/step - d_loss: 0.6792 - g_loss: 0.8563
# Epoch 545/600
# 24/24 [==============================] - 6s 230ms/step - d_loss: 0.6809 - g_loss: 0.8580
# Epoch 546/600
# 24/24 [==============================] - 6s 245ms/step - d_loss: 0.6807 - g_loss: 0.8510
# Epoch 547/600
# 24/24 [==============================] - 6s 242ms/step - d_loss: 0.6780 - g_loss: 0.8417
# Epoch 548/600
# 24/24 [==============================] - 6s 240ms/step - d_loss: 0.6808 - g_loss: 0.8365
# Epoch 549/600
# 24/24 [==============================] - 5s 205ms/step - d_loss: 0.6801 - g_loss: 0.8356
# Epoch 550/600
# 24/24 [==============================] - 5s 221ms/step - d_loss: 0.6803 - g_loss: 0.8409
# Epoch 551/600
# 24/24 [==============================] - 6s 237ms/step - d_loss: 0.6787 - g_loss: 0.8510
# Epoch 552/600
# 24/24 [==============================] - 5s 212ms/step - d_loss: 0.6788 - g_loss: 0.8557
# Epoch 553/600
# 24/24 [==============================] - 6s 232ms/step - d_loss: 0.6817 - g_loss: 0.8532
# Epoch 554/600
# 24/24 [==============================] - 6s 237ms/step - d_loss: 0.6789 - g_loss: 0.8456
# Epoch 555/600
# 24/24 [==============================] - 6s 235ms/step - d_loss: 0.6802 - g_loss: 0.8391
# Epoch 556/600
# 24/24 [==============================] - 6s 238ms/step - d_loss: 0.6792 - g_loss: 0.8365
# Epoch 557/600
# 24/24 [==============================] - 6s 235ms/step - d_loss: 0.6791 - g_loss: 0.8404
# Epoch 558/600
# 24/24 [==============================] - 5s 198ms/step - d_loss: 0.6806 - g_loss: 0.8481
# Epoch 559/600
# 24/24 [==============================] - 5s 220ms/step - d_loss: 0.6816 - g_loss: 0.8516
# Epoch 560/600
# 24/24 [==============================] - 6s 236ms/step - d_loss: 0.6776 - g_loss: 0.8506
# Epoch 561/600
# 24/24 [==============================] - 5s 221ms/step - d_loss: 0.6787 - g_loss: 0.8481
# Epoch 562/600
# 24/24 [==============================] - 6s 236ms/step - d_loss: 0.6792 - g_loss: 0.8450
# Epoch 563/600
# 24/24 [==============================] - 6s 235ms/step - d_loss: 0.6793 - g_loss: 0.8420
# Epoch 564/600
# 24/24 [==============================] - 5s 215ms/step - d_loss: 0.6780 - g_loss: 0.8438
# Epoch 565/600
# 24/24 [==============================] - 5s 217ms/step - d_loss: 0.6803 - g_loss: 0.8487
# Epoch 566/600
# 24/24 [==============================] - 5s 227ms/step - d_loss: 0.6806 - g_loss: 0.8535
# Epoch 567/600
# 24/24 [==============================] - 5s 220ms/step - d_loss: 0.6792 - g_loss: 0.8533
# Epoch 568/600
# 24/24 [==============================] - 6s 230ms/step - d_loss: 0.6771 - g_loss: 0.8502
# Epoch 569/600
# 24/24 [==============================] - 5s 223ms/step - d_loss: 0.6794 - g_loss: 0.8460
# Epoch 570/600
# 24/24 [==============================] - 5s 226ms/step - d_loss: 0.6787 - g_loss: 0.8433
# Epoch 571/600
# 24/24 [==============================] - 5s 208ms/step - d_loss: 0.6805 - g_loss: 0.8448
# Epoch 572/600
# 24/24 [==============================] - 5s 222ms/step - d_loss: 0.6794 - g_loss: 0.8483
# Epoch 573/600
# 24/24 [==============================] - 5s 226ms/step - d_loss: 0.6803 - g_loss: 0.8513
# Epoch 574/600
# 24/24 [==============================] - 5s 227ms/step - d_loss: 0.6785 - g_loss: 0.8512
# Epoch 575/600
# 24/24 [==============================] - 5s 213ms/step - d_loss: 0.6805 - g_loss: 0.8487
# Epoch 576/600
# 24/24 [==============================] - 6s 231ms/step - d_loss: 0.6778 - g_loss: 0.8467
# Epoch 577/600
# 24/24 [==============================] - 5s 225ms/step - d_loss: 0.6821 - g_loss: 0.8458
# Epoch 578/600
# 24/24 [==============================] - 6s 242ms/step - d_loss: 0.6775 - g_loss: 0.8454
# Epoch 579/600
# 24/24 [==============================] - 5s 216ms/step - d_loss: 0.6777 - g_loss: 0.8484
# Epoch 580/600
# 24/24 [==============================] - 5s 220ms/step - d_loss: 0.6796 - g_loss: 0.8511
# Epoch 581/600
# 24/24 [==============================] - 6s 234ms/step - d_loss: 0.6808 - g_loss: 0.8536
# Epoch 582/600
# 24/24 [==============================] - 6s 231ms/step - d_loss: 0.6809 - g_loss: 0.8516
# Epoch 583/600
# 24/24 [==============================] - 5s 219ms/step - d_loss: 0.6808 - g_loss: 0.8470
# Epoch 584/600
# 24/24 [==============================] - 6s 242ms/step - d_loss: 0.6795 - g_loss: 0.8444
# Epoch 585/600
# 24/24 [==============================] - 5s 228ms/step - d_loss: 0.6779 - g_loss: 0.8446
# Epoch 586/600
# 24/24 [==============================] - 6s 230ms/step - d_loss: 0.6791 - g_loss: 0.8482
# Epoch 587/600
# 24/24 [==============================] - 6s 237ms/step - d_loss: 0.6791 - g_loss: 0.8531
# Epoch 588/600
# 24/24 [==============================] - 6s 235ms/step - d_loss: 0.6790 - g_loss: 0.8535
# Epoch 589/600
# 24/24 [==============================] - 5s 227ms/step - d_loss: 0.6804 - g_loss: 0.8507
# Epoch 590/600
# 24/24 [==============================] - 5s 229ms/step - d_loss: 0.6773 - g_loss: 0.8460
# Epoch 591/600
# 24/24 [==============================] - 6s 232ms/step - d_loss: 0.6802 - g_loss: 0.8426
# Epoch 592/600
# 24/24 [==============================] - 6s 236ms/step - d_loss: 0.6797 - g_loss: 0.8427
# Epoch 593/600
# 24/24 [==============================] - 5s 206ms/step - d_loss: 0.6785 - g_loss: 0.8487
# Epoch 594/600
# 24/24 [==============================] - 5s 222ms/step - d_loss: 0.6801 - g_loss: 0.8555
# Epoch 595/600
# 24/24 [==============================] - 5s 225ms/step - d_loss: 0.6790 - g_loss: 0.8547
# Epoch 596/600
# 24/24 [==============================] - 6s 240ms/step - d_loss: 0.6810 - g_loss: 0.8491
# Epoch 597/600
# 24/24 [==============================] - 5s 209ms/step - d_loss: 0.6807 - g_loss: 0.8434
# Epoch 598/600
# 24/24 [==============================] - 5s 219ms/step - d_loss: 0.6792 - g_loss: 0.8426
# Epoch 599/600
# 24/24 [==============================] - 5s 209ms/step - d_loss: 0.6804 - g_loss: 0.8445
# Epoch 600/600
# 24/24 [==============================] - 5s 222ms/step - d_loss: 0.6811 - g_loss: 0.8485

# %%
scenario_size = 30
normal_noise = tf.random.normal((scenario_size, batch_size, 1))
n = [np.random.normal() for _ in range(scenario_size)]
series = np.multiply(generator.predict(normal_noise), max)
resolution = 100

probabilities = []
ranges = np.linspace(-3.5, 3.5, 8)
intervals = np.linspace(-3, 3, 7)
probs = [stats.norm.cdf(i) for i in n]
prob_ranges = {intervals[i]: [stats.norm.cdf(ranges[i]), stats.norm.cdf(ranges[i+1])] for i in range(len(intervals))}
for i in probs:
    for key in intervals:
        if prob_ranges[key][0]<= i <=prob_ranges[key][1]:
            probabilities.append(prob_ranges[key][1]-prob_ranges[key][0])
            break
scenarios = {'probs': probabilities}
for j in range(resolution):
    scenarios[j] = []
for i in range(scenario_size):
    s = series[i].reshape([resolution])
    for j in range(resolution):
        scenarios[j].append(s[j])



pd.DataFrame(scenarios).to_csv(f'LoadScenarios-{month_name}-{day_type}.csv')
# Out:
# 1/1 [==============================] - 0s 51ms/step

# %%
ticks = [i for i in range(resolution) if i%4 == 0]

fig, ax = plt.subplots(1, 2, figsize=(15, 4), dpi=200)
for s in series[:5]:
    ax[0].plot(range(resolution), s.reshape([resolution]), linewidth=1)
ax[0].set_xlabel('Timestamp (15 min)')
ax[0].set_ylabel('Generated Power Consumption')
ax[0].set_xticks(ticks, ticks)
ax[0].grid(color='#666362', linestyle='-', linewidth=0.1)

if day_type == 'w':
    ax[1].plot(my_data[[c for c in my_data.columns if 'weekday' in c][:5]], linewidth=1)
else:
    ax[1].plot(my_data[[c for c in my_data.columns if 'weekend' in c][:5]], linewidth=1)
ax[1].set_xlabel('Timestamp (15 min)')
ax[1].set_ylabel('Historical Power Consumption')
ax[1].set_xticks(ticks, ticks)
ax[1].grid(color='#666362', linestyle='-', linewidth=0.1)
plt.subplots_adjust(wspace=0.1)

plt.savefig(f'IMG/{month_name}-{day_type}.jpg', bbox_inches='tight')

# %% [markdown]
# ### Save models

# %%
generator.save(f'HarrisCounty/GAN Models/generator-{month_name}-{day_type}.h5')
discriminator.save(f'HarrisCounty/GAN Models/discriminator-{month_name}-{day_type}.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
plt.figure(figsize=(7, 3), dpi=300)
plt.plot(hist.history['d_loss'], label='Generator Loss')
plt.plot(hist.history['g_loss'], label='Discriminator Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(color='#666362', linestyle='-', linewidth=0.1)
plt.savefig(f'IMG/{month_name}-{day_type}-loss.jpg', bbox_inches='tight')

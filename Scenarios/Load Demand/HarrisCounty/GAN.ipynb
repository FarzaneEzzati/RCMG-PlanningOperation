# %%
import tensorflow as tf
from keras import layers, Model
import numpy as np
import datetime
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
from keras.callbacks import Callback
from keras.utils import array_to_img
from keras import Sequential
from keras.layers import Conv2D, Dense, Flatten, Reshape, LeakyReLU, Dropout, UpSampling1D
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from keras.models import Model

gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.reset_memory_stats(gpu, True)
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('ignore')

c = pd.read_csv('../../../Visualizations/color.csv')['color']

# %%
month_name='SepOct'
day_type = 'e'
my_data = pd.read_csv(f'ForGAN/{month_name}.csv')
ds = []
if day_type == 'w':
    for c in my_data.columns:
        if 'weekday' in c:
            last = my_data[c].values[-1]
            ds.append(np.concatenate([my_data[c].values, [last, last, last, last]]).reshape([1, 100]))
else:
    for c in my_data.columns:
        if 'weekend' in c:
            last = my_data[c].values[-1]
            ds.append(np.concatenate([my_data[c].values, [last, last, last, last]]).reshape([1, 100]))

max = np.max(ds)
ds = np.divide(ds, max)

# %% [markdown]
# ### Prepare data to feed into GAN

# %%
ds = tf.data.Dataset.from_tensor_slices(ds)
batch_size = 12
ds = ds.cache()
ds = ds.shuffle(1000)
ds = ds.batch(batch_size)
ds = ds.prefetch(64)

# %% [markdown]
# ## Generator

# %%
g_relu = 0.2
if day_type == 'w':
    def build_generator():
        model = Sequential()

        model.add(Dense(1*100*batch_size, input_dim=batch_size))
        model.add(LeakyReLU(g_relu))
        model.add(Reshape((1,100, batch_size)))

        #model.add(UpSamplingD())
        model.add(Conv2D(batch_size, 3, padding='same'))
        model.add(LeakyReLU(g_relu))

        model.add(Conv2D(batch_size, 3, padding='same'))
        model.add(LeakyReLU(g_relu))

        model.add(Conv2D(batch_size, 3, padding='same'))
        model.add(LeakyReLU(g_relu))

        model.add(Conv2D(batch_size, 3, padding='same'))
        model.add(LeakyReLU(g_relu))

        model.add(Conv2D(1, 5, padding='same', activation='sigmoid'))
        return model
    generator = build_generator()
    generator.summary()
else:
    def build_generator():
            model = Sequential()

            model.add(Dense(1*100*batch_size, input_dim=batch_size))
            model.add(LeakyReLU(g_relu))
            model.add(Reshape((1,100, batch_size)))

            #model.add(UpSamplingD())
            model.add(Conv2D(batch_size, 5, padding='same'))
            model.add(LeakyReLU(g_relu))

            model.add(Conv2D(batch_size, 5, padding='same'))
            model.add(LeakyReLU(g_relu))

            model.add(Conv2D(batch_size, 5, padding='same'))
            model.add(LeakyReLU(g_relu))

            model.add(Conv2D(1, 5, padding='same', activation='sigmoid'))
            return model
    generator = build_generator()
    generator.summary()
# series = generator.predict(np.random.randn(4, 6, 1))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1200)              15600
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 1200)              0
#
#  reshape_1 (Reshape)         (None, 1, 100, 12)        0
#
#  conv2d_4 (Conv2D)           (None, 1, 100, 12)        3612
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 1, 100, 12)        0
#
#  conv2d_5 (Conv2D)           (None, 1, 100, 12)        3612
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 1, 100, 12)        0
#
#  conv2d_6 (Conv2D)           (None, 1, 100, 12)        3612
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 1, 100, 12)        0
#
#  conv2d_7 (Conv2D)           (None, 1, 100, 1)         301
#
# =================================================================
# Total params: 26,737
# Trainable params: 26,737
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Discriminator

# %%
d_relu = 0.2
d_dropout = 0.2
if day_type == 'w':
    def build_discriminator():
        model = Sequential()

        model.add(Dense(200, input_shape=(1, 100, 1)))
        model.add(LeakyReLU(d_relu))
        model.add(Dropout(d_dropout))

        model.add(Dense(150))
        model.add(LeakyReLU(d_relu))
        model.add(Dropout(d_dropout))

        model.add(Flatten())
        model.add(Dropout(d_dropout))
        model.add(Dense(1, activation='sigmoid'))
        # 1: fake series, 0: real series

        return model
    discriminator = build_discriminator()
    discriminator.summary()
else:
    def build_discriminator():
            model = Sequential()

            model.add(Dense(100, input_shape=(1, 100, 1)))
            model.add(LeakyReLU(d_relu))
            model.add(Dropout(d_dropout))

            model.add(Dense(120))
            model.add(LeakyReLU(d_relu))
            model.add(Dropout(d_dropout))

            model.add(Flatten())
            model.add(Dropout(d_dropout))
            model.add(Dense(1, activation='sigmoid'))
            # 1: fake series, 0: real series

            return model
    discriminator = build_discriminator()
    discriminator.summary()
# Single prediction needs np.expand_dims(series[0], 0)
# discriminator.predict(np.expand_dims(series[0], 0))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 1, 100, 100)       200
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 1, 100, 100)       0
#
#  dropout_3 (Dropout)         (None, 1, 100, 100)       0
#
#  dense_6 (Dense)             (None, 1, 100, 120)       12120
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 1, 100, 120)       0
#
#  dropout_4 (Dropout)         (None, 1, 100, 120)       0
#
#  flatten_1 (Flatten)         (None, 12000)             0
#
#  dropout_5 (Dropout)         (None, 12000)             0
#
#  dense_7 (Dense)             (None, 1)                 12001
#
# =================================================================
# Total params: 24,321
# Trainable params: 24,321
# Non-trainable params: 0
# _________________________________________________________________

# %%
g_a, d_a = 0.0001, 0.00001
g_opt = Adam(learning_rate=g_a)
d_opt = Adam(learning_rate=d_a)  # Does not learn too fast
g_loss = BinaryCrossentropy()
d_loss = BinaryCrossentropy()
class LoadGAN(Model):
    def __init__(self, generator, discriminator, *args, **kwargs):
        # pass through args and kwargs to base class
        super().__init__(*args, **kwargs)
        # Create attributes for gen and disc
        self.generator = generator
        self.discriminator = discriminator

    def compilee(self, g_opt, d_opt, g_loss, d_loss, *args, **kwargs):
        # Compile with base class
        super().compile(*args, **kwargs)

        self.g_opt = g_opt
        self.d_opt = d_opt
        self.g_loss = g_loss
        self.d_loss = d_loss

    def train_step(self, batch):
        real_series = batch
        fake_series = self.generator(tf.random.normal((batch_size, batch_size, 1)), training=False)

        # train the discriminator
        with tf.GradientTape() as d_tape:
            # pass the real and fake images
            yhat_real = self.discriminator(real_series, training=True)
            yhat_fake = self.discriminator(fake_series, training=True)
            yhat_realfake = tf.concat([yhat_real, yhat_fake], axis=0)

            # create labels for real and fake series
            y_realfake = tf.concat([tf.zeros_like(yhat_real), tf.ones_like(yhat_fake)], axis=0)


            # pass through and add some noise to the outputs
            noise_real = 0.15*tf.random.uniform(tf.shape(yhat_real))
            noise_fake = 0.15*tf.random.uniform(tf.shape(yhat_fake))
            y_realfake += tf.concat([noise_real, noise_fake], axis=0)

            # calculate the loss
            total_d_loss = self.d_loss(y_realfake, yhat_realfake)

        # apply backpropagation
        dgrad = d_tape.gradient(total_d_loss, self.discriminator.trainable_variables)
        self.d_opt.apply_gradients(zip(dgrad, self.discriminator.trainable_variables))

        # Generator training
        with tf.GradientTape() as g_tape:
            # generate same new images
            gen_series = self.generator(tf.random.normal((batch_size, batch_size, 1)), training=True)

            # create the predicted labels
            predicted_labels = self.discriminator(gen_series, training=False)

            # calculate loss
            total_g_loss = self.g_loss(tf.zeros_like(predicted_labels), predicted_labels)

        # apply backpropagation
        ggrad = g_tape.gradient(total_g_loss, self.generator.trainable_variables)
        self.g_opt.apply_gradients(zip(ggrad, self.generator.trainable_variables))

        return {"d_loss":total_d_loss, "g_loss":total_g_loss}
loadgan = LoadGAN(generator, discriminator)
loadgan.compilee(g_opt, d_opt, g_loss, d_loss)

# %% [markdown]
# #### Call Back

# %%
class ModelMonitor(Callback):
    def __init__(self, num_img=3, latent_dim=batch_size):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vector = tf.random.uniform((self.num_img, self.latent_dim, 1))
        generated_series = self.model.generator(random_latent_vector)
        generated_series *= max
        generated_series.numpy()
        for i in range(self.num_img):
            serie = array_to_img(generated_series[i])

# %% [markdown]
# #### Train

# %%
hist = loadgan.fit(ds, epochs=500)
# Out:
# Epoch 1/500
# 20/20 [==============================] - 2s 90ms/step - d_loss: 0.7081 - g_loss: 0.6252
# Epoch 2/500
# 20/20 [==============================] - 2s 100ms/step - d_loss: 0.7052 - g_loss: 0.6451
# Epoch 3/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6996 - g_loss: 0.6739
# Epoch 4/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6950 - g_loss: 0.7068
# Epoch 5/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6907 - g_loss: 0.7365
# Epoch 6/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6859 - g_loss: 0.7533
# Epoch 7/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6904 - g_loss: 0.7566
# Epoch 8/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6954 - g_loss: 0.7508
# Epoch 9/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6952 - g_loss: 0.7440
# Epoch 10/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6924 - g_loss: 0.7364
# Epoch 11/500
# 20/20 [==============================] - 2s 119ms/step - d_loss: 0.6895 - g_loss: 0.7298
# Epoch 12/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6895 - g_loss: 0.7274
# Epoch 13/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6890 - g_loss: 0.7288
# Epoch 14/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6881 - g_loss: 0.7340
# Epoch 15/500
# 20/20 [==============================] - 2s 121ms/step - d_loss: 0.6881 - g_loss: 0.7405
# Epoch 16/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6901 - g_loss: 0.7482
# Epoch 17/500
# 20/20 [==============================] - 6s 279ms/step - d_loss: 0.6891 - g_loss: 0.7559
# Epoch 18/500
# 20/20 [==============================] - 3s 149ms/step - d_loss: 0.6872 - g_loss: 0.7616
# Epoch 19/500
# 20/20 [==============================] - 3s 155ms/step - d_loss: 0.6874 - g_loss: 0.7689
# Epoch 20/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6893 - g_loss: 0.7773
# Epoch 21/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6832 - g_loss: 0.7889
# Epoch 22/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6814 - g_loss: 0.8003
# Epoch 23/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6824 - g_loss: 0.8114
# Epoch 24/500
# 20/20 [==============================] - 3s 174ms/step - d_loss: 0.6769 - g_loss: 0.8204
# Epoch 25/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6798 - g_loss: 0.8303
# Epoch 26/500
# 20/20 [==============================] - 4s 190ms/step - d_loss: 0.6782 - g_loss: 0.8372
# Epoch 27/500
# 20/20 [==============================] - 4s 185ms/step - d_loss: 0.6786 - g_loss: 0.8442
# Epoch 28/500
# 20/20 [==============================] - 5s 234ms/step - d_loss: 0.6773 - g_loss: 0.8499
# Epoch 29/500
# 20/20 [==============================] - 5s 248ms/step - d_loss: 0.6733 - g_loss: 0.8527
# Epoch 30/500
# 20/20 [==============================] - 4s 195ms/step - d_loss: 0.6747 - g_loss: 0.8535
# Epoch 31/500
# 20/20 [==============================] - 6s 291ms/step - d_loss: 0.6753 - g_loss: 0.8536
# Epoch 32/500
# 20/20 [==============================] - 6s 312ms/step - d_loss: 0.6775 - g_loss: 0.8533
# Epoch 33/500
# 20/20 [==============================] - 5s 230ms/step - d_loss: 0.6768 - g_loss: 0.8512
# Epoch 34/500
# 20/20 [==============================] - 4s 213ms/step - d_loss: 0.6737 - g_loss: 0.8509
# Epoch 35/500
# 20/20 [==============================] - 5s 264ms/step - d_loss: 0.6735 - g_loss: 0.8491
# Epoch 36/500
# 20/20 [==============================] - 3s 168ms/step - d_loss: 0.6745 - g_loss: 0.8453
# Epoch 37/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6765 - g_loss: 0.8415
# Epoch 38/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6786 - g_loss: 0.8353
# Epoch 39/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6803 - g_loss: 0.8312
# Epoch 40/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6787 - g_loss: 0.8280
# Epoch 41/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6769 - g_loss: 0.8256
# Epoch 42/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6765 - g_loss: 0.8246
# Epoch 43/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6786 - g_loss: 0.8215
# Epoch 44/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6802 - g_loss: 0.8172
# Epoch 45/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6777 - g_loss: 0.8146
# Epoch 46/500
# 20/20 [==============================] - 3s 156ms/step - d_loss: 0.6797 - g_loss: 0.8138
# Epoch 47/500
# 20/20 [==============================] - 4s 175ms/step - d_loss: 0.6801 - g_loss: 0.8141
# Epoch 48/500
# 20/20 [==============================] - 3s 161ms/step - d_loss: 0.6772 - g_loss: 0.8125
# Epoch 49/500
# 20/20 [==============================] - 3s 151ms/step - d_loss: 0.6782 - g_loss: 0.8127
# Epoch 50/500
# 20/20 [==============================] - 3s 147ms/step - d_loss: 0.6820 - g_loss: 0.8128
# Epoch 51/500
# 20/20 [==============================] - 4s 185ms/step - d_loss: 0.6816 - g_loss: 0.8130
# Epoch 52/500
# 20/20 [==============================] - 4s 183ms/step - d_loss: 0.6800 - g_loss: 0.8117
# Epoch 53/500
# 20/20 [==============================] - 4s 200ms/step - d_loss: 0.6832 - g_loss: 0.8121
# Epoch 54/500
# 20/20 [==============================] - 4s 176ms/step - d_loss: 0.6805 - g_loss: 0.8154
# Epoch 55/500
# 20/20 [==============================] - 3s 149ms/step - d_loss: 0.6820 - g_loss: 0.8160
# Epoch 56/500
# 20/20 [==============================] - 3s 168ms/step - d_loss: 0.6838 - g_loss: 0.8183
# Epoch 57/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6830 - g_loss: 0.8225
# Epoch 58/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6822 - g_loss: 0.8268
# Epoch 59/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6851 - g_loss: 0.8316
# Epoch 60/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6813 - g_loss: 0.8355
# Epoch 61/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6802 - g_loss: 0.8404
# Epoch 62/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6811 - g_loss: 0.8467
# Epoch 63/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6786 - g_loss: 0.8520
# Epoch 64/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6815 - g_loss: 0.8574
# Epoch 65/500
# 20/20 [==============================] - 3s 152ms/step - d_loss: 0.6759 - g_loss: 0.8587
# Epoch 66/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6758 - g_loss: 0.8627
# Epoch 67/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6751 - g_loss: 0.8667
# Epoch 68/500
# 20/20 [==============================] - 3s 173ms/step - d_loss: 0.6749 - g_loss: 0.8719
# Epoch 69/500
# 20/20 [==============================] - 3s 147ms/step - d_loss: 0.6753 - g_loss: 0.8774
# Epoch 70/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6746 - g_loss: 0.8815
# Epoch 71/500
# 20/20 [==============================] - 3s 149ms/step - d_loss: 0.6765 - g_loss: 0.8813
# Epoch 72/500
# 20/20 [==============================] - 3s 164ms/step - d_loss: 0.6701 - g_loss: 0.8813
# Epoch 73/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6764 - g_loss: 0.8843
# Epoch 74/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6756 - g_loss: 0.8842
# Epoch 75/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6759 - g_loss: 0.8816
# Epoch 76/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6773 - g_loss: 0.8797
# Epoch 77/500
# 20/20 [==============================] - 3s 140ms/step - d_loss: 0.6802 - g_loss: 0.8777
# Epoch 78/500
# 20/20 [==============================] - 3s 164ms/step - d_loss: 0.6760 - g_loss: 0.8752
# Epoch 79/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6776 - g_loss: 0.8727
# Epoch 80/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6789 - g_loss: 0.8698
# Epoch 81/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6784 - g_loss: 0.8659
# Epoch 82/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6809 - g_loss: 0.8627
# Epoch 83/500
# 20/20 [==============================] - 4s 216ms/step - d_loss: 0.6819 - g_loss: 0.8598
# Epoch 84/500
# 20/20 [==============================] - 6s 265ms/step - d_loss: 0.6819 - g_loss: 0.8550
# Epoch 85/500
# 20/20 [==============================] - 7s 343ms/step - d_loss: 0.6842 - g_loss: 0.8502
# Epoch 86/500
# 20/20 [==============================] - 4s 199ms/step - d_loss: 0.6814 - g_loss: 0.8460
# Epoch 87/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6810 - g_loss: 0.8449
# Epoch 88/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6815 - g_loss: 0.8434
# Epoch 89/500
# 20/20 [==============================] - 3s 149ms/step - d_loss: 0.6842 - g_loss: 0.8423
# Epoch 90/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6808 - g_loss: 0.8423
# Epoch 91/500
# 20/20 [==============================] - 4s 179ms/step - d_loss: 0.6813 - g_loss: 0.8411
# Epoch 92/500
# 20/20 [==============================] - 5s 256ms/step - d_loss: 0.6766 - g_loss: 0.8422
# Epoch 93/500
# 20/20 [==============================] - 3s 158ms/step - d_loss: 0.6795 - g_loss: 0.8444
# Epoch 94/500
# 20/20 [==============================] - 3s 171ms/step - d_loss: 0.6833 - g_loss: 0.8472
# Epoch 95/500
# 20/20 [==============================] - 4s 196ms/step - d_loss: 0.6776 - g_loss: 0.8484
# Epoch 96/500
# 20/20 [==============================] - 3s 159ms/step - d_loss: 0.6766 - g_loss: 0.8501
# Epoch 97/500
# 20/20 [==============================] - 3s 154ms/step - d_loss: 0.6778 - g_loss: 0.8512
# Epoch 98/500
# 20/20 [==============================] - 3s 140ms/step - d_loss: 0.6810 - g_loss: 0.8504
# Epoch 99/500
# 20/20 [==============================] - 3s 148ms/step - d_loss: 0.6772 - g_loss: 0.8490
# Epoch 100/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6784 - g_loss: 0.8488
# Epoch 101/500
# 20/20 [==============================] - 3s 176ms/step - d_loss: 0.6774 - g_loss: 0.8492
# Epoch 102/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6789 - g_loss: 0.8498
# Epoch 103/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6792 - g_loss: 0.8494
# Epoch 104/500
# 20/20 [==============================] - 3s 172ms/step - d_loss: 0.6808 - g_loss: 0.8483
# Epoch 105/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6815 - g_loss: 0.8473
# Epoch 106/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6769 - g_loss: 0.8465
# Epoch 107/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6769 - g_loss: 0.8462
# Epoch 108/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6795 - g_loss: 0.8464
# Epoch 109/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6798 - g_loss: 0.8479
# Epoch 110/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6806 - g_loss: 0.8497
# Epoch 111/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6831 - g_loss: 0.8483
# Epoch 112/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6833 - g_loss: 0.8473
# Epoch 113/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6764 - g_loss: 0.8477
# Epoch 114/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6832 - g_loss: 0.8480
# Epoch 115/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6820 - g_loss: 0.8475
# Epoch 116/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6837 - g_loss: 0.8452
# Epoch 117/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6833 - g_loss: 0.8442
# Epoch 118/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6839 - g_loss: 0.8433
# Epoch 119/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6834 - g_loss: 0.8427
# Epoch 120/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6824 - g_loss: 0.8431
# Epoch 121/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6851 - g_loss: 0.8429
# Epoch 122/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6845 - g_loss: 0.8427
# Epoch 123/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6881 - g_loss: 0.8429
# Epoch 124/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6844 - g_loss: 0.8442
# Epoch 125/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6874 - g_loss: 0.8446
# Epoch 126/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6848 - g_loss: 0.8465
# Epoch 127/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6851 - g_loss: 0.8487
# Epoch 128/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6851 - g_loss: 0.8522
# Epoch 129/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6846 - g_loss: 0.8530
# Epoch 130/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6804 - g_loss: 0.8571
# Epoch 131/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6802 - g_loss: 0.8611
# Epoch 132/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6797 - g_loss: 0.8632
# Epoch 133/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6794 - g_loss: 0.8650
# Epoch 134/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6774 - g_loss: 0.8666
# Epoch 135/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6778 - g_loss: 0.8680
# Epoch 136/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6783 - g_loss: 0.8696
# Epoch 137/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6767 - g_loss: 0.8690
# Epoch 138/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6771 - g_loss: 0.8697
# Epoch 139/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6765 - g_loss: 0.8696
# Epoch 140/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6770 - g_loss: 0.8684
# Epoch 141/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6779 - g_loss: 0.8689
# Epoch 142/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6791 - g_loss: 0.8694
# Epoch 143/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6820 - g_loss: 0.8674
# Epoch 144/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6759 - g_loss: 0.8677
# Epoch 145/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6830 - g_loss: 0.8684
# Epoch 146/500
# 20/20 [==============================] - 3s 125ms/step - d_loss: 0.6809 - g_loss: 0.8671
# Epoch 147/500
# 20/20 [==============================] - 3s 167ms/step - d_loss: 0.6792 - g_loss: 0.8681
# Epoch 148/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6778 - g_loss: 0.8689
# Epoch 149/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6809 - g_loss: 0.8688
# Epoch 150/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6771 - g_loss: 0.8692
# Epoch 151/500
# 20/20 [==============================] - 2s 119ms/step - d_loss: 0.6777 - g_loss: 0.8692
# Epoch 152/500
# 20/20 [==============================] - 2s 120ms/step - d_loss: 0.6786 - g_loss: 0.8695
# Epoch 153/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6795 - g_loss: 0.8684
# Epoch 154/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6795 - g_loss: 0.8678
# Epoch 155/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6774 - g_loss: 0.8665
# Epoch 156/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6796 - g_loss: 0.8649
# Epoch 157/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6770 - g_loss: 0.8624
# Epoch 158/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6747 - g_loss: 0.8597
# Epoch 159/500
# 20/20 [==============================] - 2s 120ms/step - d_loss: 0.6770 - g_loss: 0.8574
# Epoch 160/500
# 20/20 [==============================] - 2s 117ms/step - d_loss: 0.6781 - g_loss: 0.8556
# Epoch 161/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6773 - g_loss: 0.8549
# Epoch 162/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6782 - g_loss: 0.8540
# Epoch 163/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6777 - g_loss: 0.8519
# Epoch 164/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6790 - g_loss: 0.8516
# Epoch 165/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6773 - g_loss: 0.8523
# Epoch 166/500
# 20/20 [==============================] - 2s 122ms/step - d_loss: 0.6761 - g_loss: 0.8531
# Epoch 167/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6745 - g_loss: 0.8543
# Epoch 168/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6776 - g_loss: 0.8551
# Epoch 169/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6735 - g_loss: 0.8572
# Epoch 170/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6807 - g_loss: 0.8571
# Epoch 171/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6762 - g_loss: 0.8555
# Epoch 172/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6793 - g_loss: 0.8534
# Epoch 173/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6789 - g_loss: 0.8514
# Epoch 174/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6783 - g_loss: 0.8502
# Epoch 175/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6793 - g_loss: 0.8497
# Epoch 176/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6808 - g_loss: 0.8482
# Epoch 177/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6792 - g_loss: 0.8473
# Epoch 178/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6808 - g_loss: 0.8466
# Epoch 179/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6808 - g_loss: 0.8467
# Epoch 180/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6827 - g_loss: 0.8462
# Epoch 181/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6831 - g_loss: 0.8460
# Epoch 182/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6832 - g_loss: 0.8446
# Epoch 183/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6822 - g_loss: 0.8454
# Epoch 184/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6808 - g_loss: 0.8452
# Epoch 185/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6823 - g_loss: 0.8473
# Epoch 186/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6819 - g_loss: 0.8489
# Epoch 187/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6849 - g_loss: 0.8497
# Epoch 188/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6809 - g_loss: 0.8491
# Epoch 189/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6818 - g_loss: 0.8514
# Epoch 190/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6845 - g_loss: 0.8533
# Epoch 191/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6797 - g_loss: 0.8537
# Epoch 192/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6810 - g_loss: 0.8555
# Epoch 193/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6789 - g_loss: 0.8566
# Epoch 194/500
# 20/20 [==============================] - 2s 117ms/step - d_loss: 0.6788 - g_loss: 0.8584
# Epoch 195/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6798 - g_loss: 0.8598
# Epoch 196/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6806 - g_loss: 0.8588
# Epoch 197/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6796 - g_loss: 0.8572
# Epoch 198/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6791 - g_loss: 0.8567
# Epoch 199/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6778 - g_loss: 0.8566
# Epoch 200/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6789 - g_loss: 0.8556
# Epoch 201/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6796 - g_loss: 0.8543
# Epoch 202/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6772 - g_loss: 0.8534
# Epoch 203/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6782 - g_loss: 0.8541
# Epoch 204/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6799 - g_loss: 0.8538
# Epoch 205/500
# 20/20 [==============================] - 2s 122ms/step - d_loss: 0.6796 - g_loss: 0.8535
# Epoch 206/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6795 - g_loss: 0.8537
# Epoch 207/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6785 - g_loss: 0.8543
# Epoch 208/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6802 - g_loss: 0.8551
# Epoch 209/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6773 - g_loss: 0.8564
# Epoch 210/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6819 - g_loss: 0.8575
# Epoch 211/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6794 - g_loss: 0.8591
# Epoch 212/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6805 - g_loss: 0.8597
# Epoch 213/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6787 - g_loss: 0.8603
# Epoch 214/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6799 - g_loss: 0.8602
# Epoch 215/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6792 - g_loss: 0.8592
# Epoch 216/500
# 20/20 [==============================] - 2s 120ms/step - d_loss: 0.6781 - g_loss: 0.8590
# Epoch 217/500
# 20/20 [==============================] - 2s 118ms/step - d_loss: 0.6799 - g_loss: 0.8594
# Epoch 218/500
# 20/20 [==============================] - 2s 119ms/step - d_loss: 0.6782 - g_loss: 0.8592
# Epoch 219/500
# 20/20 [==============================] - 2s 119ms/step - d_loss: 0.6786 - g_loss: 0.8590
# Epoch 220/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6790 - g_loss: 0.8578
# Epoch 221/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6792 - g_loss: 0.8564
# Epoch 222/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6797 - g_loss: 0.8562
# Epoch 223/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6788 - g_loss: 0.8556
# Epoch 224/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6788 - g_loss: 0.8540
# Epoch 225/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6809 - g_loss: 0.8540
# Epoch 226/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6766 - g_loss: 0.8541
# Epoch 227/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6812 - g_loss: 0.8548
# Epoch 228/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6814 - g_loss: 0.8538
# Epoch 229/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6794 - g_loss: 0.8538
# Epoch 230/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6804 - g_loss: 0.8534
# Epoch 231/500
# 20/20 [==============================] - 2s 110ms/step - d_loss: 0.6792 - g_loss: 0.8533
# Epoch 232/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6816 - g_loss: 0.8535
# Epoch 233/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6786 - g_loss: 0.8533
# Epoch 234/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6790 - g_loss: 0.8535
# Epoch 235/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6774 - g_loss: 0.8547
# Epoch 236/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6787 - g_loss: 0.8550
# Epoch 237/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6798 - g_loss: 0.8544
# Epoch 238/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6812 - g_loss: 0.8538
# Epoch 239/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6803 - g_loss: 0.8539
# Epoch 240/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6796 - g_loss: 0.8552
# Epoch 241/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6788 - g_loss: 0.8559
# Epoch 242/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6794 - g_loss: 0.8565
# Epoch 243/500
# 20/20 [==============================] - 2s 123ms/step - d_loss: 0.6786 - g_loss: 0.8580
# Epoch 244/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6752 - g_loss: 0.8587
# Epoch 245/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6800 - g_loss: 0.8597
# Epoch 246/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6781 - g_loss: 0.8601
# Epoch 247/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6752 - g_loss: 0.8596
# Epoch 248/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6779 - g_loss: 0.8590
# Epoch 249/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6789 - g_loss: 0.8558
# Epoch 250/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6800 - g_loss: 0.8526
# Epoch 251/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6782 - g_loss: 0.8519
# Epoch 252/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6783 - g_loss: 0.8521
# Epoch 253/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6792 - g_loss: 0.8516
# Epoch 254/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6795 - g_loss: 0.8514
# Epoch 255/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6765 - g_loss: 0.8503
# Epoch 256/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6804 - g_loss: 0.8492
# Epoch 257/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6782 - g_loss: 0.8485
# Epoch 258/500
# 20/20 [==============================] - 2s 120ms/step - d_loss: 0.6775 - g_loss: 0.8492
# Epoch 259/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6788 - g_loss: 0.8507
# Epoch 260/500
# 20/20 [==============================] - 2s 124ms/step - d_loss: 0.6789 - g_loss: 0.8498
# Epoch 261/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6817 - g_loss: 0.8490
# Epoch 262/500
# 20/20 [==============================] - 2s 117ms/step - d_loss: 0.6806 - g_loss: 0.8466
# Epoch 263/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6808 - g_loss: 0.8451
# Epoch 264/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6826 - g_loss: 0.8452
# Epoch 265/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6779 - g_loss: 0.8460
# Epoch 266/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6805 - g_loss: 0.8489
# Epoch 267/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6821 - g_loss: 0.8500
# Epoch 268/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6821 - g_loss: 0.8500
# Epoch 269/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6790 - g_loss: 0.8501
# Epoch 270/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6810 - g_loss: 0.8511
# Epoch 271/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6804 - g_loss: 0.8519
# Epoch 272/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6801 - g_loss: 0.8509
# Epoch 273/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6809 - g_loss: 0.8493
# Epoch 274/500
# 20/20 [==============================] - 2s 122ms/step - d_loss: 0.6805 - g_loss: 0.8484
# Epoch 275/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6780 - g_loss: 0.8479
# Epoch 276/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6810 - g_loss: 0.8479
# Epoch 277/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6799 - g_loss: 0.8470
# Epoch 278/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6776 - g_loss: 0.8465
# Epoch 279/500
# 20/20 [==============================] - 2s 121ms/step - d_loss: 0.6796 - g_loss: 0.8477
# Epoch 280/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6796 - g_loss: 0.8475
# Epoch 281/500
# 20/20 [==============================] - 2s 117ms/step - d_loss: 0.6824 - g_loss: 0.8460
# Epoch 282/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6785 - g_loss: 0.8444
# Epoch 283/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6821 - g_loss: 0.8450
# Epoch 284/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6786 - g_loss: 0.8465
# Epoch 285/500
# 20/20 [==============================] - 2s 122ms/step - d_loss: 0.6823 - g_loss: 0.8475
# Epoch 286/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6777 - g_loss: 0.8492
# Epoch 287/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6820 - g_loss: 0.8504
# Epoch 288/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6800 - g_loss: 0.8501
# Epoch 289/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6815 - g_loss: 0.8504
# Epoch 290/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6803 - g_loss: 0.8492
# Epoch 291/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6802 - g_loss: 0.8479
# Epoch 292/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6798 - g_loss: 0.8480
# Epoch 293/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6783 - g_loss: 0.8486
# Epoch 294/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6841 - g_loss: 0.8481
# Epoch 295/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6800 - g_loss: 0.8484
# Epoch 296/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6767 - g_loss: 0.8504
# Epoch 297/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6802 - g_loss: 0.8524
# Epoch 298/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6784 - g_loss: 0.8521
# Epoch 299/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6814 - g_loss: 0.8520
# Epoch 300/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6786 - g_loss: 0.8519
# Epoch 301/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6799 - g_loss: 0.8505
# Epoch 302/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6786 - g_loss: 0.8494
# Epoch 303/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6789 - g_loss: 0.8501
# Epoch 304/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6790 - g_loss: 0.8509
# Epoch 305/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6809 - g_loss: 0.8514
# Epoch 306/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6806 - g_loss: 0.8508
# Epoch 307/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6797 - g_loss: 0.8497
# Epoch 308/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6813 - g_loss: 0.8494
# Epoch 309/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6787 - g_loss: 0.8485
# Epoch 310/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6817 - g_loss: 0.8490
# Epoch 311/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6769 - g_loss: 0.8468
# Epoch 312/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6780 - g_loss: 0.8470
# Epoch 313/500
# 20/20 [==============================] - 2s 121ms/step - d_loss: 0.6798 - g_loss: 0.8481
# Epoch 314/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6770 - g_loss: 0.8483
# Epoch 315/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6797 - g_loss: 0.8498
# Epoch 316/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6797 - g_loss: 0.8494
# Epoch 317/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6806 - g_loss: 0.8489
# Epoch 318/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6770 - g_loss: 0.8498
# Epoch 319/500
# 20/20 [==============================] - 2s 117ms/step - d_loss: 0.6771 - g_loss: 0.8523
# Epoch 320/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6771 - g_loss: 0.8527
# Epoch 321/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6782 - g_loss: 0.8529
# Epoch 322/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6788 - g_loss: 0.8530
# Epoch 323/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6778 - g_loss: 0.8520
# Epoch 324/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6789 - g_loss: 0.8521
# Epoch 325/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6795 - g_loss: 0.8521
# Epoch 326/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6807 - g_loss: 0.8503
# Epoch 327/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6804 - g_loss: 0.8485
# Epoch 328/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6795 - g_loss: 0.8480
# Epoch 329/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6814 - g_loss: 0.8484
# Epoch 330/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6803 - g_loss: 0.8489
# Epoch 331/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6785 - g_loss: 0.8506
# Epoch 332/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6793 - g_loss: 0.8509
# Epoch 333/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6797 - g_loss: 0.8501
# Epoch 334/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6813 - g_loss: 0.8494
# Epoch 335/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6786 - g_loss: 0.8487
# Epoch 336/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6794 - g_loss: 0.8510
# Epoch 337/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6795 - g_loss: 0.8525
# Epoch 338/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6791 - g_loss: 0.8530
# Epoch 339/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6801 - g_loss: 0.8527
# Epoch 340/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6799 - g_loss: 0.8517
# Epoch 341/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6784 - g_loss: 0.8512
# Epoch 342/500
# 20/20 [==============================] - 2s 117ms/step - d_loss: 0.6810 - g_loss: 0.8508
# Epoch 343/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6798 - g_loss: 0.8502
# Epoch 344/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6785 - g_loss: 0.8495
# Epoch 345/500
# 20/20 [==============================] - 2s 122ms/step - d_loss: 0.6784 - g_loss: 0.8481
# Epoch 346/500
# 20/20 [==============================] - 3s 124ms/step - d_loss: 0.6792 - g_loss: 0.8465
# Epoch 347/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6791 - g_loss: 0.8472
# Epoch 348/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6774 - g_loss: 0.8479
# Epoch 349/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6801 - g_loss: 0.8483
# Epoch 350/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6757 - g_loss: 0.8494
# Epoch 351/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6792 - g_loss: 0.8507
# Epoch 352/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6835 - g_loss: 0.8495
# Epoch 353/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6803 - g_loss: 0.8472
# Epoch 354/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6797 - g_loss: 0.8464
# Epoch 355/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6763 - g_loss: 0.8476
# Epoch 356/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6804 - g_loss: 0.8502
# Epoch 357/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6802 - g_loss: 0.8507
# Epoch 358/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6807 - g_loss: 0.8511
# Epoch 359/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6805 - g_loss: 0.8508
# Epoch 360/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6785 - g_loss: 0.8501
# Epoch 361/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6833 - g_loss: 0.8503
# Epoch 362/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6782 - g_loss: 0.8497
# Epoch 363/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6773 - g_loss: 0.8489
# Epoch 364/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6760 - g_loss: 0.8492
# Epoch 365/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6783 - g_loss: 0.8514
# Epoch 366/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6815 - g_loss: 0.8512
# Epoch 367/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6791 - g_loss: 0.8493
# Epoch 368/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6781 - g_loss: 0.8488
# Epoch 369/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6800 - g_loss: 0.8492
# Epoch 370/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6817 - g_loss: 0.8488
# Epoch 371/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6816 - g_loss: 0.8471
# Epoch 372/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6786 - g_loss: 0.8475
# Epoch 373/500
# 20/20 [==============================] - 2s 118ms/step - d_loss: 0.6811 - g_loss: 0.8491
# Epoch 374/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6814 - g_loss: 0.8491
# Epoch 375/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6802 - g_loss: 0.8484
# Epoch 376/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6785 - g_loss: 0.8471
# Epoch 377/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6787 - g_loss: 0.8475
# Epoch 378/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6795 - g_loss: 0.8481
# Epoch 379/500
# 20/20 [==============================] - 2s 117ms/step - d_loss: 0.6796 - g_loss: 0.8480
# Epoch 380/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6795 - g_loss: 0.8485
# Epoch 381/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6783 - g_loss: 0.8493
# Epoch 382/500
# 20/20 [==============================] - 2s 121ms/step - d_loss: 0.6802 - g_loss: 0.8497
# Epoch 383/500
# 20/20 [==============================] - 4s 199ms/step - d_loss: 0.6825 - g_loss: 0.8500
# Epoch 384/500
# 20/20 [==============================] - 3s 166ms/step - d_loss: 0.6798 - g_loss: 0.8503
# Epoch 385/500
# 20/20 [==============================] - 3s 173ms/step - d_loss: 0.6771 - g_loss: 0.8507
# Epoch 386/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6802 - g_loss: 0.8516
# Epoch 387/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6807 - g_loss: 0.8518
# Epoch 388/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6766 - g_loss: 0.8519
# Epoch 389/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6815 - g_loss: 0.8525
# Epoch 390/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6781 - g_loss: 0.8513
# Epoch 391/500
# 20/20 [==============================] - 2s 117ms/step - d_loss: 0.6782 - g_loss: 0.8514
# Epoch 392/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6795 - g_loss: 0.8513
# Epoch 393/500
# 20/20 [==============================] - 2s 120ms/step - d_loss: 0.6791 - g_loss: 0.8518
# Epoch 394/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6804 - g_loss: 0.8517
# Epoch 395/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6819 - g_loss: 0.8504
# Epoch 396/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6794 - g_loss: 0.8496
# Epoch 397/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6784 - g_loss: 0.8490
# Epoch 398/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6800 - g_loss: 0.8491
# Epoch 399/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6770 - g_loss: 0.8501
# Epoch 400/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6782 - g_loss: 0.8514
# Epoch 401/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6811 - g_loss: 0.8509
# Epoch 402/500
# 20/20 [==============================] - 2s 119ms/step - d_loss: 0.6781 - g_loss: 0.8508
# Epoch 403/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6800 - g_loss: 0.8520
# Epoch 404/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6794 - g_loss: 0.8518
# Epoch 405/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6783 - g_loss: 0.8521
# Epoch 406/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6791 - g_loss: 0.8511
# Epoch 407/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6796 - g_loss: 0.8502
# Epoch 408/500
# 20/20 [==============================] - 2s 121ms/step - d_loss: 0.6787 - g_loss: 0.8505
# Epoch 409/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6792 - g_loss: 0.8506
# Epoch 410/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6800 - g_loss: 0.8492
# Epoch 411/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6796 - g_loss: 0.8482
# Epoch 412/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6790 - g_loss: 0.8490
# Epoch 413/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6785 - g_loss: 0.8503
# Epoch 414/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6798 - g_loss: 0.8520
# Epoch 415/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6770 - g_loss: 0.8506
# Epoch 416/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6807 - g_loss: 0.8490
# Epoch 417/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6802 - g_loss: 0.8479
# Epoch 418/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6770 - g_loss: 0.8476
# Epoch 419/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6777 - g_loss: 0.8497
# Epoch 420/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6797 - g_loss: 0.8505
# Epoch 421/500
# 20/20 [==============================] - 2s 117ms/step - d_loss: 0.6812 - g_loss: 0.8493
# Epoch 422/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6799 - g_loss: 0.8477
# Epoch 423/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6793 - g_loss: 0.8476
# Epoch 424/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6807 - g_loss: 0.8482
# Epoch 425/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6816 - g_loss: 0.8484
# Epoch 426/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6817 - g_loss: 0.8475
# Epoch 427/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6779 - g_loss: 0.8465
# Epoch 428/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6810 - g_loss: 0.8476
# Epoch 429/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6774 - g_loss: 0.8495
# Epoch 430/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6780 - g_loss: 0.8509
# Epoch 431/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6818 - g_loss: 0.8507
# Epoch 432/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6766 - g_loss: 0.8501
# Epoch 433/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6796 - g_loss: 0.8504
# Epoch 434/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6783 - g_loss: 0.8509
# Epoch 435/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6807 - g_loss: 0.8506
# Epoch 436/500
# 20/20 [==============================] - 2s 124ms/step - d_loss: 0.6781 - g_loss: 0.8500
# Epoch 437/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6791 - g_loss: 0.8512
# Epoch 438/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6758 - g_loss: 0.8536
# Epoch 439/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6780 - g_loss: 0.8554
# Epoch 440/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6798 - g_loss: 0.8547
# Epoch 441/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6796 - g_loss: 0.8525
# Epoch 442/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6792 - g_loss: 0.8512
# Epoch 443/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6787 - g_loss: 0.8511
# Epoch 444/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6786 - g_loss: 0.8519
# Epoch 445/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6806 - g_loss: 0.8525
# Epoch 446/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6786 - g_loss: 0.8533
# Epoch 447/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6785 - g_loss: 0.8539
# Epoch 448/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6783 - g_loss: 0.8539
# Epoch 449/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6810 - g_loss: 0.8524
# Epoch 450/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6808 - g_loss: 0.8515
# Epoch 451/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6811 - g_loss: 0.8510
# Epoch 452/500
# 20/20 [==============================] - 2s 119ms/step - d_loss: 0.6814 - g_loss: 0.8512
# Epoch 453/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6795 - g_loss: 0.8525
# Epoch 454/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6805 - g_loss: 0.8515
# Epoch 455/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6788 - g_loss: 0.8502
# Epoch 456/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6784 - g_loss: 0.8506
# Epoch 457/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6781 - g_loss: 0.8509
# Epoch 458/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6775 - g_loss: 0.8513
# Epoch 459/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6784 - g_loss: 0.8507
# Epoch 460/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6804 - g_loss: 0.8504
# Epoch 461/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6793 - g_loss: 0.8503
# Epoch 462/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6797 - g_loss: 0.8508
# Epoch 463/500
# 20/20 [==============================] - 2s 119ms/step - d_loss: 0.6778 - g_loss: 0.8513
# Epoch 464/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6795 - g_loss: 0.8510
# Epoch 465/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6802 - g_loss: 0.8505
# Epoch 466/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6775 - g_loss: 0.8504
# Epoch 467/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6784 - g_loss: 0.8505
# Epoch 468/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6787 - g_loss: 0.8509
# Epoch 469/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6800 - g_loss: 0.8514
# Epoch 470/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6792 - g_loss: 0.8512
# Epoch 471/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6800 - g_loss: 0.8512
# Epoch 472/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6800 - g_loss: 0.8517
# Epoch 473/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6806 - g_loss: 0.8527
# Epoch 474/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6781 - g_loss: 0.8521
# Epoch 475/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6782 - g_loss: 0.8517
# Epoch 476/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6808 - g_loss: 0.8516
# Epoch 477/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6796 - g_loss: 0.8516
# Epoch 478/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6795 - g_loss: 0.8523
# Epoch 479/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6770 - g_loss: 0.8523
# Epoch 480/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6769 - g_loss: 0.8524
# Epoch 481/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6783 - g_loss: 0.8518
# Epoch 482/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6815 - g_loss: 0.8515
# Epoch 483/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6773 - g_loss: 0.8516
# Epoch 484/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6814 - g_loss: 0.8521
# Epoch 485/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6805 - g_loss: 0.8507
# Epoch 486/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6794 - g_loss: 0.8495
# Epoch 487/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6823 - g_loss: 0.8497
# Epoch 488/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6771 - g_loss: 0.8502
# Epoch 489/500
# 20/20 [==============================] - 2s 117ms/step - d_loss: 0.6797 - g_loss: 0.8507
# Epoch 490/500
# 20/20 [==============================] - 2s 118ms/step - d_loss: 0.6823 - g_loss: 0.8499
# Epoch 491/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6821 - g_loss: 0.8486
# Epoch 492/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6789 - g_loss: 0.8479
# Epoch 493/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6794 - g_loss: 0.8483
# Epoch 494/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6788 - g_loss: 0.8490
# Epoch 495/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6814 - g_loss: 0.8501
# Epoch 496/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6803 - g_loss: 0.8502
# Epoch 497/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6792 - g_loss: 0.8504
# Epoch 498/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6784 - g_loss: 0.8511
# Epoch 499/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6811 - g_loss: 0.8513
# Epoch 500/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6820 - g_loss: 0.8498

# %%
if True:
    scenario_size = 30
    normal_noise = tf.random.normal((scenario_size, batch_size, 1))
    n = [np.random.normal() for _ in range(scenario_size)]
    series = np.multiply(generator.predict(normal_noise), max)
    resolution = 100

    probabilities = []
    ranges = np.linspace(-3.5, 3.5, 8)
    intervals = np.linspace(-3, 3, 7)
    probs = [stats.norm.cdf(i) for i in n]
    prob_ranges = {intervals[i]: [stats.norm.cdf(ranges[i]), stats.norm.cdf(ranges[i+1])] for i in range(len(intervals))}
    for i in probs:
        for key in intervals:
            if prob_ranges[key][0]<= i <=prob_ranges[key][1]:
                probabilities.append(prob_ranges[key][1]-prob_ranges[key][0])
                break
    scenarios = {'probs': probabilities}
    for j in range(resolution):
        scenarios[j] = []
    for i in range(scenario_size):
        s = series[i].reshape([resolution])
        for j in range(resolution):
            scenarios[j].append(s[j])
pd.DataFrame(scenarios).to_csv(f'LoadScenarios-{month_name}-{day_type}.csv')
if True:
    ticks = [i for i in range(resolution) if i%4 == 0]
    fig, ax = plt.subplots(1, 2, figsize=(15, 4), dpi=200)
    for s in series[:3]:
        ax[0].plot(range(resolution), s.reshape([resolution]), linewidth=1)
    ax[0].set_xlabel('Timestamp (15 min)')
    ax[0].set_ylabel('Generated Power Consumption')
    ax[0].set_xticks(ticks, ticks)
    ax[0].grid(color='#666362', linestyle='-', linewidth=0.1)

    if day_type == 'w':
        ax[1].plot(my_data[[c for c in my_data.columns if 'weekday' in c][:3]], linewidth=1)
    else:
        ax[1].plot(my_data[[c for c in my_data.columns if 'weekend' in c][:3]], linewidth=1)
    ax[1].set_xlabel('Timestamp (15 min)')
    ax[1].set_ylabel('Historical Power Consumption')
    ax[1].set_xticks(ticks, ticks)
    ax[1].grid(color='#666362', linestyle='-', linewidth=0.1)
    plt.subplots_adjust(wspace=0.1)
# plt.savefig(f'IMG/{month_name}-{day_type}.jpg', bbox_inches='tight')
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %% [markdown]
# ### Save models

# %%
generator.save(f'HarrisCounty/GAN Models/generator-{month_name}-{day_type}.h5')
discriminator.save(f'HarrisCounty/GAN Models/discriminator-{month_name}-{day_type}.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
plt.figure(figsize=(7, 3), dpi=300)
plt.plot(hist.history['d_loss'], label='Generator Loss')
plt.plot(hist.history['g_loss'], label='Discriminator Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(color='#666362', linestyle='-', linewidth=0.1)
plt.savefig(f'IMG/{month_name}-{day_type}-loss.jpg', bbox_inches='tight')

# %%
import tensorflow as tf
from keras import layers, Model
import numpy as np
import datetime
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
from keras.callbacks import Callback
from keras.utils import array_to_img
from keras import Sequential
from keras.layers import Conv2D, Dense, Flatten, Reshape, LeakyReLU, Dropout, UpSampling1D
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from keras.models import Model

gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.reset_memory_stats(gpu, True)
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('ignore')

c = pd.read_csv('../../../Visualizations/color.csv')['color']

# %%
month_name='JanFeb'
day_type = 'e'
my_data = pd.read_csv(f'ForGAN/{month_name}.csv')
ds = []
if day_type == 'w':
    for c in my_data.columns:
        if 'weekday' in c:
            ds.append([my_data[c].values])
else:
    for c in my_data.columns:
        if 'weekend' in c:
            ds.append([my_data[c].values])

max = np.max(ds)
ds = np.divide(ds, max)

# %% [markdown]
# ### Prepare data to feed into GAN

# %%
ds = tf.data.Dataset.from_tensor_slices(ds)
batch_size = 12
ds = ds.cache()
ds = ds.shuffle(1000)
ds = ds.batch(batch_size)
ds = ds.prefetch(64)

# %% [markdown]
# ## Generator

# %%
g_relu = 0.2
if day_type == 'w':
    def build_generator():
        model = Sequential()

        model.add(Dense(1*96*batch_size, input_dim=batch_size))
        model.add(LeakyReLU(g_relu))
        model.add(Reshape((1,96, batch_size)))

        #model.add(UpSamplingD())
        model.add(Conv2D(batch_size, 3, padding='same'))
        model.add(LeakyReLU(g_relu))

        model.add(Conv2D(batch_size, 3, padding='same'))
        model.add(LeakyReLU(g_relu))

        model.add(Conv2D(batch_size, 3, padding='same'))
        model.add(LeakyReLU(g_relu))

        model.add(Conv2D(batch_size, 3, padding='same'))
        model.add(LeakyReLU(g_relu))

        model.add(Conv2D(1, 5, padding='same', activation='sigmoid'))
        return model
    generator = build_generator()
    generator.summary()
else:
    def build_generator():
            model = Sequential()

            model.add(Dense(1*96*batch_size, input_dim=batch_size))
            model.add(LeakyReLU(g_relu))
            model.add(Reshape((1,96, batch_size)))

            #model.add(UpSamplingD())
            model.add(Conv2D(batch_size, 5, padding='same'))
            model.add(LeakyReLU(g_relu))

            model.add(Conv2D(batch_size, 5, padding='same'))
            model.add(LeakyReLU(g_relu))

            model.add(Conv2D(batch_size, 5, padding='same'))
            model.add(LeakyReLU(g_relu))

            model.add(Conv2D(1, 5, padding='same', activation='sigmoid'))
            return model
    generator = build_generator()
    generator.summary()
# series = generator.predict(np.random.randn(4, 6, 1))
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_17 (Dense)            (None, 1152)              14976
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 1152)              0
#
#  reshape_5 (Reshape)         (None, 1, 96, 12)         0
#
#  conv2d_20 (Conv2D)          (None, 1, 96, 12)         3612
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 1, 96, 12)         0
#
#  conv2d_21 (Conv2D)          (None, 1, 96, 12)         3612
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 1, 96, 12)         0
#
#  conv2d_22 (Conv2D)          (None, 1, 96, 12)         3612
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 1, 96, 12)         0
#
#  conv2d_23 (Conv2D)          (None, 1, 96, 1)          301
#
# =================================================================
# Total params: 26,113
# Trainable params: 26,113
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Discriminator

# %%
d_relu = 0.2
d_dropout = 0.2
if day_type == 'w':
    def build_discriminator():
        model = Sequential()

        model.add(Dense(200, input_shape=(1, 96, 1)))
        model.add(LeakyReLU(d_relu))
        model.add(Dropout(d_dropout))

        model.add(Dense(150))
        model.add(LeakyReLU(d_relu))
        model.add(Dropout(d_dropout))

        model.add(Flatten())
        model.add(Dropout(d_dropout))
        model.add(Dense(1, activation='sigmoid'))
        # 1: fake series, 0: real series

        return model
    discriminator = build_discriminator()
    discriminator.summary()
else:
    def build_discriminator():
            model = Sequential()

            model.add(Dense(100, input_shape=(1, 96, 1)))
            model.add(LeakyReLU(d_relu))
            model.add(Dropout(d_dropout))

            model.add(Dense(120))
            model.add(LeakyReLU(d_relu))
            model.add(Dropout(d_dropout))

            model.add(Flatten())
            model.add(Dropout(d_dropout))
            model.add(Dense(1, activation='sigmoid'))
            # 1: fake series, 0: real series

            return model
    discriminator = build_discriminator()
    discriminator.summary()
# Single prediction needs np.expand_dims(series[0], 0)
# discriminator.predict(np.expand_dims(series[0], 0))
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 1, 96, 100)        200
#
#  leaky_re_lu_32 (LeakyReLU)  (None, 1, 96, 100)        0
#
#  dropout_12 (Dropout)        (None, 1, 96, 100)        0
#
#  dense_19 (Dense)            (None, 1, 96, 120)        12120
#
#  leaky_re_lu_33 (LeakyReLU)  (None, 1, 96, 120)        0
#
#  dropout_13 (Dropout)        (None, 1, 96, 120)        0
#
#  flatten_4 (Flatten)         (None, 11520)             0
#
#  dropout_14 (Dropout)        (None, 11520)             0
#
#  dense_20 (Dense)            (None, 1)                 11521
#
# =================================================================
# Total params: 23,841
# Trainable params: 23,841
# Non-trainable params: 0
# _________________________________________________________________

# %%
g_a, d_a = 0.0001, 0.00001
g_opt = Adam(learning_rate=g_a)
d_opt = Adam(learning_rate=d_a)  # Does not learn too fast
g_loss = BinaryCrossentropy()
d_loss = BinaryCrossentropy()
class LoadGAN(Model):
    def __init__(self, generator, discriminator, *args, **kwargs):
        # pass through args and kwargs to base class
        super().__init__(*args, **kwargs)
        # Create attributes for gen and disc
        self.generator = generator
        self.discriminator = discriminator

    def compilee(self, g_opt, d_opt, g_loss, d_loss, *args, **kwargs):
        # Compile with base class
        super().compile(*args, **kwargs)

        self.g_opt = g_opt
        self.d_opt = d_opt
        self.g_loss = g_loss
        self.d_loss = d_loss

    def train_step(self, batch):
        real_series = batch
        fake_series = self.generator(tf.random.normal((batch_size, batch_size, 1)), training=False)

        # train the discriminator
        with tf.GradientTape() as d_tape:
            # pass the real and fake images
            yhat_real = self.discriminator(real_series, training=True)
            yhat_fake = self.discriminator(fake_series, training=True)
            yhat_realfake = tf.concat([yhat_real, yhat_fake], axis=0)

            # create labels for real and fake series
            y_realfake = tf.concat([tf.zeros_like(yhat_real), tf.ones_like(yhat_fake)], axis=0)


            # pass through and add some noise to the outputs
            noise_real = 0.15*tf.random.uniform(tf.shape(yhat_real))
            noise_fake = 0.15*tf.random.uniform(tf.shape(yhat_fake))
            y_realfake += tf.concat([noise_real, noise_fake], axis=0)

            # calculate the loss
            total_d_loss = self.d_loss(y_realfake, yhat_realfake)

        # apply backpropagation
        dgrad = d_tape.gradient(total_d_loss, self.discriminator.trainable_variables)
        self.d_opt.apply_gradients(zip(dgrad, self.discriminator.trainable_variables))

        # Generator training
        with tf.GradientTape() as g_tape:
            # generate same new images
            gen_series = self.generator(tf.random.normal((batch_size, batch_size, 1)), training=True)

            # create the predicted labels
            predicted_labels = self.discriminator(gen_series, training=False)

            # calculate loss
            total_g_loss = self.g_loss(tf.zeros_like(predicted_labels), predicted_labels)

        # apply backpropagation
        ggrad = g_tape.gradient(total_g_loss, self.generator.trainable_variables)
        self.g_opt.apply_gradients(zip(ggrad, self.generator.trainable_variables))

        return {"d_loss":total_d_loss, "g_loss":total_g_loss}
loadgan = LoadGAN(generator, discriminator)
loadgan.compilee(g_opt, d_opt, g_loss, d_loss)

# %% [markdown]
# #### Call Back

# %%
class ModelMonitor(Callback):
    def __init__(self, num_img=3, latent_dim=batch_size):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vector = tf.random.uniform((self.num_img, self.latent_dim, 1))
        generated_series = self.model.generator(random_latent_vector)
        generated_series *= max
        generated_series.numpy()
        for i in range(self.num_img):
            serie = array_to_img(generated_series[i])

# %% [markdown]
# #### Train

# %%
hist = loadgan.fit(ds, epochs=500)
# Out:
# Epoch 1/500
# 20/20 [==============================] - 3s 154ms/step - d_loss: 0.6946 - g_loss: 0.6884
# Epoch 2/500
# 20/20 [==============================] - 3s 147ms/step - d_loss: 0.6928 - g_loss: 0.7034
# Epoch 3/500
# 20/20 [==============================] - 3s 148ms/step - d_loss: 0.6861 - g_loss: 0.7179
# Epoch 4/500
# 20/20 [==============================] - 3s 150ms/step - d_loss: 0.6874 - g_loss: 0.7310
# Epoch 5/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6815 - g_loss: 0.7430
# Epoch 6/500
# 20/20 [==============================] - 3s 147ms/step - d_loss: 0.6792 - g_loss: 0.7528
# Epoch 7/500
# 20/20 [==============================] - 3s 149ms/step - d_loss: 0.6821 - g_loss: 0.7595
# Epoch 8/500
# 20/20 [==============================] - 3s 151ms/step - d_loss: 0.6796 - g_loss: 0.7617
# Epoch 9/500
# 20/20 [==============================] - 3s 149ms/step - d_loss: 0.6818 - g_loss: 0.7578
# Epoch 10/500
# 20/20 [==============================] - 3s 147ms/step - d_loss: 0.6880 - g_loss: 0.7454
# Epoch 11/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6981 - g_loss: 0.7254
# Epoch 12/500
# 20/20 [==============================] - 3s 149ms/step - d_loss: 0.6990 - g_loss: 0.7046
# Epoch 13/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6988 - g_loss: 0.6901
# Epoch 14/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6943 - g_loss: 0.6793
# Epoch 15/500
# 20/20 [==============================] - 3s 150ms/step - d_loss: 0.6899 - g_loss: 0.6689
# Epoch 16/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6884 - g_loss: 0.6572
# Epoch 17/500
# 20/20 [==============================] - 4s 185ms/step - d_loss: 0.6919 - g_loss: 0.6468
# Epoch 18/500
# 20/20 [==============================] - 4s 198ms/step - d_loss: 0.6902 - g_loss: 0.6396
# Epoch 19/500
# 20/20 [==============================] - 4s 202ms/step - d_loss: 0.6937 - g_loss: 0.6355
# Epoch 20/500
# 20/20 [==============================] - 4s 205ms/step - d_loss: 0.6943 - g_loss: 0.6356
# Epoch 21/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6929 - g_loss: 0.6402
# Epoch 22/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6953 - g_loss: 0.6464
# Epoch 23/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6947 - g_loss: 0.6548
# Epoch 24/500
# 20/20 [==============================] - 2s 120ms/step - d_loss: 0.6914 - g_loss: 0.6634
# Epoch 25/500
# 20/20 [==============================] - 2s 120ms/step - d_loss: 0.6909 - g_loss: 0.6716
# Epoch 26/500
# 20/20 [==============================] - 2s 122ms/step - d_loss: 0.6912 - g_loss: 0.6780
# Epoch 27/500
# 20/20 [==============================] - 2s 122ms/step - d_loss: 0.6916 - g_loss: 0.6829
# Epoch 28/500
# 20/20 [==============================] - 2s 120ms/step - d_loss: 0.6893 - g_loss: 0.6858
# Epoch 29/500
# 20/20 [==============================] - 2s 122ms/step - d_loss: 0.6908 - g_loss: 0.6872
# Epoch 30/500
# 20/20 [==============================] - 2s 124ms/step - d_loss: 0.6923 - g_loss: 0.6882
# Epoch 31/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6917 - g_loss: 0.6889
# Epoch 32/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6911 - g_loss: 0.6901
# Epoch 33/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6892 - g_loss: 0.6922
# Epoch 34/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6889 - g_loss: 0.6950
# Epoch 35/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6883 - g_loss: 0.6996
# Epoch 36/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6877 - g_loss: 0.7052
# Epoch 37/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6871 - g_loss: 0.7146
# Epoch 38/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6850 - g_loss: 0.7273
# Epoch 39/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6846 - g_loss: 0.7447
# Epoch 40/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6820 - g_loss: 0.7652
# Epoch 41/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6815 - g_loss: 0.7806
# Epoch 42/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6874 - g_loss: 0.7847
# Epoch 43/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6869 - g_loss: 0.7813
# Epoch 44/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6914 - g_loss: 0.7743
# Epoch 45/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6935 - g_loss: 0.7661
# Epoch 46/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6896 - g_loss: 0.7596
# Epoch 47/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6836 - g_loss: 0.7534
# Epoch 48/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6854 - g_loss: 0.7464
# Epoch 49/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6868 - g_loss: 0.7357
# Epoch 50/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6926 - g_loss: 0.7293
# Epoch 51/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6936 - g_loss: 0.7382
# Epoch 52/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6850 - g_loss: 0.7719
# Epoch 53/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6732 - g_loss: 0.8193
# Epoch 54/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6702 - g_loss: 0.8568
# Epoch 55/500
# 20/20 [==============================] - 3s 152ms/step - d_loss: 0.6708 - g_loss: 0.8715
# Epoch 56/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6795 - g_loss: 0.8646
# Epoch 57/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6862 - g_loss: 0.8445
# Epoch 58/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6894 - g_loss: 0.8210
# Epoch 59/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6925 - g_loss: 0.8011
# Epoch 60/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6842 - g_loss: 0.7880
# Epoch 61/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6751 - g_loss: 0.7796
# Epoch 62/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6687 - g_loss: 0.7721
# Epoch 63/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6633 - g_loss: 0.7630
# Epoch 64/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6657 - g_loss: 0.7459
# Epoch 65/500
# 20/20 [==============================] - 3s 130ms/step - d_loss: 0.6783 - g_loss: 0.7243
# Epoch 66/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6849 - g_loss: 0.7098
# Epoch 67/500
# 20/20 [==============================] - 3s 171ms/step - d_loss: 0.6907 - g_loss: 0.7128
# Epoch 68/500
# 20/20 [==============================] - 3s 152ms/step - d_loss: 0.6903 - g_loss: 0.7325
# Epoch 69/500
# 20/20 [==============================] - 3s 153ms/step - d_loss: 0.6839 - g_loss: 0.7630
# Epoch 70/500
# 20/20 [==============================] - 4s 183ms/step - d_loss: 0.6774 - g_loss: 0.7988
# Epoch 71/500
# 20/20 [==============================] - 3s 174ms/step - d_loss: 0.6699 - g_loss: 0.8334
# Epoch 72/500
# 20/20 [==============================] - 4s 177ms/step - d_loss: 0.6666 - g_loss: 0.8613
# Epoch 73/500
# 20/20 [==============================] - 4s 179ms/step - d_loss: 0.6644 - g_loss: 0.8788
# Epoch 74/500
# 20/20 [==============================] - 4s 176ms/step - d_loss: 0.6690 - g_loss: 0.8834
# Epoch 75/500
# 20/20 [==============================] - 3s 173ms/step - d_loss: 0.6715 - g_loss: 0.8793
# Epoch 76/500
# 20/20 [==============================] - 3s 170ms/step - d_loss: 0.6774 - g_loss: 0.8693
# Epoch 77/500
# 20/20 [==============================] - 3s 146ms/step - d_loss: 0.6785 - g_loss: 0.8540
# Epoch 78/500
# 20/20 [==============================] - 3s 167ms/step - d_loss: 0.6815 - g_loss: 0.8365
# Epoch 79/500
# 20/20 [==============================] - 3s 164ms/step - d_loss: 0.6855 - g_loss: 0.8230
# Epoch 80/500
# 20/20 [==============================] - 3s 157ms/step - d_loss: 0.6829 - g_loss: 0.8103
# Epoch 81/500
# 20/20 [==============================] - 3s 155ms/step - d_loss: 0.6811 - g_loss: 0.8008
# Epoch 82/500
# 20/20 [==============================] - 3s 158ms/step - d_loss: 0.6783 - g_loss: 0.7930
# Epoch 83/500
# 20/20 [==============================] - 3s 155ms/step - d_loss: 0.6760 - g_loss: 0.7871
# Epoch 84/500
# 20/20 [==============================] - 3s 166ms/step - d_loss: 0.6771 - g_loss: 0.7833
# Epoch 85/500
# 20/20 [==============================] - 5s 235ms/step - d_loss: 0.6742 - g_loss: 0.7836
# Epoch 86/500
# 20/20 [==============================] - 3s 165ms/step - d_loss: 0.6761 - g_loss: 0.7879
# Epoch 87/500
# 20/20 [==============================] - 4s 198ms/step - d_loss: 0.6760 - g_loss: 0.7972
# Epoch 88/500
# 20/20 [==============================] - 4s 191ms/step - d_loss: 0.6712 - g_loss: 0.8093
# Epoch 89/500
# 20/20 [==============================] - 4s 180ms/step - d_loss: 0.6686 - g_loss: 0.8208
# Epoch 90/500
# 20/20 [==============================] - 4s 182ms/step - d_loss: 0.6740 - g_loss: 0.8345
# Epoch 91/500
# 20/20 [==============================] - 4s 181ms/step - d_loss: 0.6707 - g_loss: 0.8476
# Epoch 92/500
# 20/20 [==============================] - 4s 180ms/step - d_loss: 0.6740 - g_loss: 0.8560
# Epoch 93/500
# 20/20 [==============================] - 3s 165ms/step - d_loss: 0.6724 - g_loss: 0.8591
# Epoch 94/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6753 - g_loss: 0.8602
# Epoch 95/500
# 20/20 [==============================] - 3s 140ms/step - d_loss: 0.6764 - g_loss: 0.8623
# Epoch 96/500
# 20/20 [==============================] - 3s 151ms/step - d_loss: 0.6754 - g_loss: 0.8609
# Epoch 97/500
# 20/20 [==============================] - 3s 173ms/step - d_loss: 0.6784 - g_loss: 0.8616
# Epoch 98/500
# 20/20 [==============================] - 4s 180ms/step - d_loss: 0.6756 - g_loss: 0.8644
# Epoch 99/500
# 20/20 [==============================] - 4s 192ms/step - d_loss: 0.6772 - g_loss: 0.8676
# Epoch 100/500
# 20/20 [==============================] - 4s 183ms/step - d_loss: 0.6776 - g_loss: 0.8749
# Epoch 101/500
# 20/20 [==============================] - 4s 183ms/step - d_loss: 0.6779 - g_loss: 0.8811
# Epoch 102/500
# 20/20 [==============================] - 4s 181ms/step - d_loss: 0.6763 - g_loss: 0.8887
# Epoch 103/500
# 20/20 [==============================] - 4s 183ms/step - d_loss: 0.6750 - g_loss: 0.8948
# Epoch 104/500
# 20/20 [==============================] - 4s 183ms/step - d_loss: 0.6780 - g_loss: 0.8994
# Epoch 105/500
# 20/20 [==============================] - 4s 183ms/step - d_loss: 0.6722 - g_loss: 0.9017
# Epoch 106/500
# 20/20 [==============================] - 4s 187ms/step - d_loss: 0.6737 - g_loss: 0.9039
# Epoch 107/500
# 20/20 [==============================] - 4s 183ms/step - d_loss: 0.6757 - g_loss: 0.9027
# Epoch 108/500
# 20/20 [==============================] - 4s 184ms/step - d_loss: 0.6765 - g_loss: 0.9019
# Epoch 109/500
# 20/20 [==============================] - 4s 188ms/step - d_loss: 0.6718 - g_loss: 0.9000
# Epoch 110/500
# 20/20 [==============================] - 4s 186ms/step - d_loss: 0.6743 - g_loss: 0.8985
# Epoch 111/500
# 20/20 [==============================] - 4s 193ms/step - d_loss: 0.6741 - g_loss: 0.8978
# Epoch 112/500
# 20/20 [==============================] - 4s 188ms/step - d_loss: 0.6706 - g_loss: 0.8958
# Epoch 113/500
# 20/20 [==============================] - 4s 188ms/step - d_loss: 0.6734 - g_loss: 0.8941
# Epoch 114/500
# 20/20 [==============================] - 4s 201ms/step - d_loss: 0.6702 - g_loss: 0.8912
# Epoch 115/500
# 20/20 [==============================] - 4s 187ms/step - d_loss: 0.6682 - g_loss: 0.8877
# Epoch 116/500
# 20/20 [==============================] - 4s 189ms/step - d_loss: 0.6725 - g_loss: 0.8830
# Epoch 117/500
# 20/20 [==============================] - 4s 199ms/step - d_loss: 0.6720 - g_loss: 0.8779
# Epoch 118/500
# 20/20 [==============================] - 4s 189ms/step - d_loss: 0.6693 - g_loss: 0.8726
# Epoch 119/500
# 20/20 [==============================] - 4s 189ms/step - d_loss: 0.6703 - g_loss: 0.8678
# Epoch 120/500
# 20/20 [==============================] - 4s 190ms/step - d_loss: 0.6710 - g_loss: 0.8635
# Epoch 121/500
# 20/20 [==============================] - 4s 188ms/step - d_loss: 0.6715 - g_loss: 0.8604
# Epoch 122/500
# 20/20 [==============================] - 4s 187ms/step - d_loss: 0.6710 - g_loss: 0.8584
# Epoch 123/500
# 20/20 [==============================] - 4s 186ms/step - d_loss: 0.6708 - g_loss: 0.8567
# Epoch 124/500
# 20/20 [==============================] - 4s 184ms/step - d_loss: 0.6689 - g_loss: 0.8549
# Epoch 125/500
# 20/20 [==============================] - 4s 187ms/step - d_loss: 0.6712 - g_loss: 0.8519
# Epoch 126/500
# 20/20 [==============================] - 4s 188ms/step - d_loss: 0.6692 - g_loss: 0.8499
# Epoch 127/500
# 20/20 [==============================] - 4s 190ms/step - d_loss: 0.6721 - g_loss: 0.8488
# Epoch 128/500
# 20/20 [==============================] - 4s 187ms/step - d_loss: 0.6714 - g_loss: 0.8470
# Epoch 129/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6745 - g_loss: 0.8457
# Epoch 130/500
# 20/20 [==============================] - 3s 161ms/step - d_loss: 0.6716 - g_loss: 0.8441
# Epoch 131/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6730 - g_loss: 0.8422
# Epoch 132/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6718 - g_loss: 0.8404
# Epoch 133/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6752 - g_loss: 0.8388
# Epoch 134/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6728 - g_loss: 0.8381
# Epoch 135/500
# 20/20 [==============================] - 3s 146ms/step - d_loss: 0.6742 - g_loss: 0.8399
# Epoch 136/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6755 - g_loss: 0.8413
# Epoch 137/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6764 - g_loss: 0.8435
# Epoch 138/500
# 20/20 [==============================] - 2s 102ms/step - d_loss: 0.6785 - g_loss: 0.8465
# Epoch 139/500
# 20/20 [==============================] - 2s 120ms/step - d_loss: 0.6788 - g_loss: 0.8488
# Epoch 140/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6802 - g_loss: 0.8530
# Epoch 141/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6784 - g_loss: 0.8594
# Epoch 142/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6794 - g_loss: 0.8654
# Epoch 143/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6792 - g_loss: 0.8719
# Epoch 144/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6754 - g_loss: 0.8784
# Epoch 145/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6790 - g_loss: 0.8831
# Epoch 146/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6772 - g_loss: 0.8882
# Epoch 147/500
# 20/20 [==============================] - 3s 147ms/step - d_loss: 0.6807 - g_loss: 0.8901
# Epoch 148/500
# 20/20 [==============================] - 3s 150ms/step - d_loss: 0.6826 - g_loss: 0.8920
# Epoch 149/500
# 20/20 [==============================] - 3s 158ms/step - d_loss: 0.6790 - g_loss: 0.8927
# Epoch 150/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6760 - g_loss: 0.8927
# Epoch 151/500
# 20/20 [==============================] - 3s 146ms/step - d_loss: 0.6797 - g_loss: 0.8943
# Epoch 152/500
# 20/20 [==============================] - 3s 148ms/step - d_loss: 0.6797 - g_loss: 0.8949
# Epoch 153/500
# 20/20 [==============================] - 3s 148ms/step - d_loss: 0.6775 - g_loss: 0.8943
# Epoch 154/500
# 20/20 [==============================] - 3s 165ms/step - d_loss: 0.6798 - g_loss: 0.8938
# Epoch 155/500
# 20/20 [==============================] - 3s 150ms/step - d_loss: 0.6775 - g_loss: 0.8932
# Epoch 156/500
# 20/20 [==============================] - 3s 146ms/step - d_loss: 0.6778 - g_loss: 0.8917
# Epoch 157/500
# 20/20 [==============================] - 2s 110ms/step - d_loss: 0.6769 - g_loss: 0.8914
# Epoch 158/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6742 - g_loss: 0.8909
# Epoch 159/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6750 - g_loss: 0.8891
# Epoch 160/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6724 - g_loss: 0.8883
# Epoch 161/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6748 - g_loss: 0.8860
# Epoch 162/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6759 - g_loss: 0.8825
# Epoch 163/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6750 - g_loss: 0.8798
# Epoch 164/500
# 20/20 [==============================] - 2s 125ms/step - d_loss: 0.6770 - g_loss: 0.8787
# Epoch 165/500
# 20/20 [==============================] - 3s 150ms/step - d_loss: 0.6743 - g_loss: 0.8766
# Epoch 166/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6750 - g_loss: 0.8744
# Epoch 167/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6742 - g_loss: 0.8728
# Epoch 168/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6761 - g_loss: 0.8730
# Epoch 169/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6749 - g_loss: 0.8729
# Epoch 170/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6740 - g_loss: 0.8729
# Epoch 171/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6711 - g_loss: 0.8725
# Epoch 172/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6719 - g_loss: 0.8733
# Epoch 173/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6694 - g_loss: 0.8727
# Epoch 174/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6691 - g_loss: 0.8716
# Epoch 175/500
# 20/20 [==============================] - 3s 177ms/step - d_loss: 0.6694 - g_loss: 0.8701
# Epoch 176/500
# 20/20 [==============================] - 6s 269ms/step - d_loss: 0.6688 - g_loss: 0.8685
# Epoch 177/500
# 20/20 [==============================] - 4s 223ms/step - d_loss: 0.6730 - g_loss: 0.8655
# Epoch 178/500
# 20/20 [==============================] - 4s 205ms/step - d_loss: 0.6714 - g_loss: 0.8657
# Epoch 179/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6709 - g_loss: 0.8651
# Epoch 180/500
# 20/20 [==============================] - 3s 153ms/step - d_loss: 0.6708 - g_loss: 0.8649
# Epoch 181/500
# 20/20 [==============================] - 3s 157ms/step - d_loss: 0.6724 - g_loss: 0.8650
# Epoch 182/500
# 20/20 [==============================] - 3s 147ms/step - d_loss: 0.6687 - g_loss: 0.8665
# Epoch 183/500
# 20/20 [==============================] - 3s 153ms/step - d_loss: 0.6703 - g_loss: 0.8683
# Epoch 184/500
# 20/20 [==============================] - 3s 159ms/step - d_loss: 0.6748 - g_loss: 0.8717
# Epoch 185/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6718 - g_loss: 0.8728
# Epoch 186/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6760 - g_loss: 0.8773
# Epoch 187/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6737 - g_loss: 0.8818
# Epoch 188/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6741 - g_loss: 0.8858
# Epoch 189/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6773 - g_loss: 0.8893
# Epoch 190/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6743 - g_loss: 0.8929
# Epoch 191/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6757 - g_loss: 0.8967
# Epoch 192/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6760 - g_loss: 0.8987
# Epoch 193/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6787 - g_loss: 0.8992
# Epoch 194/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6738 - g_loss: 0.8986
# Epoch 195/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6742 - g_loss: 0.8966
# Epoch 196/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6760 - g_loss: 0.8956
# Epoch 197/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6781 - g_loss: 0.8935
# Epoch 198/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6791 - g_loss: 0.8905
# Epoch 199/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6744 - g_loss: 0.8873
# Epoch 200/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6752 - g_loss: 0.8840
# Epoch 201/500
# 20/20 [==============================] - 3s 153ms/step - d_loss: 0.6764 - g_loss: 0.8833
# Epoch 202/500
# 20/20 [==============================] - 3s 167ms/step - d_loss: 0.6746 - g_loss: 0.8821
# Epoch 203/500
# 20/20 [==============================] - 3s 140ms/step - d_loss: 0.6787 - g_loss: 0.8805
# Epoch 204/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6715 - g_loss: 0.8784
# Epoch 205/500
# 20/20 [==============================] - 3s 147ms/step - d_loss: 0.6725 - g_loss: 0.8781
# Epoch 206/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6742 - g_loss: 0.8764
# Epoch 207/500
# 20/20 [==============================] - 3s 140ms/step - d_loss: 0.6754 - g_loss: 0.8751
# Epoch 208/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6763 - g_loss: 0.8724
# Epoch 209/500
# 20/20 [==============================] - 3s 140ms/step - d_loss: 0.6752 - g_loss: 0.8698
# Epoch 210/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6747 - g_loss: 0.8688
# Epoch 211/500
# 20/20 [==============================] - 3s 132ms/step - d_loss: 0.6719 - g_loss: 0.8681
# Epoch 212/500
# 20/20 [==============================] - 3s 150ms/step - d_loss: 0.6728 - g_loss: 0.8679
# Epoch 213/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6714 - g_loss: 0.8674
# Epoch 214/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6759 - g_loss: 0.8658
# Epoch 215/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6761 - g_loss: 0.8649
# Epoch 216/500
# 20/20 [==============================] - 3s 150ms/step - d_loss: 0.6749 - g_loss: 0.8649
# Epoch 217/500
# 20/20 [==============================] - 3s 147ms/step - d_loss: 0.6737 - g_loss: 0.8645
# Epoch 218/500
# 20/20 [==============================] - 3s 146ms/step - d_loss: 0.6752 - g_loss: 0.8643
# Epoch 219/500
# 20/20 [==============================] - 3s 147ms/step - d_loss: 0.6756 - g_loss: 0.8643
# Epoch 220/500
# 20/20 [==============================] - 3s 137ms/step - d_loss: 0.6726 - g_loss: 0.8652
# Epoch 221/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6745 - g_loss: 0.8676
# Epoch 222/500
# 20/20 [==============================] - 2s 118ms/step - d_loss: 0.6730 - g_loss: 0.8702
# Epoch 223/500
# 20/20 [==============================] - 2s 119ms/step - d_loss: 0.6773 - g_loss: 0.8715
# Epoch 224/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6729 - g_loss: 0.8738
# Epoch 225/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6762 - g_loss: 0.8760
# Epoch 226/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6739 - g_loss: 0.8769
# Epoch 227/500
# 20/20 [==============================] - 2s 123ms/step - d_loss: 0.6752 - g_loss: 0.8783
# Epoch 228/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6714 - g_loss: 0.8802
# Epoch 229/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6742 - g_loss: 0.8830
# Epoch 230/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6733 - g_loss: 0.8852
# Epoch 231/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6732 - g_loss: 0.8841
# Epoch 232/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6728 - g_loss: 0.8830
# Epoch 233/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6722 - g_loss: 0.8807
# Epoch 234/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6740 - g_loss: 0.8781
# Epoch 235/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6767 - g_loss: 0.8755
# Epoch 236/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6749 - g_loss: 0.8731
# Epoch 237/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6785 - g_loss: 0.8707
# Epoch 238/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6755 - g_loss: 0.8694
# Epoch 239/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6772 - g_loss: 0.8684
# Epoch 240/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6770 - g_loss: 0.8666
# Epoch 241/500
# 20/20 [==============================] - 3s 140ms/step - d_loss: 0.6744 - g_loss: 0.8654
# Epoch 242/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6757 - g_loss: 0.8657
# Epoch 243/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6740 - g_loss: 0.8649
# Epoch 244/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6752 - g_loss: 0.8639
# Epoch 245/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6768 - g_loss: 0.8631
# Epoch 246/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6758 - g_loss: 0.8616
# Epoch 247/500
# 20/20 [==============================] - 2s 120ms/step - d_loss: 0.6733 - g_loss: 0.8614
# Epoch 248/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6765 - g_loss: 0.8608
# Epoch 249/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6744 - g_loss: 0.8605
# Epoch 250/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6732 - g_loss: 0.8599
# Epoch 251/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6740 - g_loss: 0.8591
# Epoch 252/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6721 - g_loss: 0.8585
# Epoch 253/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6725 - g_loss: 0.8575
# Epoch 254/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6724 - g_loss: 0.8567
# Epoch 255/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6733 - g_loss: 0.8561
# Epoch 256/500
# 20/20 [==============================] - 3s 141ms/step - d_loss: 0.6759 - g_loss: 0.8563
# Epoch 257/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6756 - g_loss: 0.8560
# Epoch 258/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6734 - g_loss: 0.8556
# Epoch 259/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6755 - g_loss: 0.8562
# Epoch 260/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6745 - g_loss: 0.8577
# Epoch 261/500
# 20/20 [==============================] - 3s 157ms/step - d_loss: 0.6753 - g_loss: 0.8591
# Epoch 262/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6772 - g_loss: 0.8589
# Epoch 263/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6742 - g_loss: 0.8616
# Epoch 264/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6739 - g_loss: 0.8673
# Epoch 265/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6754 - g_loss: 0.8742
# Epoch 266/500
# 20/20 [==============================] - 3s 143ms/step - d_loss: 0.6757 - g_loss: 0.8786
# Epoch 267/500
# 20/20 [==============================] - 3s 163ms/step - d_loss: 0.6718 - g_loss: 0.8846
# Epoch 268/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6783 - g_loss: 0.8882
# Epoch 269/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6757 - g_loss: 0.8879
# Epoch 270/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6760 - g_loss: 0.8881
# Epoch 271/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6760 - g_loss: 0.8881
# Epoch 272/500
# 20/20 [==============================] - 3s 146ms/step - d_loss: 0.6794 - g_loss: 0.8871
# Epoch 273/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6737 - g_loss: 0.8835
# Epoch 274/500
# 20/20 [==============================] - 3s 145ms/step - d_loss: 0.6746 - g_loss: 0.8806
# Epoch 275/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6767 - g_loss: 0.8785
# Epoch 276/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6747 - g_loss: 0.8751
# Epoch 277/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6740 - g_loss: 0.8725
# Epoch 278/500
# 20/20 [==============================] - 3s 162ms/step - d_loss: 0.6761 - g_loss: 0.8699
# Epoch 279/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6743 - g_loss: 0.8679
# Epoch 280/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6727 - g_loss: 0.8657
# Epoch 281/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6735 - g_loss: 0.8646
# Epoch 282/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6751 - g_loss: 0.8632
# Epoch 283/500
# 20/20 [==============================] - 3s 147ms/step - d_loss: 0.6746 - g_loss: 0.8609
# Epoch 284/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6743 - g_loss: 0.8591
# Epoch 285/500
# 20/20 [==============================] - 3s 140ms/step - d_loss: 0.6713 - g_loss: 0.8590
# Epoch 286/500
# 20/20 [==============================] - 2s 118ms/step - d_loss: 0.6729 - g_loss: 0.8600
# Epoch 287/500
# 20/20 [==============================] - 2s 125ms/step - d_loss: 0.6733 - g_loss: 0.8605
# Epoch 288/500
# 20/20 [==============================] - 3s 135ms/step - d_loss: 0.6744 - g_loss: 0.8602
# Epoch 289/500
# 20/20 [==============================] - 2s 110ms/step - d_loss: 0.6751 - g_loss: 0.8595
# Epoch 290/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6723 - g_loss: 0.8593
# Epoch 291/500
# 20/20 [==============================] - 2s 119ms/step - d_loss: 0.6730 - g_loss: 0.8596
# Epoch 292/500
# 20/20 [==============================] - 2s 123ms/step - d_loss: 0.6749 - g_loss: 0.8600
# Epoch 293/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6764 - g_loss: 0.8607
# Epoch 294/500
# 20/20 [==============================] - 2s 119ms/step - d_loss: 0.6747 - g_loss: 0.8622
# Epoch 295/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6731 - g_loss: 0.8655
# Epoch 296/500
# 20/20 [==============================] - 2s 110ms/step - d_loss: 0.6757 - g_loss: 0.8687
# Epoch 297/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6759 - g_loss: 0.8722
# Epoch 298/500
# 20/20 [==============================] - 2s 119ms/step - d_loss: 0.6737 - g_loss: 0.8748
# Epoch 299/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6765 - g_loss: 0.8777
# Epoch 300/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6748 - g_loss: 0.8786
# Epoch 301/500
# 20/20 [==============================] - 2s 122ms/step - d_loss: 0.6719 - g_loss: 0.8791
# Epoch 302/500
# 20/20 [==============================] - 2s 109ms/step - d_loss: 0.6750 - g_loss: 0.8788
# Epoch 303/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6761 - g_loss: 0.8771
# Epoch 304/500
# 20/20 [==============================] - 2s 110ms/step - d_loss: 0.6736 - g_loss: 0.8740
# Epoch 305/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6738 - g_loss: 0.8723
# Epoch 306/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6752 - g_loss: 0.8711
# Epoch 307/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6725 - g_loss: 0.8694
# Epoch 308/500
# 20/20 [==============================] - 2s 110ms/step - d_loss: 0.6737 - g_loss: 0.8671
# Epoch 309/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6760 - g_loss: 0.8656
# Epoch 310/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6723 - g_loss: 0.8642
# Epoch 311/500
# 20/20 [==============================] - 2s 109ms/step - d_loss: 0.6742 - g_loss: 0.8641
# Epoch 312/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6748 - g_loss: 0.8643
# Epoch 313/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6744 - g_loss: 0.8634
# Epoch 314/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6760 - g_loss: 0.8639
# Epoch 315/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6770 - g_loss: 0.8625
# Epoch 316/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6762 - g_loss: 0.8628
# Epoch 317/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6752 - g_loss: 0.8631
# Epoch 318/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6743 - g_loss: 0.8639
# Epoch 319/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6763 - g_loss: 0.8648
# Epoch 320/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6738 - g_loss: 0.8660
# Epoch 321/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6752 - g_loss: 0.8675
# Epoch 322/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6754 - g_loss: 0.8693
# Epoch 323/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6744 - g_loss: 0.8711
# Epoch 324/500
# 20/20 [==============================] - 3s 125ms/step - d_loss: 0.6761 - g_loss: 0.8734
# Epoch 325/500
# 20/20 [==============================] - 2s 117ms/step - d_loss: 0.6760 - g_loss: 0.8747
# Epoch 326/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6712 - g_loss: 0.8761
# Epoch 327/500
# 20/20 [==============================] - 3s 128ms/step - d_loss: 0.6756 - g_loss: 0.8786
# Epoch 328/500
# 20/20 [==============================] - 2s 123ms/step - d_loss: 0.6726 - g_loss: 0.8795
# Epoch 329/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6745 - g_loss: 0.8792
# Epoch 330/500
# 20/20 [==============================] - 3s 134ms/step - d_loss: 0.6720 - g_loss: 0.8778
# Epoch 331/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6717 - g_loss: 0.8767
# Epoch 332/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6740 - g_loss: 0.8752
# Epoch 333/500
# 20/20 [==============================] - 2s 122ms/step - d_loss: 0.6761 - g_loss: 0.8731
# Epoch 334/500
# 20/20 [==============================] - 2s 121ms/step - d_loss: 0.6746 - g_loss: 0.8700
# Epoch 335/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6724 - g_loss: 0.8677
# Epoch 336/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6736 - g_loss: 0.8666
# Epoch 337/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6757 - g_loss: 0.8663
# Epoch 338/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6734 - g_loss: 0.8661
# Epoch 339/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6734 - g_loss: 0.8661
# Epoch 340/500
# 20/20 [==============================] - 2s 109ms/step - d_loss: 0.6718 - g_loss: 0.8677
# Epoch 341/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6721 - g_loss: 0.8691
# Epoch 342/500
# 20/20 [==============================] - 2s 118ms/step - d_loss: 0.6725 - g_loss: 0.8713
# Epoch 343/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6733 - g_loss: 0.8723
# Epoch 344/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6732 - g_loss: 0.8732
# Epoch 345/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6743 - g_loss: 0.8725
# Epoch 346/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6741 - g_loss: 0.8713
# Epoch 347/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6742 - g_loss: 0.8707
# Epoch 348/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6773 - g_loss: 0.8694
# Epoch 349/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6733 - g_loss: 0.8669
# Epoch 350/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6756 - g_loss: 0.8662
# Epoch 351/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6749 - g_loss: 0.8650
# Epoch 352/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6770 - g_loss: 0.8642
# Epoch 353/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6756 - g_loss: 0.8640
# Epoch 354/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6742 - g_loss: 0.8633
# Epoch 355/500
# 20/20 [==============================] - 2s 102ms/step - d_loss: 0.6738 - g_loss: 0.8623
# Epoch 356/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6719 - g_loss: 0.8627
# Epoch 357/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6723 - g_loss: 0.8633
# Epoch 358/500
# 20/20 [==============================] - 2s 102ms/step - d_loss: 0.6749 - g_loss: 0.8635
# Epoch 359/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6757 - g_loss: 0.8639
# Epoch 360/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6732 - g_loss: 0.8649
# Epoch 361/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6749 - g_loss: 0.8658
# Epoch 362/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6749 - g_loss: 0.8665
# Epoch 363/500
# 20/20 [==============================] - 3s 139ms/step - d_loss: 0.6735 - g_loss: 0.8667
# Epoch 364/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6769 - g_loss: 0.8671
# Epoch 365/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6741 - g_loss: 0.8675
# Epoch 366/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6711 - g_loss: 0.8679
# Epoch 367/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6717 - g_loss: 0.8693
# Epoch 368/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6762 - g_loss: 0.8700
# Epoch 369/500
# 20/20 [==============================] - 2s 120ms/step - d_loss: 0.6740 - g_loss: 0.8692
# Epoch 370/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6756 - g_loss: 0.8692
# Epoch 371/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6728 - g_loss: 0.8683
# Epoch 372/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6746 - g_loss: 0.8679
# Epoch 373/500
# 20/20 [==============================] - 2s 102ms/step - d_loss: 0.6748 - g_loss: 0.8669
# Epoch 374/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6746 - g_loss: 0.8661
# Epoch 375/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6752 - g_loss: 0.8660
# Epoch 376/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6736 - g_loss: 0.8652
# Epoch 377/500
# 20/20 [==============================] - 3s 144ms/step - d_loss: 0.6748 - g_loss: 0.8641
# Epoch 378/500
# 20/20 [==============================] - 2s 120ms/step - d_loss: 0.6763 - g_loss: 0.8640
# Epoch 379/500
# 20/20 [==============================] - 2s 109ms/step - d_loss: 0.6749 - g_loss: 0.8638
# Epoch 380/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6742 - g_loss: 0.8641
# Epoch 381/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6737 - g_loss: 0.8643
# Epoch 382/500
# 20/20 [==============================] - 2s 102ms/step - d_loss: 0.6748 - g_loss: 0.8646
# Epoch 383/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6764 - g_loss: 0.8643
# Epoch 384/500
# 20/20 [==============================] - 2s 109ms/step - d_loss: 0.6739 - g_loss: 0.8644
# Epoch 385/500
# 20/20 [==============================] - 3s 140ms/step - d_loss: 0.6751 - g_loss: 0.8655
# Epoch 386/500
# 20/20 [==============================] - 3s 148ms/step - d_loss: 0.6719 - g_loss: 0.8666
# Epoch 387/500
# 20/20 [==============================] - 2s 121ms/step - d_loss: 0.6742 - g_loss: 0.8676
# Epoch 388/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6736 - g_loss: 0.8680
# Epoch 389/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6744 - g_loss: 0.8672
# Epoch 390/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6719 - g_loss: 0.8667
# Epoch 391/500
# 20/20 [==============================] - 2s 109ms/step - d_loss: 0.6742 - g_loss: 0.8666
# Epoch 392/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6759 - g_loss: 0.8664
# Epoch 393/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6746 - g_loss: 0.8660
# Epoch 394/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6739 - g_loss: 0.8665
# Epoch 395/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6763 - g_loss: 0.8660
# Epoch 396/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6767 - g_loss: 0.8653
# Epoch 397/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6740 - g_loss: 0.8648
# Epoch 398/500
# 20/20 [==============================] - 3s 129ms/step - d_loss: 0.6747 - g_loss: 0.8648
# Epoch 399/500
# 20/20 [==============================] - 2s 123ms/step - d_loss: 0.6713 - g_loss: 0.8656
# Epoch 400/500
# 20/20 [==============================] - 2s 109ms/step - d_loss: 0.6751 - g_loss: 0.8669
# Epoch 401/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6749 - g_loss: 0.8671
# Epoch 402/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6732 - g_loss: 0.8668
# Epoch 403/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6729 - g_loss: 0.8671
# Epoch 404/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6721 - g_loss: 0.8682
# Epoch 405/500
# 20/20 [==============================] - 3s 133ms/step - d_loss: 0.6732 - g_loss: 0.8696
# Epoch 406/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6745 - g_loss: 0.8701
# Epoch 407/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6756 - g_loss: 0.8707
# Epoch 408/500
# 20/20 [==============================] - 2s 110ms/step - d_loss: 0.6734 - g_loss: 0.8705
# Epoch 409/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6735 - g_loss: 0.8696
# Epoch 410/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6727 - g_loss: 0.8692
# Epoch 411/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6737 - g_loss: 0.8697
# Epoch 412/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6763 - g_loss: 0.8689
# Epoch 413/500
# 20/20 [==============================] - 2s 109ms/step - d_loss: 0.6734 - g_loss: 0.8678
# Epoch 414/500
# 20/20 [==============================] - 2s 110ms/step - d_loss: 0.6761 - g_loss: 0.8680
# Epoch 415/500
# 20/20 [==============================] - 2s 110ms/step - d_loss: 0.6753 - g_loss: 0.8681
# Epoch 416/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6729 - g_loss: 0.8680
# Epoch 417/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6757 - g_loss: 0.8683
# Epoch 418/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6728 - g_loss: 0.8684
# Epoch 419/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6749 - g_loss: 0.8683
# Epoch 420/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6742 - g_loss: 0.8683
# Epoch 421/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6756 - g_loss: 0.8678
# Epoch 422/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6758 - g_loss: 0.8659
# Epoch 423/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6737 - g_loss: 0.8640
# Epoch 424/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6731 - g_loss: 0.8629
# Epoch 425/500
# 20/20 [==============================] - 2s 121ms/step - d_loss: 0.6720 - g_loss: 0.8619
# Epoch 426/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6717 - g_loss: 0.8610
# Epoch 427/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6753 - g_loss: 0.8611
# Epoch 428/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6732 - g_loss: 0.8609
# Epoch 429/500
# 20/20 [==============================] - 3s 127ms/step - d_loss: 0.6746 - g_loss: 0.8605
# Epoch 430/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6750 - g_loss: 0.8604
# Epoch 431/500
# 20/20 [==============================] - 2s 110ms/step - d_loss: 0.6714 - g_loss: 0.8614
# Epoch 432/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6754 - g_loss: 0.8629
# Epoch 433/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6749 - g_loss: 0.8637
# Epoch 434/500
# 20/20 [==============================] - 2s 121ms/step - d_loss: 0.6729 - g_loss: 0.8654
# Epoch 435/500
# 20/20 [==============================] - 2s 120ms/step - d_loss: 0.6755 - g_loss: 0.8668
# Epoch 436/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6750 - g_loss: 0.8676
# Epoch 437/500
# 20/20 [==============================] - 2s 118ms/step - d_loss: 0.6726 - g_loss: 0.8683
# Epoch 438/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6726 - g_loss: 0.8698
# Epoch 439/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6728 - g_loss: 0.8688
# Epoch 440/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6752 - g_loss: 0.8678
# Epoch 441/500
# 20/20 [==============================] - 2s 123ms/step - d_loss: 0.6727 - g_loss: 0.8659
# Epoch 442/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6757 - g_loss: 0.8644
# Epoch 443/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6768 - g_loss: 0.8626
# Epoch 444/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6742 - g_loss: 0.8609
# Epoch 445/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6753 - g_loss: 0.8615
# Epoch 446/500
# 20/20 [==============================] - 2s 102ms/step - d_loss: 0.6719 - g_loss: 0.8633
# Epoch 447/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6769 - g_loss: 0.8654
# Epoch 448/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6756 - g_loss: 0.8673
# Epoch 449/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6757 - g_loss: 0.8689
# Epoch 450/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6744 - g_loss: 0.8713
# Epoch 451/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6733 - g_loss: 0.8731
# Epoch 452/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6735 - g_loss: 0.8739
# Epoch 453/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6757 - g_loss: 0.8723
# Epoch 454/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6738 - g_loss: 0.8696
# Epoch 455/500
# 20/20 [==============================] - 2s 119ms/step - d_loss: 0.6740 - g_loss: 0.8680
# Epoch 456/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6727 - g_loss: 0.8666
# Epoch 457/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6703 - g_loss: 0.8657
# Epoch 458/500
# 20/20 [==============================] - 2s 109ms/step - d_loss: 0.6731 - g_loss: 0.8654
# Epoch 459/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6723 - g_loss: 0.8654
# Epoch 460/500
# 20/20 [==============================] - 2s 103ms/step - d_loss: 0.6735 - g_loss: 0.8664
# Epoch 461/500
# 20/20 [==============================] - 2s 102ms/step - d_loss: 0.6716 - g_loss: 0.8670
# Epoch 462/500
# 20/20 [==============================] - 2s 104ms/step - d_loss: 0.6742 - g_loss: 0.8680
# Epoch 463/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6744 - g_loss: 0.8698
# Epoch 464/500
# 20/20 [==============================] - 3s 126ms/step - d_loss: 0.6745 - g_loss: 0.8712
# Epoch 465/500
# 20/20 [==============================] - 2s 109ms/step - d_loss: 0.6739 - g_loss: 0.8733
# Epoch 466/500
# 20/20 [==============================] - 2s 105ms/step - d_loss: 0.6717 - g_loss: 0.8749
# Epoch 467/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6743 - g_loss: 0.8767
# Epoch 468/500
# 20/20 [==============================] - 2s 106ms/step - d_loss: 0.6733 - g_loss: 0.8764
# Epoch 469/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6746 - g_loss: 0.8739
# Epoch 470/500
# 20/20 [==============================] - 3s 131ms/step - d_loss: 0.6745 - g_loss: 0.8711
# Epoch 471/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6730 - g_loss: 0.8689
# Epoch 472/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6725 - g_loss: 0.8667
# Epoch 473/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6727 - g_loss: 0.8654
# Epoch 474/500
# 20/20 [==============================] - 3s 138ms/step - d_loss: 0.6755 - g_loss: 0.8645
# Epoch 475/500
# 20/20 [==============================] - 2s 109ms/step - d_loss: 0.6740 - g_loss: 0.8639
# Epoch 476/500
# 20/20 [==============================] - 2s 111ms/step - d_loss: 0.6781 - g_loss: 0.8645
# Epoch 477/500
# 20/20 [==============================] - 2s 119ms/step - d_loss: 0.6727 - g_loss: 0.8652
# Epoch 478/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6736 - g_loss: 0.8667
# Epoch 479/500
# 20/20 [==============================] - 2s 124ms/step - d_loss: 0.6744 - g_loss: 0.8677
# Epoch 480/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6735 - g_loss: 0.8682
# Epoch 481/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6748 - g_loss: 0.8687
# Epoch 482/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6751 - g_loss: 0.8684
# Epoch 483/500
# 20/20 [==============================] - 3s 142ms/step - d_loss: 0.6770 - g_loss: 0.8683
# Epoch 484/500
# 20/20 [==============================] - 2s 113ms/step - d_loss: 0.6746 - g_loss: 0.8676
# Epoch 485/500
# 20/20 [==============================] - 3s 136ms/step - d_loss: 0.6728 - g_loss: 0.8666
# Epoch 486/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6747 - g_loss: 0.8659
# Epoch 487/500
# 20/20 [==============================] - 2s 110ms/step - d_loss: 0.6744 - g_loss: 0.8656
# Epoch 488/500
# 20/20 [==============================] - 2s 109ms/step - d_loss: 0.6732 - g_loss: 0.8655
# Epoch 489/500
# 20/20 [==============================] - 2s 112ms/step - d_loss: 0.6723 - g_loss: 0.8652
# Epoch 490/500
# 20/20 [==============================] - 2s 115ms/step - d_loss: 0.6742 - g_loss: 0.8644
# Epoch 491/500
# 20/20 [==============================] - 2s 114ms/step - d_loss: 0.6736 - g_loss: 0.8637
# Epoch 492/500
# 20/20 [==============================] - 2s 109ms/step - d_loss: 0.6714 - g_loss: 0.8644
# Epoch 493/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6747 - g_loss: 0.8648
# Epoch 494/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6742 - g_loss: 0.8643
# Epoch 495/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6731 - g_loss: 0.8647
# Epoch 496/500
# 20/20 [==============================] - 2s 109ms/step - d_loss: 0.6734 - g_loss: 0.8661
# Epoch 497/500
# 20/20 [==============================] - 2s 107ms/step - d_loss: 0.6732 - g_loss: 0.8675
# Epoch 498/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6738 - g_loss: 0.8699
# Epoch 499/500
# 20/20 [==============================] - 2s 108ms/step - d_loss: 0.6760 - g_loss: 0.8715
# Epoch 500/500
# 20/20 [==============================] - 2s 116ms/step - d_loss: 0.6733 - g_loss: 0.8713

# %%
if True:
    scenario_size = 30
    normal_noise = tf.random.normal((scenario_size, batch_size, 1))
    n = [np.random.normal() for _ in range(scenario_size)]
    series = np.multiply(generator.predict(normal_noise), max)
    resolution = 96

    probabilities = []
    ranges = np.linspace(-3.5, 3.5, 8)
    intervals = np.linspace(-3, 3, 7)
    probs = [stats.norm.cdf(i) for i in n]
    prob_ranges = {intervals[i]: [stats.norm.cdf(ranges[i]), stats.norm.cdf(ranges[i+1])] for i in range(len(intervals))}
    for i in probs:
        for key in intervals:
            if prob_ranges[key][0]<= i <=prob_ranges[key][1]:
                probabilities.append(prob_ranges[key][1]-prob_ranges[key][0])
                break
    scenarios = {'probs': probabilities}
    for j in range(resolution):
        scenarios[j] = []
    for i in range(scenario_size):
        s = series[i].reshape([resolution])
        for j in range(resolution):
            scenarios[j].append(s[j])
pd.DataFrame(scenarios).to_csv(f'LoadScenarios-{month_name}-{day_type}.csv')
if True:
    ticks = [i for i in range(resolution) if i%4 == 0]
    fig, ax = plt.subplots(1, 2, figsize=(15, 4), dpi=200)
    for s in series[:3]:
        ax[0].plot(range(resolution), s.reshape([resolution]), linewidth=1)
    ax[0].set_xlabel('Timestamp (15 min)')
    ax[0].set_ylabel('Generated Power Consumption')
    ax[0].set_xticks(ticks, ticks)
    ax[0].grid(color='#666362', linestyle='-', linewidth=0.1)

    if day_type == 'w':
        ax[1].plot(my_data[[c for c in my_data.columns if 'weekday' in c][:3]], linewidth=1)
    else:
        ax[1].plot(my_data[[c for c in my_data.columns if 'weekend' in c][:3]], linewidth=1)
    ax[1].set_xlabel('Timestamp (15 min)')
    ax[1].set_ylabel('Historical Power Consumption')
    ax[1].set_xticks(ticks, ticks)
    ax[1].grid(color='#666362', linestyle='-', linewidth=0.1)
    plt.subplots_adjust(wspace=0.1)
# plt.savefig(f'IMG/{month_name}-{day_type}.jpg', bbox_inches='tight')
# Out:
# 1/1 [==============================] - 0s 57ms/step

# %% [markdown]
# ### Save models

# %%
generator.save(f'HarrisCounty/GAN Models/generator-{month_name}-{day_type}.h5')
discriminator.save(f'HarrisCounty/GAN Models/discriminator-{month_name}-{day_type}.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
plt.figure(figsize=(7, 3), dpi=300)
plt.plot(hist.history['d_loss'], label='Generator Loss')
plt.plot(hist.history['g_loss'], label='Discriminator Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(color='#666362', linestyle='-', linewidth=0.1)
plt.savefig(f'IMG/{month_name}-{day_type}-loss.jpg', bbox_inches='tight')

# %%
import random
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
from keras.callbacks import Callback
from keras.utils import array_to_img
from keras import Sequential
from keras.layers import Conv2D, Dense, Flatten, Reshape, LeakyReLU, Dropout, UpSampling1D
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from keras.models import Model
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.reset_memory_stats(gpu, True)
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('ignore')

# %%
pv_year = pd.read_csv('hourly.csv')[['Month', 'Day', 'Hour', 'DC Output (W)']]
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
for m in range(1, 13):
    mask = pv_year['Month'] == m
    to_save = {}
    for t in range(int(len(pv_year[mask]['DC Output (W)'])/24)):
        to_save[t] = np.divide(pv_year[mask]['DC Output (W)'].iloc[t*24:(t+1)*24].values, 1000)
    counter = 1
    while counter <= 30:
        c1 = random.choice(list(to_save.keys()))
        c2 = random.choice(list(to_save.keys()))
        while True:
            if c2 == c1:
                c2 = random.choice(list(to_save.keys()))
            else:
                break
        to_save[f'g{counter}'] = np.divide(to_save[c1] + to_save[c2], 2)
        counter += 1
    pd.DataFrame(to_save).to_csv(f'PV-{months[m-1]}.csv')

# %%
month_name='Sep'
my_data = pd.read_csv(f'PV-{month_name}.csv')
ds = []
for c in my_data.columns[1:]:
        ds.append([my_data[c].values])
max = np.max(ds)
ds = np.divide(ds, max)

# %% [markdown]
# ### Prepare data to feed into GAN

# %%
ds = tf.data.Dataset.from_tensor_slices(ds)
batch_size = 8
ds = ds.cache()
ds = ds.shuffle(1000)
ds = ds.batch(batch_size)
ds = ds.prefetch(64)

# %% [markdown]
# ## Generator

# %%
g_relu = 0.2
def build_generator():
    model = Sequential()

    model.add(Dense(1*24*batch_size, input_dim=batch_size))
    model.add(LeakyReLU(g_relu))
    model.add(Reshape((1,24, batch_size)))

    #model.add(UpSamplingD())
    model.add(Conv2D(batch_size, 3, padding='same'))
    model.add(LeakyReLU(g_relu))

    model.add(Conv2D(batch_size, 3, padding='same'))
    model.add(LeakyReLU(g_relu))

    model.add(Conv2D(batch_size, 3, padding='same'))
    model.add(LeakyReLU(g_relu))

    model.add(Conv2D(batch_size, 3, padding='same'))
    model.add(LeakyReLU(g_relu))

    model.add(Conv2D(1, 3, padding='same', activation='sigmoid'))
    return model
generator = build_generator()
#generator.summary()
# series = generator.predict(np.random.randn(4, 6, 1))

# %% [markdown]
# ## Discriminator

# %%
d_relu = 0.2
d_dropout = 0.2
def build_discriminator():
    model = Sequential()

    model.add(Dense(200, input_shape=(1, 24, 1)))
    model.add(LeakyReLU(d_relu))
    model.add(Dropout(d_dropout))

    model.add(Dense(150))
    model.add(LeakyReLU(d_relu))
    model.add(Dropout(d_dropout))

    model.add(Flatten())
    model.add(Dropout(d_dropout))
    model.add(Dense(1, activation='sigmoid'))
    # 1: fake series, 0: real series

    return model
discriminator = build_discriminator()
#discriminator.summary()
# Single prediction needs np.expand_dims(series[0], 0)
# discriminator.predict(np.expand_dims(series[0], 0))

# %%
g_a, d_a = 0.0001, 0.00001
g_opt = Adam(learning_rate=g_a)
d_opt = Adam(learning_rate=d_a)  # Does not learn too fast
g_loss = BinaryCrossentropy()
d_loss = BinaryCrossentropy()
class LoadGAN(Model):
    def __init__(self, generator, discriminator, *args, **kwargs):
        # pass through args and kwargs to base class
        super().__init__(*args, **kwargs)
        # Create attributes for gen and disc
        self.generator = generator
        self.discriminator = discriminator

    def compilee(self, g_opt, d_opt, g_loss, d_loss, *args, **kwargs):
        # Compile with base class
        super().compile(*args, **kwargs)

        self.g_opt = g_opt
        self.d_opt = d_opt
        self.g_loss = g_loss
        self.d_loss = d_loss

    def train_step(self, batch):
        real_series = batch
        fake_series = self.generator(tf.random.normal((batch_size, batch_size, 1)), training=False)

        # train the discriminator
        with tf.GradientTape() as d_tape:
            # pass the real and fake images
            yhat_real = self.discriminator(real_series, training=True)
            yhat_fake = self.discriminator(fake_series, training=True)
            yhat_realfake = tf.concat([yhat_real, yhat_fake], axis=0)

            # create labels for real and fake series
            y_realfake = tf.concat([tf.zeros_like(yhat_real), tf.ones_like(yhat_fake)], axis=0)


            # pass through and add some noise to the outputs
            noise_real = 0.15*tf.random.uniform(tf.shape(yhat_real))
            noise_fake = 0.15*tf.random.uniform(tf.shape(yhat_fake))
            y_realfake += tf.concat([noise_real, noise_fake], axis=0)

            # calculate the loss
            total_d_loss = self.d_loss(y_realfake, yhat_realfake)

        # apply backpropagation
        dgrad = d_tape.gradient(total_d_loss, self.discriminator.trainable_variables)
        self.d_opt.apply_gradients(zip(dgrad, self.discriminator.trainable_variables))

        # Generator training
        with tf.GradientTape() as g_tape:
            # generate same new images
            gen_series = self.generator(tf.random.normal((batch_size, batch_size, 1)), training=True)

            # create the predicted labels
            predicted_labels = self.discriminator(gen_series, training=False)

            # calculate loss
            total_g_loss = self.g_loss(tf.zeros_like(predicted_labels), predicted_labels)

        # apply backpropagation
        ggrad = g_tape.gradient(total_g_loss, self.generator.trainable_variables)
        self.g_opt.apply_gradients(zip(ggrad, self.generator.trainable_variables))

        return {"d_loss":total_d_loss, "g_loss":total_g_loss}
loadgan = LoadGAN(generator, discriminator)
loadgan.compilee(g_opt, d_opt, g_loss, d_loss)

# %% [markdown]
# #### Call Back

# %%
class ModelMonitor(Callback):
    def __init__(self, num_img=3, latent_dim=batch_size):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vector = tf.random.uniform((self.num_img, self.latent_dim, 1))
        generated_series = self.model.generator(random_latent_vector)
        generated_series *= max
        generated_series.numpy()
        for i in range(self.num_img):
            serie = array_to_img(generated_series[i])

# %% [markdown]
# #### Train

# %%
hist = loadgan.fit(ds, epochs=400)
# Out:
# Epoch 1/400
# 8/8 [==============================] - 1s 132ms/step - d_loss: 0.6871 - g_loss: 0.7179
# Epoch 2/400
# 8/8 [==============================] - 1s 122ms/step - d_loss: 0.6862 - g_loss: 0.7211
# Epoch 3/400
# 8/8 [==============================] - 1s 139ms/step - d_loss: 0.6823 - g_loss: 0.7243
# Epoch 4/400
# 8/8 [==============================] - 1s 112ms/step - d_loss: 0.6807 - g_loss: 0.7275
# Epoch 5/400
# 8/8 [==============================] - 1s 123ms/step - d_loss: 0.6824 - g_loss: 0.7307
# Epoch 6/400
# 8/8 [==============================] - 1s 133ms/step - d_loss: 0.6797 - g_loss: 0.7339
# Epoch 7/400
# 8/8 [==============================] - 1s 136ms/step - d_loss: 0.6766 - g_loss: 0.7370
# Epoch 8/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6755 - g_loss: 0.7402
# Epoch 9/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6760 - g_loss: 0.7434
# Epoch 10/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6730 - g_loss: 0.7465
# Epoch 11/400
# 8/8 [==============================] - 1s 138ms/step - d_loss: 0.6701 - g_loss: 0.7496
# Epoch 12/400
# 8/8 [==============================] - 1s 140ms/step - d_loss: 0.6702 - g_loss: 0.7527
# Epoch 13/400
# 8/8 [==============================] - 1s 150ms/step - d_loss: 0.6675 - g_loss: 0.7559
# Epoch 14/400
# 8/8 [==============================] - 1s 144ms/step - d_loss: 0.6630 - g_loss: 0.7590
# Epoch 15/400
# 8/8 [==============================] - 1s 161ms/step - d_loss: 0.6662 - g_loss: 0.7621
# Epoch 16/400
# 8/8 [==============================] - 2s 185ms/step - d_loss: 0.6651 - g_loss: 0.7651
# Epoch 17/400
# 8/8 [==============================] - 1s 153ms/step - d_loss: 0.6610 - g_loss: 0.7680
# Epoch 18/400
# 8/8 [==============================] - 1s 135ms/step - d_loss: 0.6594 - g_loss: 0.7709
# Epoch 19/400
# 8/8 [==============================] - 1s 159ms/step - d_loss: 0.6590 - g_loss: 0.7737
# Epoch 20/400
# 8/8 [==============================] - 1s 156ms/step - d_loss: 0.6541 - g_loss: 0.7765
# Epoch 21/400
# 8/8 [==============================] - 1s 156ms/step - d_loss: 0.6542 - g_loss: 0.7793
# Epoch 22/400
# 8/8 [==============================] - 1s 161ms/step - d_loss: 0.6566 - g_loss: 0.7822
# Epoch 23/400
# 8/8 [==============================] - 1s 161ms/step - d_loss: 0.6575 - g_loss: 0.7848
# Epoch 24/400
# 8/8 [==============================] - 1s 156ms/step - d_loss: 0.6522 - g_loss: 0.7873
# Epoch 25/400
# 8/8 [==============================] - 1s 132ms/step - d_loss: 0.6480 - g_loss: 0.7896
# Epoch 26/400
# 8/8 [==============================] - 1s 105ms/step - d_loss: 0.6519 - g_loss: 0.7918
# Epoch 27/400
# 8/8 [==============================] - 1s 182ms/step - d_loss: 0.6479 - g_loss: 0.7941
# Epoch 28/400
# 8/8 [==============================] - 1s 161ms/step - d_loss: 0.6487 - g_loss: 0.7955
# Epoch 29/400
# 8/8 [==============================] - 1s 161ms/step - d_loss: 0.6475 - g_loss: 0.7974
# Epoch 30/400
# 8/8 [==============================] - 1s 154ms/step - d_loss: 0.6483 - g_loss: 0.7987
# Epoch 31/400
# 8/8 [==============================] - 1s 156ms/step - d_loss: 0.6468 - g_loss: 0.7997
# Epoch 32/400
# 8/8 [==============================] - 1s 156ms/step - d_loss: 0.6453 - g_loss: 0.7997
# Epoch 33/400
# 8/8 [==============================] - 1s 152ms/step - d_loss: 0.6479 - g_loss: 0.8007
# Epoch 34/400
# 8/8 [==============================] - 1s 160ms/step - d_loss: 0.6505 - g_loss: 0.7997
# Epoch 35/400
# 8/8 [==============================] - 1s 143ms/step - d_loss: 0.6478 - g_loss: 0.7987
# Epoch 36/400
# 8/8 [==============================] - 1s 139ms/step - d_loss: 0.6466 - g_loss: 0.7971
# Epoch 37/400
# 8/8 [==============================] - 1s 155ms/step - d_loss: 0.6502 - g_loss: 0.7949
# Epoch 38/400
# 8/8 [==============================] - 1s 141ms/step - d_loss: 0.6506 - g_loss: 0.7931
# Epoch 39/400
# 8/8 [==============================] - 1s 135ms/step - d_loss: 0.6520 - g_loss: 0.7893
# Epoch 40/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6539 - g_loss: 0.7852
# Epoch 41/400
# 8/8 [==============================] - 1s 118ms/step - d_loss: 0.6515 - g_loss: 0.7800
# Epoch 42/400
# 8/8 [==============================] - 1s 118ms/step - d_loss: 0.6552 - g_loss: 0.7740
# Epoch 43/400
# 8/8 [==============================] - 1s 122ms/step - d_loss: 0.6593 - g_loss: 0.7717
# Epoch 44/400
# 8/8 [==============================] - 1s 133ms/step - d_loss: 0.6644 - g_loss: 0.7647
# Epoch 45/400
# 8/8 [==============================] - 1s 135ms/step - d_loss: 0.6653 - g_loss: 0.7617
# Epoch 46/400
# 8/8 [==============================] - 1s 144ms/step - d_loss: 0.6657 - g_loss: 0.7557
# Epoch 47/400
# 8/8 [==============================] - 1s 132ms/step - d_loss: 0.6677 - g_loss: 0.7520
# Epoch 48/400
# 8/8 [==============================] - 1s 111ms/step - d_loss: 0.6694 - g_loss: 0.7483
# Epoch 49/400
# 8/8 [==============================] - 1s 122ms/step - d_loss: 0.6721 - g_loss: 0.7433
# Epoch 50/400
# 8/8 [==============================] - 1s 151ms/step - d_loss: 0.6703 - g_loss: 0.7400
# Epoch 51/400
# 8/8 [==============================] - 1s 117ms/step - d_loss: 0.6720 - g_loss: 0.7367
# Epoch 52/400
# 8/8 [==============================] - 1s 124ms/step - d_loss: 0.6732 - g_loss: 0.7349
# Epoch 53/400
# 8/8 [==============================] - 1s 159ms/step - d_loss: 0.6744 - g_loss: 0.7319
# Epoch 54/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6760 - g_loss: 0.7300
# Epoch 55/400
# 8/8 [==============================] - 1s 131ms/step - d_loss: 0.6737 - g_loss: 0.7285
# Epoch 56/400
# 8/8 [==============================] - 1s 129ms/step - d_loss: 0.6764 - g_loss: 0.7276
# Epoch 57/400
# 8/8 [==============================] - 1s 141ms/step - d_loss: 0.6731 - g_loss: 0.7251
# Epoch 58/400
# 8/8 [==============================] - 1s 113ms/step - d_loss: 0.6728 - g_loss: 0.7230
# Epoch 59/400
# 8/8 [==============================] - 1s 129ms/step - d_loss: 0.6755 - g_loss: 0.7236
# Epoch 60/400
# 8/8 [==============================] - 1s 98ms/step - d_loss: 0.6723 - g_loss: 0.7222
# Epoch 61/400
# 8/8 [==============================] - 1s 144ms/step - d_loss: 0.6716 - g_loss: 0.7221
# Epoch 62/400
# 8/8 [==============================] - 1s 143ms/step - d_loss: 0.6728 - g_loss: 0.7213
# Epoch 63/400
# 8/8 [==============================] - 1s 129ms/step - d_loss: 0.6701 - g_loss: 0.7217
# Epoch 64/400
# 8/8 [==============================] - 1s 135ms/step - d_loss: 0.6706 - g_loss: 0.7212
# Epoch 65/400
# 8/8 [==============================] - 1s 132ms/step - d_loss: 0.6689 - g_loss: 0.7215
# Epoch 66/400
# 8/8 [==============================] - 1s 131ms/step - d_loss: 0.6667 - g_loss: 0.7213
# Epoch 67/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6668 - g_loss: 0.7218
# Epoch 68/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6677 - g_loss: 0.7222
# Epoch 69/400
# 8/8 [==============================] - 1s 144ms/step - d_loss: 0.6651 - g_loss: 0.7216
# Epoch 70/400
# 8/8 [==============================] - 1s 120ms/step - d_loss: 0.6647 - g_loss: 0.7225
# Epoch 71/400
# 8/8 [==============================] - 1s 96ms/step - d_loss: 0.6649 - g_loss: 0.7231
# Epoch 72/400
# 8/8 [==============================] - 1s 104ms/step - d_loss: 0.6637 - g_loss: 0.7234
# Epoch 73/400
# 8/8 [==============================] - 1s 107ms/step - d_loss: 0.6625 - g_loss: 0.7239
# Epoch 74/400
# 8/8 [==============================] - 1s 149ms/step - d_loss: 0.6569 - g_loss: 0.7252
# Epoch 75/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6600 - g_loss: 0.7254
# Epoch 76/400
# 8/8 [==============================] - 1s 133ms/step - d_loss: 0.6574 - g_loss: 0.7254
# Epoch 77/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6555 - g_loss: 0.7267
# Epoch 78/400
# 8/8 [==============================] - 1s 130ms/step - d_loss: 0.6531 - g_loss: 0.7263
# Epoch 79/400
# 8/8 [==============================] - 1s 120ms/step - d_loss: 0.6521 - g_loss: 0.7273
# Epoch 80/400
# 8/8 [==============================] - 1s 151ms/step - d_loss: 0.6525 - g_loss: 0.7285
# Epoch 81/400
# 8/8 [==============================] - 1s 130ms/step - d_loss: 0.6505 - g_loss: 0.7293
# Epoch 82/400
# 8/8 [==============================] - 1s 131ms/step - d_loss: 0.6507 - g_loss: 0.7289
# Epoch 83/400
# 8/8 [==============================] - 1s 132ms/step - d_loss: 0.6471 - g_loss: 0.7300
# Epoch 84/400
# 8/8 [==============================] - 1s 137ms/step - d_loss: 0.6453 - g_loss: 0.7312
# Epoch 85/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6449 - g_loss: 0.7302
# Epoch 86/400
# 8/8 [==============================] - 1s 129ms/step - d_loss: 0.6436 - g_loss: 0.7323
# Epoch 87/400
# 8/8 [==============================] - 1s 142ms/step - d_loss: 0.6431 - g_loss: 0.7327
# Epoch 88/400
# 8/8 [==============================] - 1s 130ms/step - d_loss: 0.6418 - g_loss: 0.7322
# Epoch 89/400
# 8/8 [==============================] - 1s 141ms/step - d_loss: 0.6404 - g_loss: 0.7328
# Epoch 90/400
# 8/8 [==============================] - 1s 147ms/step - d_loss: 0.6393 - g_loss: 0.7342
# Epoch 91/400
# 8/8 [==============================] - 1s 142ms/step - d_loss: 0.6373 - g_loss: 0.7366
# Epoch 92/400
# 8/8 [==============================] - 1s 136ms/step - d_loss: 0.6338 - g_loss: 0.7339
# Epoch 93/400
# 8/8 [==============================] - 1s 143ms/step - d_loss: 0.6339 - g_loss: 0.7359
# Epoch 94/400
# 8/8 [==============================] - 1s 134ms/step - d_loss: 0.6311 - g_loss: 0.7355
# Epoch 95/400
# 8/8 [==============================] - 1s 154ms/step - d_loss: 0.6318 - g_loss: 0.7377
# Epoch 96/400
# 8/8 [==============================] - 1s 135ms/step - d_loss: 0.6318 - g_loss: 0.7347
# Epoch 97/400
# 8/8 [==============================] - 1s 118ms/step - d_loss: 0.6288 - g_loss: 0.7371
# Epoch 98/400
# 8/8 [==============================] - 1s 117ms/step - d_loss: 0.6273 - g_loss: 0.7381
# Epoch 99/400
# 8/8 [==============================] - 1s 114ms/step - d_loss: 0.6262 - g_loss: 0.7401
# Epoch 100/400
# 8/8 [==============================] - 1s 102ms/step - d_loss: 0.6271 - g_loss: 0.7390
# Epoch 101/400
# 8/8 [==============================] - 1s 104ms/step - d_loss: 0.6247 - g_loss: 0.7384
# Epoch 102/400
# 8/8 [==============================] - 1s 86ms/step - d_loss: 0.6258 - g_loss: 0.7380
# Epoch 103/400
# 8/8 [==============================] - 1s 95ms/step - d_loss: 0.6246 - g_loss: 0.7375
# Epoch 104/400
# 8/8 [==============================] - 1s 90ms/step - d_loss: 0.6228 - g_loss: 0.7352
# Epoch 105/400
# 8/8 [==============================] - 1s 91ms/step - d_loss: 0.6219 - g_loss: 0.7323
# Epoch 106/400
# 8/8 [==============================] - 1s 95ms/step - d_loss: 0.6249 - g_loss: 0.7423
# Epoch 107/400
# 8/8 [==============================] - 1s 110ms/step - d_loss: 0.6197 - g_loss: 0.7355
# Epoch 108/400
# 8/8 [==============================] - 1s 116ms/step - d_loss: 0.6199 - g_loss: 0.7363
# Epoch 109/400
# 8/8 [==============================] - 1s 114ms/step - d_loss: 0.6189 - g_loss: 0.7362
# Epoch 110/400
# 8/8 [==============================] - 1s 130ms/step - d_loss: 0.6213 - g_loss: 0.7327
# Epoch 111/400
# 8/8 [==============================] - 1s 115ms/step - d_loss: 0.6208 - g_loss: 0.7356
# Epoch 112/400
# 8/8 [==============================] - 1s 122ms/step - d_loss: 0.6203 - g_loss: 0.7370
# Epoch 113/400
# 8/8 [==============================] - 1s 129ms/step - d_loss: 0.6225 - g_loss: 0.7365
# Epoch 114/400
# 8/8 [==============================] - 1s 113ms/step - d_loss: 0.6203 - g_loss: 0.7226
# Epoch 115/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6198 - g_loss: 0.7249
# Epoch 116/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6287 - g_loss: 0.7287
# Epoch 117/400
# 8/8 [==============================] - 1s 123ms/step - d_loss: 0.6192 - g_loss: 0.7254
# Epoch 118/400
# 8/8 [==============================] - 1s 129ms/step - d_loss: 0.6246 - g_loss: 0.7228
# Epoch 119/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6212 - g_loss: 0.7273
# Epoch 120/400
# 8/8 [==============================] - 1s 130ms/step - d_loss: 0.6225 - g_loss: 0.7267
# Epoch 121/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6179 - g_loss: 0.7384
# Epoch 122/400
# 8/8 [==============================] - 1s 119ms/step - d_loss: 0.6242 - g_loss: 0.7056
# Epoch 123/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6242 - g_loss: 0.7267
# Epoch 124/400
# 8/8 [==============================] - 1s 124ms/step - d_loss: 0.6309 - g_loss: 0.7231
# Epoch 125/400
# 8/8 [==============================] - 1s 102ms/step - d_loss: 0.6290 - g_loss: 0.7267
# Epoch 126/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6329 - g_loss: 0.7021
# Epoch 127/400
# 8/8 [==============================] - 1s 124ms/step - d_loss: 0.6403 - g_loss: 0.6908
# Epoch 128/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6287 - g_loss: 0.7112
# Epoch 129/400
# 8/8 [==============================] - 1s 106ms/step - d_loss: 0.6328 - g_loss: 0.7002
# Epoch 130/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6409 - g_loss: 0.7127
# Epoch 131/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6401 - g_loss: 0.7057
# Epoch 132/400
# 8/8 [==============================] - 1s 122ms/step - d_loss: 0.6249 - g_loss: 0.6983
# Epoch 133/400
# 8/8 [==============================] - 1s 132ms/step - d_loss: 0.6402 - g_loss: 0.6929
# Epoch 134/400
# 8/8 [==============================] - 1s 120ms/step - d_loss: 0.6419 - g_loss: 0.7023
# Epoch 135/400
# 8/8 [==============================] - 1s 141ms/step - d_loss: 0.6305 - g_loss: 0.6983
# Epoch 136/400
# 8/8 [==============================] - 1s 150ms/step - d_loss: 0.6388 - g_loss: 0.7036
# Epoch 137/400
# 8/8 [==============================] - 1s 140ms/step - d_loss: 0.6454 - g_loss: 0.7005
# Epoch 138/400
# 8/8 [==============================] - 1s 145ms/step - d_loss: 0.6455 - g_loss: 0.7016
# Epoch 139/400
# 8/8 [==============================] - 1s 139ms/step - d_loss: 0.6417 - g_loss: 0.6970
# Epoch 140/400
# 8/8 [==============================] - 1s 155ms/step - d_loss: 0.6521 - g_loss: 0.6855
# Epoch 141/400
# 8/8 [==============================] - 1s 141ms/step - d_loss: 0.6481 - g_loss: 0.6695
# Epoch 142/400
# 8/8 [==============================] - 1s 151ms/step - d_loss: 0.6440 - g_loss: 0.6793
# Epoch 143/400
# 8/8 [==============================] - 1s 124ms/step - d_loss: 0.6753 - g_loss: 0.6619
# Epoch 144/400
# 8/8 [==============================] - 1s 153ms/step - d_loss: 0.6598 - g_loss: 0.6863
# Epoch 145/400
# 8/8 [==============================] - 1s 152ms/step - d_loss: 0.6577 - g_loss: 0.6832
# Epoch 146/400
# 8/8 [==============================] - 1s 157ms/step - d_loss: 0.6535 - g_loss: 0.6848
# Epoch 147/400
# 8/8 [==============================] - 1s 158ms/step - d_loss: 0.6698 - g_loss: 0.6762
# Epoch 148/400
# 8/8 [==============================] - 1s 153ms/step - d_loss: 0.6736 - g_loss: 0.6707
# Epoch 149/400
# 8/8 [==============================] - 1s 164ms/step - d_loss: 0.6728 - g_loss: 0.6626
# Epoch 150/400
# 8/8 [==============================] - 1s 182ms/step - d_loss: 0.6640 - g_loss: 0.6755
# Epoch 151/400
# 8/8 [==============================] - 1s 157ms/step - d_loss: 0.6787 - g_loss: 0.6647
# Epoch 152/400
# 8/8 [==============================] - 1s 160ms/step - d_loss: 0.6770 - g_loss: 0.6933
# Epoch 153/400
# 8/8 [==============================] - 1s 155ms/step - d_loss: 0.6691 - g_loss: 0.6777
# Epoch 154/400
# 8/8 [==============================] - 1s 154ms/step - d_loss: 0.6699 - g_loss: 0.6622
# Epoch 155/400
# 8/8 [==============================] - 1s 150ms/step - d_loss: 0.6815 - g_loss: 0.6768
# Epoch 156/400
# 8/8 [==============================] - 1s 173ms/step - d_loss: 0.6755 - g_loss: 0.6758
# Epoch 157/400
# 8/8 [==============================] - 1s 138ms/step - d_loss: 0.6782 - g_loss: 0.6668
# Epoch 158/400
# 8/8 [==============================] - 1s 149ms/step - d_loss: 0.6749 - g_loss: 0.6510
# Epoch 159/400
# 8/8 [==============================] - 1s 113ms/step - d_loss: 0.6867 - g_loss: 0.6896
# Epoch 160/400
# 8/8 [==============================] - 1s 136ms/step - d_loss: 0.7027 - g_loss: 0.6827
# Epoch 161/400
# 8/8 [==============================] - 1s 130ms/step - d_loss: 0.6994 - g_loss: 0.6679
# Epoch 162/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6884 - g_loss: 0.6744
# Epoch 163/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6677 - g_loss: 0.6993
# Epoch 164/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6706 - g_loss: 0.7035
# Epoch 165/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6782 - g_loss: 0.6852
# Epoch 166/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6758 - g_loss: 0.7031
# Epoch 167/400
# 8/8 [==============================] - 1s 123ms/step - d_loss: 0.6813 - g_loss: 0.6928
# Epoch 168/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.7033 - g_loss: 0.6994
# Epoch 169/400
# 8/8 [==============================] - 1s 117ms/step - d_loss: 0.6913 - g_loss: 0.6979
# Epoch 170/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6822 - g_loss: 0.6943
# Epoch 171/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6766 - g_loss: 0.7028
# Epoch 172/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6921 - g_loss: 0.7263
# Epoch 173/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6938 - g_loss: 0.7154
# Epoch 174/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6720 - g_loss: 0.7121
# Epoch 175/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6819 - g_loss: 0.7160
# Epoch 176/400
# 8/8 [==============================] - 1s 130ms/step - d_loss: 0.6921 - g_loss: 0.7248
# Epoch 177/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6844 - g_loss: 0.7467
# Epoch 178/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6812 - g_loss: 0.7255
# Epoch 179/400
# 8/8 [==============================] - 1s 130ms/step - d_loss: 0.6934 - g_loss: 0.7184
# Epoch 180/400
# 8/8 [==============================] - 1s 133ms/step - d_loss: 0.6800 - g_loss: 0.7254
# Epoch 181/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6962 - g_loss: 0.7464
# Epoch 182/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6828 - g_loss: 0.7432
# Epoch 183/400
# 8/8 [==============================] - 1s 138ms/step - d_loss: 0.6830 - g_loss: 0.7278
# Epoch 184/400
# 8/8 [==============================] - 1s 122ms/step - d_loss: 0.6866 - g_loss: 0.7430
# Epoch 185/400
# 8/8 [==============================] - 1s 129ms/step - d_loss: 0.6796 - g_loss: 0.7542
# Epoch 186/400
# 8/8 [==============================] - 1s 129ms/step - d_loss: 0.6841 - g_loss: 0.7726
# Epoch 187/400
# 8/8 [==============================] - 1s 134ms/step - d_loss: 0.6759 - g_loss: 0.7766
# Epoch 188/400
# 8/8 [==============================] - 1s 139ms/step - d_loss: 0.6783 - g_loss: 0.7819
# Epoch 189/400
# 8/8 [==============================] - 1s 143ms/step - d_loss: 0.6815 - g_loss: 0.7811
# Epoch 190/400
# 8/8 [==============================] - 1s 135ms/step - d_loss: 0.6742 - g_loss: 0.7733
# Epoch 191/400
# 8/8 [==============================] - 1s 133ms/step - d_loss: 0.6779 - g_loss: 0.7863
# Epoch 192/400
# 8/8 [==============================] - 1s 143ms/step - d_loss: 0.6779 - g_loss: 0.7925
# Epoch 193/400
# 8/8 [==============================] - 1s 167ms/step - d_loss: 0.6805 - g_loss: 0.7911
# Epoch 194/400
# 8/8 [==============================] - 1s 134ms/step - d_loss: 0.6830 - g_loss: 0.8035
# Epoch 195/400
# 8/8 [==============================] - 1s 139ms/step - d_loss: 0.6873 - g_loss: 0.8040
# Epoch 196/400
# 8/8 [==============================] - 1s 144ms/step - d_loss: 0.6806 - g_loss: 0.8137
# Epoch 197/400
# 8/8 [==============================] - 1s 130ms/step - d_loss: 0.6783 - g_loss: 0.8173
# Epoch 198/400
# 8/8 [==============================] - 1s 129ms/step - d_loss: 0.6712 - g_loss: 0.8234
# Epoch 199/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6812 - g_loss: 0.8247
# Epoch 200/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6762 - g_loss: 0.8183
# Epoch 201/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6794 - g_loss: 0.8206
# Epoch 202/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6745 - g_loss: 0.8355
# Epoch 203/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6780 - g_loss: 0.8465
# Epoch 204/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6804 - g_loss: 0.8456
# Epoch 205/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6825 - g_loss: 0.8526
# Epoch 206/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6764 - g_loss: 0.8429
# Epoch 207/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6754 - g_loss: 0.8485
# Epoch 208/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6734 - g_loss: 0.8540
# Epoch 209/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6774 - g_loss: 0.8521
# Epoch 210/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6805 - g_loss: 0.8620
# Epoch 211/400
# 8/8 [==============================] - 1s 122ms/step - d_loss: 0.6746 - g_loss: 0.8592
# Epoch 212/400
# 8/8 [==============================] - 1s 124ms/step - d_loss: 0.6813 - g_loss: 0.8673
# Epoch 213/400
# 8/8 [==============================] - 1s 135ms/step - d_loss: 0.6770 - g_loss: 0.8673
# Epoch 214/400
# 8/8 [==============================] - 1s 137ms/step - d_loss: 0.6759 - g_loss: 0.8808
# Epoch 215/400
# 8/8 [==============================] - 1s 137ms/step - d_loss: 0.6747 - g_loss: 0.8776
# Epoch 216/400
# 8/8 [==============================] - 1s 106ms/step - d_loss: 0.6734 - g_loss: 0.8813
# Epoch 217/400
# 8/8 [==============================] - 1s 124ms/step - d_loss: 0.6754 - g_loss: 0.8784
# Epoch 218/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6704 - g_loss: 0.8892
# Epoch 219/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6731 - g_loss: 0.8898
# Epoch 220/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6766 - g_loss: 0.8885
# Epoch 221/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6775 - g_loss: 0.8900
# Epoch 222/400
# 8/8 [==============================] - 1s 130ms/step - d_loss: 0.6717 - g_loss: 0.8998
# Epoch 223/400
# 8/8 [==============================] - 1s 129ms/step - d_loss: 0.6753 - g_loss: 0.9054
# Epoch 224/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6717 - g_loss: 0.9010
# Epoch 225/400
# 8/8 [==============================] - 1s 123ms/step - d_loss: 0.6747 - g_loss: 0.9092
# Epoch 226/400
# 8/8 [==============================] - 1s 132ms/step - d_loss: 0.6706 - g_loss: 0.9058
# Epoch 227/400
# 8/8 [==============================] - 1s 130ms/step - d_loss: 0.6769 - g_loss: 0.9123
# Epoch 228/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6732 - g_loss: 0.9106
# Epoch 229/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6774 - g_loss: 0.9086
# Epoch 230/400
# 8/8 [==============================] - 1s 133ms/step - d_loss: 0.6689 - g_loss: 0.9142
# Epoch 231/400
# 8/8 [==============================] - 1s 134ms/step - d_loss: 0.6714 - g_loss: 0.9160
# Epoch 232/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6652 - g_loss: 0.9167
# Epoch 233/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6704 - g_loss: 0.9170
# Epoch 234/400
# 8/8 [==============================] - 1s 120ms/step - d_loss: 0.6726 - g_loss: 0.9237
# Epoch 235/400
# 8/8 [==============================] - 1s 123ms/step - d_loss: 0.6714 - g_loss: 0.9250
# Epoch 236/400
# 8/8 [==============================] - 1s 130ms/step - d_loss: 0.6711 - g_loss: 0.9257
# Epoch 237/400
# 8/8 [==============================] - 1s 106ms/step - d_loss: 0.6729 - g_loss: 0.9218
# Epoch 238/400
# 8/8 [==============================] - 1s 140ms/step - d_loss: 0.6708 - g_loss: 0.9291
# Epoch 239/400
# 8/8 [==============================] - 1s 154ms/step - d_loss: 0.6726 - g_loss: 0.9302
# Epoch 240/400
# 8/8 [==============================] - 1s 151ms/step - d_loss: 0.6661 - g_loss: 0.9323
# Epoch 241/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6720 - g_loss: 0.9305
# Epoch 242/400
# 8/8 [==============================] - 1s 132ms/step - d_loss: 0.6706 - g_loss: 0.9343
# Epoch 243/400
# 8/8 [==============================] - 1s 133ms/step - d_loss: 0.6630 - g_loss: 0.9345
# Epoch 244/400
# 8/8 [==============================] - 1s 123ms/step - d_loss: 0.6636 - g_loss: 0.9365
# Epoch 245/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6708 - g_loss: 0.9369
# Epoch 246/400
# 8/8 [==============================] - 1s 129ms/step - d_loss: 0.6764 - g_loss: 0.9386
# Epoch 247/400
# 8/8 [==============================] - 1s 136ms/step - d_loss: 0.6731 - g_loss: 0.9385
# Epoch 248/400
# 8/8 [==============================] - 1s 134ms/step - d_loss: 0.6639 - g_loss: 0.9411
# Epoch 249/400
# 8/8 [==============================] - 1s 130ms/step - d_loss: 0.6621 - g_loss: 0.9419
# Epoch 250/400
# 8/8 [==============================] - 1s 110ms/step - d_loss: 0.6667 - g_loss: 0.9431
# Epoch 251/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6566 - g_loss: 0.9436
# Epoch 252/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6688 - g_loss: 0.9448
# Epoch 253/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6627 - g_loss: 0.9470
# Epoch 254/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6663 - g_loss: 0.9501
# Epoch 255/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6643 - g_loss: 0.9481
# Epoch 256/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6593 - g_loss: 0.9521
# Epoch 257/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6589 - g_loss: 0.9522
# Epoch 258/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6624 - g_loss: 0.9527
# Epoch 259/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6636 - g_loss: 0.9562
# Epoch 260/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6675 - g_loss: 0.9565
# Epoch 261/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6651 - g_loss: 0.9586
# Epoch 262/400
# 8/8 [==============================] - 1s 117ms/step - d_loss: 0.6599 - g_loss: 0.9592
# Epoch 263/400
# 8/8 [==============================] - 1s 134ms/step - d_loss: 0.6576 - g_loss: 0.9578
# Epoch 264/400
# 8/8 [==============================] - 1s 134ms/step - d_loss: 0.6653 - g_loss: 0.9593
# Epoch 265/400
# 8/8 [==============================] - 1s 129ms/step - d_loss: 0.6650 - g_loss: 0.9608
# Epoch 266/400
# 8/8 [==============================] - 1s 130ms/step - d_loss: 0.6590 - g_loss: 0.9605
# Epoch 267/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6679 - g_loss: 0.9609
# Epoch 268/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6624 - g_loss: 0.9604
# Epoch 269/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6645 - g_loss: 0.9598
# Epoch 270/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6644 - g_loss: 0.9615
# Epoch 271/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6619 - g_loss: 0.9632
# Epoch 272/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6612 - g_loss: 0.9632
# Epoch 273/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6645 - g_loss: 0.9629
# Epoch 274/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6615 - g_loss: 0.9644
# Epoch 275/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6623 - g_loss: 0.9631
# Epoch 276/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6604 - g_loss: 0.9634
# Epoch 277/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6685 - g_loss: 0.9629
# Epoch 278/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6573 - g_loss: 0.9632
# Epoch 279/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6536 - g_loss: 0.9635
# Epoch 280/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6570 - g_loss: 0.9650
# Epoch 281/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6562 - g_loss: 0.9616
# Epoch 282/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6571 - g_loss: 0.9637
# Epoch 283/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6622 - g_loss: 0.9633
# Epoch 284/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6634 - g_loss: 0.9633
# Epoch 285/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6592 - g_loss: 0.9637
# Epoch 286/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6638 - g_loss: 0.9612
# Epoch 287/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6563 - g_loss: 0.9599
# Epoch 288/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6565 - g_loss: 0.9607
# Epoch 289/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6602 - g_loss: 0.9610
# Epoch 290/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6561 - g_loss: 0.9595
# Epoch 291/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6579 - g_loss: 0.9592
# Epoch 292/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6595 - g_loss: 0.9580
# Epoch 293/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6590 - g_loss: 0.9563
# Epoch 294/400
# 8/8 [==============================] - 1s 119ms/step - d_loss: 0.6597 - g_loss: 0.9582
# Epoch 295/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6528 - g_loss: 0.9553
# Epoch 296/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6559 - g_loss: 0.9570
# Epoch 297/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6600 - g_loss: 0.9564
# Epoch 298/400
# 8/8 [==============================] - 1s 123ms/step - d_loss: 0.6533 - g_loss: 0.9553
# Epoch 299/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6562 - g_loss: 0.9543
# Epoch 300/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6534 - g_loss: 0.9553
# Epoch 301/400
# 8/8 [==============================] - 1s 129ms/step - d_loss: 0.6584 - g_loss: 0.9536
# Epoch 302/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6571 - g_loss: 0.9532
# Epoch 303/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6566 - g_loss: 0.9532
# Epoch 304/400
# 8/8 [==============================] - 1s 122ms/step - d_loss: 0.6525 - g_loss: 0.9558
# Epoch 305/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6582 - g_loss: 0.9526
# Epoch 306/400
# 8/8 [==============================] - 1s 130ms/step - d_loss: 0.6591 - g_loss: 0.9524
# Epoch 307/400
# 8/8 [==============================] - 1s 119ms/step - d_loss: 0.6571 - g_loss: 0.9504
# Epoch 308/400
# 8/8 [==============================] - 1s 119ms/step - d_loss: 0.6540 - g_loss: 0.9488
# Epoch 309/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6499 - g_loss: 0.9489
# Epoch 310/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6527 - g_loss: 0.9487
# Epoch 311/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6530 - g_loss: 0.9494
# Epoch 312/400
# 8/8 [==============================] - 1s 121ms/step - d_loss: 0.6561 - g_loss: 0.9478
# Epoch 313/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6549 - g_loss: 0.9483
# Epoch 314/400
# 8/8 [==============================] - 1s 129ms/step - d_loss: 0.6551 - g_loss: 0.9485
# Epoch 315/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6524 - g_loss: 0.9464
# Epoch 316/400
# 8/8 [==============================] - 1s 124ms/step - d_loss: 0.6555 - g_loss: 0.9466
# Epoch 317/400
# 8/8 [==============================] - 1s 136ms/step - d_loss: 0.6523 - g_loss: 0.9459
# Epoch 318/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6536 - g_loss: 0.9458
# Epoch 319/400
# 8/8 [==============================] - 1s 122ms/step - d_loss: 0.6566 - g_loss: 0.9419
# Epoch 320/400
# 8/8 [==============================] - 1s 131ms/step - d_loss: 0.6545 - g_loss: 0.9406
# Epoch 321/400
# 8/8 [==============================] - 1s 135ms/step - d_loss: 0.6578 - g_loss: 0.9400
# Epoch 322/400
# 8/8 [==============================] - 1s 110ms/step - d_loss: 0.6520 - g_loss: 0.9411
# Epoch 323/400
# 8/8 [==============================] - 1s 151ms/step - d_loss: 0.6583 - g_loss: 0.9376
# Epoch 324/400
# 8/8 [==============================] - 1s 114ms/step - d_loss: 0.6594 - g_loss: 0.9369
# Epoch 325/400
# 8/8 [==============================] - 1s 138ms/step - d_loss: 0.6601 - g_loss: 0.9369
# Epoch 326/400
# 8/8 [==============================] - 1s 160ms/step - d_loss: 0.6567 - g_loss: 0.9341
# Epoch 327/400
# 8/8 [==============================] - 1s 122ms/step - d_loss: 0.6566 - g_loss: 0.9336
# Epoch 328/400
# 8/8 [==============================] - 1s 162ms/step - d_loss: 0.6526 - g_loss: 0.9289
# Epoch 329/400
# 8/8 [==============================] - 1s 155ms/step - d_loss: 0.6610 - g_loss: 0.9295
# Epoch 330/400
# 8/8 [==============================] - 1s 139ms/step - d_loss: 0.6592 - g_loss: 0.9317
# Epoch 331/400
# 8/8 [==============================] - 1s 162ms/step - d_loss: 0.6622 - g_loss: 0.9292
# Epoch 332/400
# 8/8 [==============================] - 1s 171ms/step - d_loss: 0.6559 - g_loss: 0.9284
# Epoch 333/400
# 8/8 [==============================] - 1s 173ms/step - d_loss: 0.6654 - g_loss: 0.9275
# Epoch 334/400
# 8/8 [==============================] - 1s 159ms/step - d_loss: 0.6633 - g_loss: 0.9284
# Epoch 335/400
# 8/8 [==============================] - 1s 162ms/step - d_loss: 0.6581 - g_loss: 0.9280
# Epoch 336/400
# 8/8 [==============================] - 1s 145ms/step - d_loss: 0.6578 - g_loss: 0.9283
# Epoch 337/400
# 8/8 [==============================] - 1s 145ms/step - d_loss: 0.6630 - g_loss: 0.9275
# Epoch 338/400
# 8/8 [==============================] - 1s 130ms/step - d_loss: 0.6619 - g_loss: 0.9259
# Epoch 339/400
# 8/8 [==============================] - 1s 131ms/step - d_loss: 0.6606 - g_loss: 0.9260
# Epoch 340/400
# 8/8 [==============================] - 1s 111ms/step - d_loss: 0.6605 - g_loss: 0.9264
# Epoch 341/400
# 8/8 [==============================] - 1s 112ms/step - d_loss: 0.6590 - g_loss: 0.9266
# Epoch 342/400
# 8/8 [==============================] - 1s 129ms/step - d_loss: 0.6652 - g_loss: 0.9258
# Epoch 343/400
# 8/8 [==============================] - 1s 134ms/step - d_loss: 0.6601 - g_loss: 0.9245
# Epoch 344/400
# 8/8 [==============================] - 1s 117ms/step - d_loss: 0.6640 - g_loss: 0.9257
# Epoch 345/400
# 8/8 [==============================] - 1s 122ms/step - d_loss: 0.6625 - g_loss: 0.9318
# Epoch 346/400
# 8/8 [==============================] - 1s 119ms/step - d_loss: 0.6695 - g_loss: 0.9256
# Epoch 347/400
# 8/8 [==============================] - 1s 148ms/step - d_loss: 0.6624 - g_loss: 0.9232
# Epoch 348/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6632 - g_loss: 0.9248
# Epoch 349/400
# 8/8 [==============================] - 1s 142ms/step - d_loss: 0.6623 - g_loss: 0.9239
# Epoch 350/400
# 8/8 [==============================] - 1s 137ms/step - d_loss: 0.6640 - g_loss: 0.9248
# Epoch 351/400
# 8/8 [==============================] - 1s 143ms/step - d_loss: 0.6633 - g_loss: 0.9220
# Epoch 352/400
# 8/8 [==============================] - 1s 133ms/step - d_loss: 0.6640 - g_loss: 0.9237
# Epoch 353/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6608 - g_loss: 0.9231
# Epoch 354/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6626 - g_loss: 0.9222
# Epoch 355/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6678 - g_loss: 0.9230
# Epoch 356/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6690 - g_loss: 0.9201
# Epoch 357/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6647 - g_loss: 0.9207
# Epoch 358/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6719 - g_loss: 0.9209
# Epoch 359/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6663 - g_loss: 0.9193
# Epoch 360/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6601 - g_loss: 0.9178
# Epoch 361/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6699 - g_loss: 0.9174
# Epoch 362/400
# 8/8 [==============================] - 1s 124ms/step - d_loss: 0.6627 - g_loss: 0.9184
# Epoch 363/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6647 - g_loss: 0.9176
# Epoch 364/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6658 - g_loss: 0.9162
# Epoch 365/400
# 8/8 [==============================] - 1s 119ms/step - d_loss: 0.6666 - g_loss: 0.9159
# Epoch 366/400
# 8/8 [==============================] - 1s 131ms/step - d_loss: 0.6645 - g_loss: 0.9148
# Epoch 367/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6690 - g_loss: 0.9155
# Epoch 368/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6693 - g_loss: 0.9141
# Epoch 369/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6620 - g_loss: 0.9145
# Epoch 370/400
# 8/8 [==============================] - 1s 112ms/step - d_loss: 0.6728 - g_loss: 0.9149
# Epoch 371/400
# 8/8 [==============================] - 1s 115ms/step - d_loss: 0.6682 - g_loss: 0.9128
# Epoch 372/400
# 8/8 [==============================] - 1s 123ms/step - d_loss: 0.6669 - g_loss: 0.9119
# Epoch 373/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6631 - g_loss: 0.9106
# Epoch 374/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6660 - g_loss: 0.9114
# Epoch 375/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6631 - g_loss: 0.9112
# Epoch 376/400
# 8/8 [==============================] - 1s 121ms/step - d_loss: 0.6637 - g_loss: 0.9112
# Epoch 377/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6688 - g_loss: 0.9085
# Epoch 378/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6678 - g_loss: 0.9101
# Epoch 379/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6702 - g_loss: 0.9072
# Epoch 380/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6655 - g_loss: 0.9072
# Epoch 381/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6677 - g_loss: 0.9084
# Epoch 382/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6740 - g_loss: 0.9050
# Epoch 383/400
# 8/8 [==============================] - 1s 131ms/step - d_loss: 0.6661 - g_loss: 0.9075
# Epoch 384/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6687 - g_loss: 0.9059
# Epoch 385/400
# 8/8 [==============================] - 1s 120ms/step - d_loss: 0.6687 - g_loss: 0.9042
# Epoch 386/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6649 - g_loss: 0.9050
# Epoch 387/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6653 - g_loss: 0.9031
# Epoch 388/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6654 - g_loss: 0.9027
# Epoch 389/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6699 - g_loss: 0.9008
# Epoch 390/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6647 - g_loss: 0.9014
# Epoch 391/400
# 8/8 [==============================] - 1s 128ms/step - d_loss: 0.6687 - g_loss: 0.8998
# Epoch 392/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6620 - g_loss: 0.9020
# Epoch 393/400
# 8/8 [==============================] - 1s 126ms/step - d_loss: 0.6687 - g_loss: 0.9009
# Epoch 394/400
# 8/8 [==============================] - 1s 127ms/step - d_loss: 0.6620 - g_loss: 0.8999
# Epoch 395/400
# 8/8 [==============================] - 1s 135ms/step - d_loss: 0.6713 - g_loss: 0.8977
# Epoch 396/400
# 8/8 [==============================] - 1s 117ms/step - d_loss: 0.6664 - g_loss: 0.8998
# Epoch 397/400
# 8/8 [==============================] - 1s 124ms/step - d_loss: 0.6660 - g_loss: 0.8990
# Epoch 398/400
# 8/8 [==============================] - 1s 125ms/step - d_loss: 0.6683 - g_loss: 0.8988
# Epoch 399/400
# 8/8 [==============================] - 1s 139ms/step - d_loss: 0.6699 - g_loss: 0.8982
# Epoch 400/400
# 8/8 [==============================] - 1s 147ms/step - d_loss: 0.6716 - g_loss: 0.8970

# %%
if True:
    scenario_size = 30
    normal_noise = tf.random.normal((scenario_size, batch_size, 1))
    n = [np.random.normal() for _ in range(scenario_size)]
    series = np.multiply(generator.predict(normal_noise), max)
    resolution = 24

    probabilities = []
    ranges = np.linspace(-3.5, 3.5, 8)
    intervals = np.linspace(-3, 3, 7)
    probs = [stats.norm.cdf(i) for i in n]
    prob_ranges = {intervals[i]: [stats.norm.cdf(ranges[i]), stats.norm.cdf(ranges[i+1])] for i in range(len(intervals))}
    for i in probs:
        for key in intervals:
            if prob_ranges[key][0]<= i <=prob_ranges[key][1]:
                probabilities.append(prob_ranges[key][1]-prob_ranges[key][0])
                break
    scenarios = {'probs': probabilities}
    for j in range(resolution):
        scenarios[j] = []
    for i in range(scenario_size):
        s = series[i].reshape([resolution])
        for j in range(resolution):
            scenarios[j].append(s[j])
pd.DataFrame(scenarios).to_csv(f'PVscenario-{month_name}.csv')
if True:
    ticks = [i for i in range(resolution)]
    fig, ax = plt.subplots(1, 2, figsize=(15, 4), dpi=200)
    for s in series[:12]:
        ax[0].plot(range(resolution), s.reshape([resolution]), linewidth=1)
    ax[0].set_xlabel('Timestamp (15 min)')
    ax[0].set_ylabel('Generated Power Consumption')
    ax[0].set_xticks(ticks, ticks)
    ax[0].grid(color='#666362', linestyle='-', linewidth=0.1)

    ax[1].plot(my_data[[c for c in my_data.columns][4:15]], linewidth=1)
    ax[1].set_xlabel('Timestamp (15 min)')
    ax[1].set_ylabel('Historical Power Consumption')
    ax[1].set_xticks(ticks, ticks)
    ax[1].grid(color='#666362', linestyle='-', linewidth=0.1)
    plt.subplots_adjust(wspace=0.1)
#plt.savefig(f'PV GAN {month_name}.jpg', bbox_inches='tight')
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %% [markdown]
# ### Save models

# %%
plt.figure(figsize=(7, 3), dpi=300)
plt.plot(hist.history['d_loss'], label='Generator Loss')
plt.plot(hist.history['g_loss'], label='Discriminator Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(color='#666362', linestyle='-', linewidth=0.1)
plt.savefig(f'IMG/{month_name}-{day_type}-loss.jpg', bbox_inches='tight')

# %%
import random
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
from keras.callbacks import Callback
from keras.utils import array_to_img
from keras import Sequential
from keras.layers import Conv2D, Dense, Flatten, Reshape, LeakyReLU, Dropout
from keras.activations import tanh
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from keras.models import Model
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.reset_memory_stats(gpu, True)
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('ignore')

# %%
pv_year = pd.read_csv('hourly.csv')[['Month', 'Day', 'Hour', 'DC Output (W)']]
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
for m in range(1, 13):
    mask = pv_year['Month'] == m
    to_save = {}
    for t in range(int(len(pv_year[mask]['DC Output (W)'])/24)):
        to_save[t] = np.divide(pv_year[mask]['DC Output (W)'].iloc[t*24:(t+1)*24].values, 1000)
    counter = 1
    while counter <= 30:
        c1 = random.choice(list(to_save.keys()))
        c2 = random.choice(list(to_save.keys()))
        while True:
            if c2 == c1:
                c2 = random.choice(list(to_save.keys()))
            else:
                break
        to_save[f'g{counter}'] = np.divide(to_save[c1] + to_save[c2], 2)
        counter += 1
    pd.DataFrame(to_save).to_csv(f'PV-{months[m-1]}.csv')

# %%
month_name='Dec'
my_data = pd.read_csv(f'PV-{month_name}.csv')
ds = []
for c in my_data.columns[1:]:
        ds.append([my_data[c].values])
max = np.max(ds)
ds = np.divide(ds, max)

# %% [markdown]
# ### Prepare data to feed into GAN

# %%
ds = tf.data.Dataset.from_tensor_slices(ds)
batch_size = 5
ds = ds.cache()
ds = ds.shuffle(1000)
ds = ds.batch(batch_size)
ds = ds.prefetch(64)

# %% [markdown]
# ## Generator Discriminator Training

# %%
'''Generator'''
g_relu = 0.2
def build_generator():
    model = Sequential()

    model.add(Dense(1*24*batch_size, input_dim=batch_size))
    model.add(LeakyReLU(g_relu))
    model.add(Reshape((1,24, batch_size)))

    #model.add(UpSamplingD())
    model.add(Conv2D(batch_size, 3, padding='same'))
    model.add(LeakyReLU(g_relu))

    model.add(Conv2D(batch_size, 3, padding='same'))
    model.add(LeakyReLU(g_relu))

    model.add(Conv2D(batch_size, 3, padding='same'))
    model.add(LeakyReLU(g_relu))

    model.add(Conv2D(batch_size, 3, padding='same'))
    model.add(LeakyReLU(g_relu))

    model.add(Conv2D(1, 3, padding='same', activation='sigmoid'))
    return model
generator = build_generator()


'''Discriminator'''
d_relu = 0.2
d_dropout = 0.2
def build_discriminator():
    model = Sequential()

    model.add(Dense(200, input_shape=(1, 24, 1)))
    model.add(LeakyReLU(d_relu))
    model.add(Dropout(d_dropout))

    model.add(Dense(150))
    model.add(LeakyReLU(d_relu))
    model.add(Dropout(d_dropout))

    model.add(Flatten())
    model.add(Dropout(d_dropout))
    model.add(Dense(1, activation='sigmoid'))
    # 1: fake series, 0: real series

    return model
discriminator = build_discriminator()

'''Train'''
g_a, d_a = 0.0001, 0.00001
g_opt = Adam(learning_rate=g_a)
d_opt = Adam(learning_rate=d_a)  # Does not learn too fast
g_loss = BinaryCrossentropy()
d_loss = BinaryCrossentropy()
class LoadGAN(Model):
    def __init__(self, generator, discriminator, *args, **kwargs):
        # pass through args and kwargs to base class
        super().__init__(*args, **kwargs)
        # Create attributes for gen and disc
        self.generator = generator
        self.discriminator = discriminator

    def compilee(self, g_opt, d_opt, g_loss, d_loss, *args, **kwargs):
        # Compile with base class
        super().compile(*args, **kwargs)

        self.g_opt = g_opt
        self.d_opt = d_opt
        self.g_loss = g_loss
        self.d_loss = d_loss

    def train_step(self, batch):
        real_series = batch
        fake_series = self.generator(tf.random.normal((batch_size, batch_size, 1)), training=False)

        # train the discriminator
        with tf.GradientTape() as d_tape:
            # pass the real and fake images
            yhat_real = self.discriminator(real_series, training=True)
            yhat_fake = self.discriminator(fake_series, training=True)
            yhat_realfake = tf.concat([yhat_real, yhat_fake], axis=0)

            # create labels for real and fake series
            y_realfake = tf.concat([tf.zeros_like(yhat_real), tf.ones_like(yhat_fake)], axis=0)


            # pass through and add some noise to the outputs
            noise_real = 0.15*tf.random.uniform(tf.shape(yhat_real))
            noise_fake = 0.15*tf.random.uniform(tf.shape(yhat_fake))
            y_realfake += tf.concat([noise_real, noise_fake], axis=0)

            # calculate the loss
            total_d_loss = self.d_loss(y_realfake, yhat_realfake)

        # apply backpropagation
        dgrad = d_tape.gradient(total_d_loss, self.discriminator.trainable_variables)
        self.d_opt.apply_gradients(zip(dgrad, self.discriminator.trainable_variables))

        # Generator training
        with tf.GradientTape() as g_tape:
            # generate same new images
            gen_series = self.generator(tf.random.normal((batch_size, batch_size, 1)), training=True)

            # create the predicted labels
            predicted_labels = self.discriminator(gen_series, training=False)

            # calculate loss
            total_g_loss = self.g_loss(tf.zeros_like(predicted_labels), predicted_labels)

        # apply backpropagation
        ggrad = g_tape.gradient(total_g_loss, self.generator.trainable_variables)
        self.g_opt.apply_gradients(zip(ggrad, self.generator.trainable_variables))

        return {"d_loss":total_d_loss, "g_loss":total_g_loss}
loadgan = LoadGAN(generator, discriminator)
loadgan.compilee(g_opt, d_opt, g_loss, d_loss)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 25
#      23     model.add(Conv2D(1, 3, padding='same', activation='sigmoid'))
#      24     return model
# ---> 25 generator = build_generator()
#      28 '''Discriminator'''
#      29 d_relu = 0.2
#
# Cell In[6], line 12, in build_generator()
#      10 #model.add(UpSamplingD())
#      11 model.add(Conv2D(batch_size, 3, padding='same'))
# ---> 12 model.add(tanh())
#      14 model.add(Conv2D(batch_size, 3, padding='same'))
#      15 model.add(tanh())
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\dispatch.py:1170, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1168 if iterable_params is not None:
#    1169   args, kwargs = replace_iterable_params(args, kwargs, iterable_params)
# -> 1170 result = api_dispatcher.Dispatch(args, kwargs)
#    1171 if result is not NotImplemented:
#    1172   return result
#
# TypeError: Missing required positional argument

# %% [markdown]
# #### Call Back

# %%
class ModelMonitor(Callback):
    def __init__(self, num_img=3, latent_dim=batch_size):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vector = tf.random.uniform((self.num_img, self.latent_dim, 1))
        generated_series = self.model.generator(random_latent_vector)
        generated_series *= max
        generated_series.numpy()
        for i in range(self.num_img):
            serie = array_to_img(generated_series[i])

# %% [markdown]
# #### Train

# %%
hist = loadgan.fit(ds, epochs=300)
# Out:
# Epoch 1/300
# 13/13 [==============================] - 1s 77ms/step - d_loss: 0.6930 - g_loss: 0.7032
# Epoch 2/300
# 13/13 [==============================] - 1s 75ms/step - d_loss: 0.6899 - g_loss: 0.7106
# Epoch 3/300
# 13/13 [==============================] - 1s 86ms/step - d_loss: 0.6833 - g_loss: 0.7181
# Epoch 4/300
# 13/13 [==============================] - 2s 118ms/step - d_loss: 0.6790 - g_loss: 0.7256
# Epoch 5/300
# 13/13 [==============================] - 3s 218ms/step - d_loss: 0.6760 - g_loss: 0.7331
# Epoch 6/300
# 13/13 [==============================] - 2s 133ms/step - d_loss: 0.6740 - g_loss: 0.7406
# Epoch 7/300
# 13/13 [==============================] - 3s 227ms/step - d_loss: 0.6675 - g_loss: 0.7479
# Epoch 8/300
# 13/13 [==============================] - 3s 195ms/step - d_loss: 0.6641 - g_loss: 0.7553
# Epoch 9/300
# 13/13 [==============================] - 2s 144ms/step - d_loss: 0.6634 - g_loss: 0.7626
# Epoch 10/300
# 13/13 [==============================] - 1s 104ms/step - d_loss: 0.6576 - g_loss: 0.7698
# Epoch 11/300
# 13/13 [==============================] - 2s 145ms/step - d_loss: 0.6505 - g_loss: 0.7771
# Epoch 12/300
# 13/13 [==============================] - 1s 101ms/step - d_loss: 0.6511 - g_loss: 0.7843
# Epoch 13/300
# 13/13 [==============================] - 1s 105ms/step - d_loss: 0.6439 - g_loss: 0.7917
# Epoch 14/300
# 13/13 [==============================] - 1s 81ms/step - d_loss: 0.6466 - g_loss: 0.7989
# Epoch 15/300
# 13/13 [==============================] - 1s 84ms/step - d_loss: 0.6403 - g_loss: 0.8060
# Epoch 16/300
# 13/13 [==============================] - 1s 103ms/step - d_loss: 0.6358 - g_loss: 0.8131
# Epoch 17/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6342 - g_loss: 0.8201
# Epoch 18/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6301 - g_loss: 0.8270
# Epoch 19/300
# 13/13 [==============================] - 1s 80ms/step - d_loss: 0.6298 - g_loss: 0.8337
# Epoch 20/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.6265 - g_loss: 0.8405
# Epoch 21/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6228 - g_loss: 0.8471
# Epoch 22/300
# 13/13 [==============================] - 1s 99ms/step - d_loss: 0.6198 - g_loss: 0.8533
# Epoch 23/300
# 13/13 [==============================] - 1s 102ms/step - d_loss: 0.6191 - g_loss: 0.8594
# Epoch 24/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6189 - g_loss: 0.8648
# Epoch 25/300
# 13/13 [==============================] - 1s 114ms/step - d_loss: 0.6110 - g_loss: 0.8700
# Epoch 26/300
# 13/13 [==============================] - 1s 105ms/step - d_loss: 0.6106 - g_loss: 0.8748
# Epoch 27/300
# 13/13 [==============================] - 1s 104ms/step - d_loss: 0.6065 - g_loss: 0.8793
# Epoch 28/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6057 - g_loss: 0.8826
# Epoch 29/300
# 13/13 [==============================] - 2s 119ms/step - d_loss: 0.6043 - g_loss: 0.8860
# Epoch 30/300
# 13/13 [==============================] - 1s 111ms/step - d_loss: 0.6045 - g_loss: 0.8880
# Epoch 31/300
# 13/13 [==============================] - 2s 119ms/step - d_loss: 0.6023 - g_loss: 0.8885
# Epoch 32/300
# 13/13 [==============================] - 2s 127ms/step - d_loss: 0.6032 - g_loss: 0.8882
# Epoch 33/300
# 13/13 [==============================] - 2s 117ms/step - d_loss: 0.6027 - g_loss: 0.8878
# Epoch 34/300
# 13/13 [==============================] - 1s 114ms/step - d_loss: 0.6058 - g_loss: 0.8848
# Epoch 35/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6112 - g_loss: 0.8813
# Epoch 36/300
# 13/13 [==============================] - 1s 115ms/step - d_loss: 0.6089 - g_loss: 0.8754
# Epoch 37/300
# 13/13 [==============================] - 2s 119ms/step - d_loss: 0.6071 - g_loss: 0.8696
# Epoch 38/300
# 13/13 [==============================] - 1s 108ms/step - d_loss: 0.6159 - g_loss: 0.8640
# Epoch 39/300
# 13/13 [==============================] - 1s 111ms/step - d_loss: 0.6142 - g_loss: 0.8547
# Epoch 40/300
# 13/13 [==============================] - 2s 135ms/step - d_loss: 0.6258 - g_loss: 0.8479
# Epoch 41/300
# 13/13 [==============================] - 1s 104ms/step - d_loss: 0.6245 - g_loss: 0.8409
# Epoch 42/300
# 13/13 [==============================] - 1s 97ms/step - d_loss: 0.6276 - g_loss: 0.8293
# Epoch 43/300
# 13/13 [==============================] - 1s 109ms/step - d_loss: 0.6300 - g_loss: 0.8185
# Epoch 44/300
# 13/13 [==============================] - 1s 105ms/step - d_loss: 0.6380 - g_loss: 0.8122
# Epoch 45/300
# 13/13 [==============================] - 1s 115ms/step - d_loss: 0.6398 - g_loss: 0.8024
# Epoch 46/300
# 13/13 [==============================] - 2s 126ms/step - d_loss: 0.6404 - g_loss: 0.7969
# Epoch 47/300
# 13/13 [==============================] - 2s 118ms/step - d_loss: 0.6428 - g_loss: 0.7900
# Epoch 48/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6461 - g_loss: 0.7833
# Epoch 49/300
# 13/13 [==============================] - 1s 102ms/step - d_loss: 0.6455 - g_loss: 0.7774
# Epoch 50/300
# 13/13 [==============================] - 2s 126ms/step - d_loss: 0.6483 - g_loss: 0.7701
# Epoch 51/300
# 13/13 [==============================] - 2s 120ms/step - d_loss: 0.6489 - g_loss: 0.7675
# Epoch 52/300
# 13/13 [==============================] - 1s 113ms/step - d_loss: 0.6532 - g_loss: 0.7632
# Epoch 53/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6517 - g_loss: 0.7602
# Epoch 54/300
# 13/13 [==============================] - 1s 112ms/step - d_loss: 0.6528 - g_loss: 0.7569
# Epoch 55/300
# 13/13 [==============================] - 1s 95ms/step - d_loss: 0.6561 - g_loss: 0.7555
# Epoch 56/300
# 13/13 [==============================] - 2s 120ms/step - d_loss: 0.6529 - g_loss: 0.7501
# Epoch 57/300
# 13/13 [==============================] - 1s 108ms/step - d_loss: 0.6512 - g_loss: 0.7491
# Epoch 58/300
# 13/13 [==============================] - 2s 114ms/step - d_loss: 0.6480 - g_loss: 0.7475
# Epoch 59/300
# 13/13 [==============================] - 2s 116ms/step - d_loss: 0.6514 - g_loss: 0.7461
# Epoch 60/300
# 13/13 [==============================] - 1s 114ms/step - d_loss: 0.6489 - g_loss: 0.7445
# Epoch 61/300
# 13/13 [==============================] - 2s 119ms/step - d_loss: 0.6512 - g_loss: 0.7445
# Epoch 62/300
# 13/13 [==============================] - 1s 104ms/step - d_loss: 0.6476 - g_loss: 0.7449
# Epoch 63/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6467 - g_loss: 0.7426
# Epoch 64/300
# 13/13 [==============================] - 1s 102ms/step - d_loss: 0.6437 - g_loss: 0.7456
# Epoch 65/300
# 13/13 [==============================] - 2s 141ms/step - d_loss: 0.6462 - g_loss: 0.7443
# Epoch 66/300
# 13/13 [==============================] - 1s 105ms/step - d_loss: 0.6410 - g_loss: 0.7452
# Epoch 67/300
# 13/13 [==============================] - 1s 99ms/step - d_loss: 0.6383 - g_loss: 0.7452
# Epoch 68/300
# 13/13 [==============================] - 1s 99ms/step - d_loss: 0.6389 - g_loss: 0.7455
# Epoch 69/300
# 13/13 [==============================] - 2s 127ms/step - d_loss: 0.6381 - g_loss: 0.7464
# Epoch 70/300
# 13/13 [==============================] - 2s 121ms/step - d_loss: 0.6331 - g_loss: 0.7482
# Epoch 71/300
# 13/13 [==============================] - 1s 104ms/step - d_loss: 0.6323 - g_loss: 0.7482
# Epoch 72/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6289 - g_loss: 0.7487
# Epoch 73/300
# 13/13 [==============================] - 2s 125ms/step - d_loss: 0.6281 - g_loss: 0.7498
# Epoch 74/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6280 - g_loss: 0.7518
# Epoch 75/300
# 13/13 [==============================] - 2s 117ms/step - d_loss: 0.6256 - g_loss: 0.7511
# Epoch 76/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.6249 - g_loss: 0.7524
# Epoch 77/300
# 13/13 [==============================] - 2s 146ms/step - d_loss: 0.6207 - g_loss: 0.7532
# Epoch 78/300
# 13/13 [==============================] - 2s 129ms/step - d_loss: 0.6187 - g_loss: 0.7538
# Epoch 79/300
# 13/13 [==============================] - 2s 114ms/step - d_loss: 0.6159 - g_loss: 0.7556
# Epoch 80/300
# 13/13 [==============================] - 1s 112ms/step - d_loss: 0.6145 - g_loss: 0.7563
# Epoch 81/300
# 13/13 [==============================] - 2s 136ms/step - d_loss: 0.6127 - g_loss: 0.7572
# Epoch 82/300
# 13/13 [==============================] - 1s 112ms/step - d_loss: 0.6105 - g_loss: 0.7583
# Epoch 83/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.6088 - g_loss: 0.7603
# Epoch 84/300
# 13/13 [==============================] - 1s 91ms/step - d_loss: 0.6033 - g_loss: 0.7615
# Epoch 85/300
# 13/13 [==============================] - 1s 97ms/step - d_loss: 0.6035 - g_loss: 0.7635
# Epoch 86/300
# 13/13 [==============================] - 1s 96ms/step - d_loss: 0.6038 - g_loss: 0.7641
# Epoch 87/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6010 - g_loss: 0.7662
# Epoch 88/300
# 13/13 [==============================] - 1s 102ms/step - d_loss: 0.5973 - g_loss: 0.7675
# Epoch 89/300
# 13/13 [==============================] - 1s 93ms/step - d_loss: 0.5937 - g_loss: 0.7681
# Epoch 90/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.5911 - g_loss: 0.7711
# Epoch 91/300
# 13/13 [==============================] - 2s 116ms/step - d_loss: 0.5912 - g_loss: 0.7725
# Epoch 92/300
# 13/13 [==============================] - 2s 125ms/step - d_loss: 0.5882 - g_loss: 0.7745
# Epoch 93/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.5825 - g_loss: 0.7761
# Epoch 94/300
# 13/13 [==============================] - 2s 140ms/step - d_loss: 0.5866 - g_loss: 0.7769
# Epoch 95/300
# 13/13 [==============================] - 1s 108ms/step - d_loss: 0.5798 - g_loss: 0.7786
# Epoch 96/300
# 13/13 [==============================] - 2s 116ms/step - d_loss: 0.5818 - g_loss: 0.7795
# Epoch 97/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.5756 - g_loss: 0.7839
# Epoch 98/300
# 13/13 [==============================] - 1s 111ms/step - d_loss: 0.5763 - g_loss: 0.7830
# Epoch 99/300
# 13/13 [==============================] - 1s 99ms/step - d_loss: 0.5714 - g_loss: 0.7846
# Epoch 100/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.5674 - g_loss: 0.7874
# Epoch 101/300
# 13/13 [==============================] - 1s 114ms/step - d_loss: 0.5649 - g_loss: 0.7901
# Epoch 102/300
# 13/13 [==============================] - 1s 115ms/step - d_loss: 0.5677 - g_loss: 0.7857
# Epoch 103/300
# 13/13 [==============================] - 2s 119ms/step - d_loss: 0.5654 - g_loss: 0.7915
# Epoch 104/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.5630 - g_loss: 0.7880
# Epoch 105/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.5643 - g_loss: 0.7906
# Epoch 106/300
# 13/13 [==============================] - 1s 111ms/step - d_loss: 0.5598 - g_loss: 0.7910
# Epoch 107/300
# 13/13 [==============================] - 2s 127ms/step - d_loss: 0.5614 - g_loss: 0.7900
# Epoch 108/300
# 13/13 [==============================] - 1s 102ms/step - d_loss: 0.5634 - g_loss: 0.7882
# Epoch 109/300
# 13/13 [==============================] - 1s 111ms/step - d_loss: 0.5631 - g_loss: 0.7909
# Epoch 110/300
# 13/13 [==============================] - 1s 104ms/step - d_loss: 0.5625 - g_loss: 0.7819
# Epoch 111/300
# 13/13 [==============================] - 2s 114ms/step - d_loss: 0.5666 - g_loss: 0.7844
# Epoch 112/300
# 13/13 [==============================] - 1s 103ms/step - d_loss: 0.5647 - g_loss: 0.7739
# Epoch 113/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.5802 - g_loss: 0.7780
# Epoch 114/300
# 13/13 [==============================] - 2s 127ms/step - d_loss: 0.5619 - g_loss: 0.7717
# Epoch 115/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.5777 - g_loss: 0.7255
# Epoch 116/300
# 13/13 [==============================] - 2s 121ms/step - d_loss: 0.5813 - g_loss: 0.7577
# Epoch 117/300
# 13/13 [==============================] - 1s 112ms/step - d_loss: 0.5817 - g_loss: 0.7536
# Epoch 118/300
# 13/13 [==============================] - 2s 120ms/step - d_loss: 0.5871 - g_loss: 0.7394
# Epoch 119/300
# 13/13 [==============================] - 2s 130ms/step - d_loss: 0.6193 - g_loss: 0.7311
# Epoch 120/300
# 13/13 [==============================] - 1s 112ms/step - d_loss: 0.6304 - g_loss: 0.6980
# Epoch 121/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6075 - g_loss: 0.7126
# Epoch 122/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6197 - g_loss: 0.7295
# Epoch 123/300
# 13/13 [==============================] - 2s 117ms/step - d_loss: 0.6158 - g_loss: 0.6970
# Epoch 124/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.6545 - g_loss: 0.6814
# Epoch 125/300
# 13/13 [==============================] - 1s 101ms/step - d_loss: 0.6343 - g_loss: 0.6851
# Epoch 126/300
# 13/13 [==============================] - 2s 124ms/step - d_loss: 0.6887 - g_loss: 0.6211
# Epoch 127/300
# 13/13 [==============================] - 2s 119ms/step - d_loss: 0.6391 - g_loss: 0.6141
# Epoch 128/300
# 13/13 [==============================] - 2s 125ms/step - d_loss: 0.7158 - g_loss: 0.6180
# Epoch 129/300
# 13/13 [==============================] - 1s 99ms/step - d_loss: 0.6720 - g_loss: 0.6876
# Epoch 130/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.6871 - g_loss: 0.6288
# Epoch 131/300
# 13/13 [==============================] - 2s 123ms/step - d_loss: 0.6713 - g_loss: 0.6532
# Epoch 132/300
# 13/13 [==============================] - 1s 102ms/step - d_loss: 0.7278 - g_loss: 0.6043
# Epoch 133/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.7041 - g_loss: 0.6117
# Epoch 134/300
# 13/13 [==============================] - 2s 130ms/step - d_loss: 0.7203 - g_loss: 0.6734
# Epoch 135/300
# 13/13 [==============================] - 2s 127ms/step - d_loss: 0.7152 - g_loss: 0.6074
# Epoch 136/300
# 13/13 [==============================] - 1s 117ms/step - d_loss: 0.7441 - g_loss: 0.5947
# Epoch 137/300
# 13/13 [==============================] - 2s 119ms/step - d_loss: 0.6991 - g_loss: 0.6617
# Epoch 138/300
# 13/13 [==============================] - 2s 130ms/step - d_loss: 0.7285 - g_loss: 0.6742
# Epoch 139/300
# 13/13 [==============================] - 2s 129ms/step - d_loss: 0.7225 - g_loss: 0.6335
# Epoch 140/300
# 13/13 [==============================] - 1s 99ms/step - d_loss: 0.7008 - g_loss: 0.6666
# Epoch 141/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.7133 - g_loss: 0.6896
# Epoch 142/300
# 13/13 [==============================] - 2s 121ms/step - d_loss: 0.7279 - g_loss: 0.6883
# Epoch 143/300
# 13/13 [==============================] - 1s 104ms/step - d_loss: 0.7122 - g_loss: 0.7211
# Epoch 144/300
# 13/13 [==============================] - 2s 129ms/step - d_loss: 0.7250 - g_loss: 0.7114
# Epoch 145/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.7033 - g_loss: 0.7122
# Epoch 146/300
# 13/13 [==============================] - 1s 116ms/step - d_loss: 0.6977 - g_loss: 0.7387
# Epoch 147/300
# 13/13 [==============================] - 2s 125ms/step - d_loss: 0.7148 - g_loss: 0.7222
# Epoch 148/300
# 13/13 [==============================] - 2s 111ms/step - d_loss: 0.7123 - g_loss: 0.7419
# Epoch 149/300
# 13/13 [==============================] - 2s 119ms/step - d_loss: 0.7121 - g_loss: 0.7310
# Epoch 150/300
# 13/13 [==============================] - 1s 96ms/step - d_loss: 0.7112 - g_loss: 0.7991
# Epoch 151/300
# 13/13 [==============================] - 2s 116ms/step - d_loss: 0.6942 - g_loss: 0.7748
# Epoch 152/300
# 13/13 [==============================] - 1s 87ms/step - d_loss: 0.6949 - g_loss: 0.7913
# Epoch 153/300
# 13/13 [==============================] - 1s 91ms/step - d_loss: 0.6818 - g_loss: 0.7968
# Epoch 154/300
# 13/13 [==============================] - 1s 88ms/step - d_loss: 0.6902 - g_loss: 0.7988
# Epoch 155/300
# 13/13 [==============================] - 1s 91ms/step - d_loss: 0.6965 - g_loss: 0.8440
# Epoch 156/300
# 13/13 [==============================] - 1s 93ms/step - d_loss: 0.6955 - g_loss: 0.8108
# Epoch 157/300
# 13/13 [==============================] - 1s 97ms/step - d_loss: 0.6909 - g_loss: 0.8400
# Epoch 158/300
# 13/13 [==============================] - 1s 94ms/step - d_loss: 0.6888 - g_loss: 0.8645
# Epoch 159/300
# 13/13 [==============================] - 1s 101ms/step - d_loss: 0.6837 - g_loss: 0.8446
# Epoch 160/300
# 13/13 [==============================] - 1s 98ms/step - d_loss: 0.6843 - g_loss: 0.8614
# Epoch 161/300
# 13/13 [==============================] - 1s 98ms/step - d_loss: 0.6858 - g_loss: 0.8735
# Epoch 162/300
# 13/13 [==============================] - 1s 98ms/step - d_loss: 0.6734 - g_loss: 0.8745
# Epoch 163/300
# 13/13 [==============================] - 1s 98ms/step - d_loss: 0.6753 - g_loss: 0.8773
# Epoch 164/300
# 13/13 [==============================] - 1s 94ms/step - d_loss: 0.6782 - g_loss: 0.8843
# Epoch 165/300
# 13/13 [==============================] - 1s 91ms/step - d_loss: 0.6917 - g_loss: 0.8955
# Epoch 166/300
# 13/13 [==============================] - 1s 105ms/step - d_loss: 0.6874 - g_loss: 0.8909
# Epoch 167/300
# 13/13 [==============================] - 1s 90ms/step - d_loss: 0.6875 - g_loss: 0.8962
# Epoch 168/300
# 13/13 [==============================] - 1s 102ms/step - d_loss: 0.6919 - g_loss: 0.8906
# Epoch 169/300
# 13/13 [==============================] - 1s 94ms/step - d_loss: 0.6822 - g_loss: 0.9181
# Epoch 170/300
# 13/13 [==============================] - 1s 98ms/step - d_loss: 0.6759 - g_loss: 0.9274
# Epoch 171/300
# 13/13 [==============================] - 1s 99ms/step - d_loss: 0.6853 - g_loss: 0.9226
# Epoch 172/300
# 13/13 [==============================] - 1s 94ms/step - d_loss: 0.6860 - g_loss: 0.9208
# Epoch 173/300
# 13/13 [==============================] - 1s 97ms/step - d_loss: 0.6786 - g_loss: 0.9284
# Epoch 174/300
# 13/13 [==============================] - 1s 93ms/step - d_loss: 0.6944 - g_loss: 0.9313
# Epoch 175/300
# 13/13 [==============================] - 1s 79ms/step - d_loss: 0.6823 - g_loss: 0.9436
# Epoch 176/300
# 13/13 [==============================] - 1s 100ms/step - d_loss: 0.6752 - g_loss: 0.9431
# Epoch 177/300
# 13/13 [==============================] - 1s 98ms/step - d_loss: 0.6764 - g_loss: 0.9509
# Epoch 178/300
# 13/13 [==============================] - 1s 85ms/step - d_loss: 0.6767 - g_loss: 0.9504
# Epoch 179/300
# 13/13 [==============================] - 1s 73ms/step - d_loss: 0.6762 - g_loss: 0.9497
# Epoch 180/300
# 13/13 [==============================] - 1s 96ms/step - d_loss: 0.6780 - g_loss: 0.9645
# Epoch 181/300
# 13/13 [==============================] - 1s 90ms/step - d_loss: 0.6776 - g_loss: 0.9599
# Epoch 182/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.6750 - g_loss: 0.9668
# Epoch 183/300
# 13/13 [==============================] - 1s 108ms/step - d_loss: 0.6821 - g_loss: 0.9744
# Epoch 184/300
# 13/13 [==============================] - 1s 105ms/step - d_loss: 0.6777 - g_loss: 0.9736
# Epoch 185/300
# 13/13 [==============================] - 1s 104ms/step - d_loss: 0.6724 - g_loss: 0.9782
# Epoch 186/300
# 13/13 [==============================] - 1s 109ms/step - d_loss: 0.6717 - g_loss: 0.9753
# Epoch 187/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6761 - g_loss: 0.9853
# Epoch 188/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6672 - g_loss: 0.9775
# Epoch 189/300
# 13/13 [==============================] - 1s 104ms/step - d_loss: 0.6692 - g_loss: 0.9845
# Epoch 190/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6741 - g_loss: 0.9901
# Epoch 191/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6722 - g_loss: 0.9945
# Epoch 192/300
# 13/13 [==============================] - 1s 111ms/step - d_loss: 0.6749 - g_loss: 0.9904
# Epoch 193/300
# 13/13 [==============================] - 1s 112ms/step - d_loss: 0.6775 - g_loss: 0.9993
# Epoch 194/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6623 - g_loss: 0.9962
# Epoch 195/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.6659 - g_loss: 1.0039
# Epoch 196/300
# 13/13 [==============================] - 1s 103ms/step - d_loss: 0.6737 - g_loss: 1.0068
# Epoch 197/300
# 13/13 [==============================] - 1s 104ms/step - d_loss: 0.6730 - g_loss: 1.0067
# Epoch 198/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.6705 - g_loss: 1.0134
# Epoch 199/300
# 13/13 [==============================] - 1s 108ms/step - d_loss: 0.6708 - g_loss: 1.0104
# Epoch 200/300
# 13/13 [==============================] - 1s 103ms/step - d_loss: 0.6636 - g_loss: 1.0117
# Epoch 201/300
# 13/13 [==============================] - 1s 104ms/step - d_loss: 0.6700 - g_loss: 1.0114
# Epoch 202/300
# 13/13 [==============================] - 1s 105ms/step - d_loss: 0.6603 - g_loss: 1.0126
# Epoch 203/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6621 - g_loss: 1.0147
# Epoch 204/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6666 - g_loss: 1.0128
# Epoch 205/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6670 - g_loss: 1.0131
# Epoch 206/300
# 13/13 [==============================] - 1s 113ms/step - d_loss: 0.6647 - g_loss: 1.0139
# Epoch 207/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6653 - g_loss: 1.0142
# Epoch 208/300
# 13/13 [==============================] - 1s 109ms/step - d_loss: 0.6617 - g_loss: 1.0175
# Epoch 209/300
# 13/13 [==============================] - 1s 103ms/step - d_loss: 0.6685 - g_loss: 1.0146
# Epoch 210/300
# 13/13 [==============================] - 1s 101ms/step - d_loss: 0.6630 - g_loss: 1.0160
# Epoch 211/300
# 13/13 [==============================] - 1s 92ms/step - d_loss: 0.6639 - g_loss: 1.0155
# Epoch 212/300
# 13/13 [==============================] - 1s 90ms/step - d_loss: 0.6619 - g_loss: 1.0086
# Epoch 213/300
# 13/13 [==============================] - 1s 89ms/step - d_loss: 0.6600 - g_loss: 1.0125
# Epoch 214/300
# 13/13 [==============================] - 1s 90ms/step - d_loss: 0.6606 - g_loss: 1.0136
# Epoch 215/300
# 13/13 [==============================] - 1s 75ms/step - d_loss: 0.6590 - g_loss: 1.0087
# Epoch 216/300
# 13/13 [==============================] - 1s 74ms/step - d_loss: 0.6600 - g_loss: 1.0114
# Epoch 217/300
# 13/13 [==============================] - 1s 112ms/step - d_loss: 0.6661 - g_loss: 1.0135
# Epoch 218/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6678 - g_loss: 1.0084
# Epoch 219/300
# 13/13 [==============================] - 1s 102ms/step - d_loss: 0.6600 - g_loss: 1.0065
# Epoch 220/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6599 - g_loss: 1.0056
# Epoch 221/300
# 13/13 [==============================] - 1s 102ms/step - d_loss: 0.6662 - g_loss: 1.0071
# Epoch 222/300
# 13/13 [==============================] - 1s 114ms/step - d_loss: 0.6592 - g_loss: 1.0033
# Epoch 223/300
# 13/13 [==============================] - 1s 99ms/step - d_loss: 0.6561 - g_loss: 1.0057
# Epoch 224/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6576 - g_loss: 1.0036
# Epoch 225/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6570 - g_loss: 0.9997
# Epoch 226/300
# 13/13 [==============================] - 1s 99ms/step - d_loss: 0.6624 - g_loss: 1.0014
# Epoch 227/300
# 13/13 [==============================] - 2s 125ms/step - d_loss: 0.6630 - g_loss: 1.0018
# Epoch 228/300
# 13/13 [==============================] - 1s 100ms/step - d_loss: 0.6523 - g_loss: 0.9987
# Epoch 229/300
# 13/13 [==============================] - 2s 124ms/step - d_loss: 0.6568 - g_loss: 0.9978
# Epoch 230/300
# 13/13 [==============================] - 1s 118ms/step - d_loss: 0.6589 - g_loss: 0.9964
# Epoch 231/300
# 13/13 [==============================] - 1s 109ms/step - d_loss: 0.6531 - g_loss: 0.9984
# Epoch 232/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.6541 - g_loss: 0.9957
# Epoch 233/300
# 13/13 [==============================] - 1s 98ms/step - d_loss: 0.6646 - g_loss: 0.9985
# Epoch 234/300
# 13/13 [==============================] - 1s 98ms/step - d_loss: 0.6479 - g_loss: 0.9935
# Epoch 235/300
# 13/13 [==============================] - 1s 103ms/step - d_loss: 0.6543 - g_loss: 0.9921
# Epoch 236/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6581 - g_loss: 0.9891
# Epoch 237/300
# 13/13 [==============================] - 1s 97ms/step - d_loss: 0.6507 - g_loss: 0.9897
# Epoch 238/300
# 13/13 [==============================] - 1s 95ms/step - d_loss: 0.6514 - g_loss: 0.9879
# Epoch 239/300
# 13/13 [==============================] - 1s 102ms/step - d_loss: 0.6550 - g_loss: 0.9889
# Epoch 240/300
# 13/13 [==============================] - 1s 103ms/step - d_loss: 0.6547 - g_loss: 0.9866
# Epoch 241/300
# 13/13 [==============================] - 1s 103ms/step - d_loss: 0.6507 - g_loss: 0.9848
# Epoch 242/300
# 13/13 [==============================] - 1s 112ms/step - d_loss: 0.6525 - g_loss: 0.9838
# Epoch 243/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6557 - g_loss: 0.9814
# Epoch 244/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.6522 - g_loss: 0.9803
# Epoch 245/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6467 - g_loss: 0.9780
# Epoch 246/300
# 13/13 [==============================] - 1s 109ms/step - d_loss: 0.6488 - g_loss: 0.9775
# Epoch 247/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6542 - g_loss: 0.9759
# Epoch 248/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.6508 - g_loss: 0.9762
# Epoch 249/300
# 13/13 [==============================] - 1s 85ms/step - d_loss: 0.6511 - g_loss: 0.9747
# Epoch 250/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.6529 - g_loss: 0.9737
# Epoch 251/300
# 13/13 [==============================] - 1s 111ms/step - d_loss: 0.6476 - g_loss: 0.9741
# Epoch 252/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6556 - g_loss: 0.9711
# Epoch 253/300
# 13/13 [==============================] - 1s 110ms/step - d_loss: 0.6439 - g_loss: 0.9702
# Epoch 254/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6490 - g_loss: 0.9683
# Epoch 255/300
# 13/13 [==============================] - 1s 102ms/step - d_loss: 0.6485 - g_loss: 0.9695
# Epoch 256/300
# 13/13 [==============================] - 1s 107ms/step - d_loss: 0.6470 - g_loss: 0.9676
# Epoch 257/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6421 - g_loss: 0.9641
# Epoch 258/300
# 13/13 [==============================] - 1s 105ms/step - d_loss: 0.6446 - g_loss: 0.9630
# Epoch 259/300
# 13/13 [==============================] - 1s 100ms/step - d_loss: 0.6462 - g_loss: 0.9638
# Epoch 260/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6437 - g_loss: 0.9634
# Epoch 261/300
# 13/13 [==============================] - 1s 76ms/step - d_loss: 0.6461 - g_loss: 0.9633
# Epoch 262/300
# 13/13 [==============================] - 1s 73ms/step - d_loss: 0.6501 - g_loss: 0.9629
# Epoch 263/300
# 13/13 [==============================] - 1s 72ms/step - d_loss: 0.6443 - g_loss: 0.9623
# Epoch 264/300
# 13/13 [==============================] - 1s 67ms/step - d_loss: 0.6438 - g_loss: 0.9610
# Epoch 265/300
# 13/13 [==============================] - 1s 67ms/step - d_loss: 0.6398 - g_loss: 0.9568
# Epoch 266/300
# 13/13 [==============================] - 1s 71ms/step - d_loss: 0.6484 - g_loss: 0.9592
# Epoch 267/300
# 13/13 [==============================] - 1s 66ms/step - d_loss: 0.6401 - g_loss: 0.9567
# Epoch 268/300
# 13/13 [==============================] - 1s 72ms/step - d_loss: 0.6510 - g_loss: 0.9559
# Epoch 269/300
# 13/13 [==============================] - 1s 71ms/step - d_loss: 0.6442 - g_loss: 0.9536
# Epoch 270/300
# 13/13 [==============================] - 1s 82ms/step - d_loss: 0.6410 - g_loss: 0.9522
# Epoch 271/300
# 13/13 [==============================] - 1s 109ms/step - d_loss: 0.6461 - g_loss: 0.9528
# Epoch 272/300
# 13/13 [==============================] - 1s 100ms/step - d_loss: 0.6458 - g_loss: 0.9499
# Epoch 273/300
# 13/13 [==============================] - 1s 96ms/step - d_loss: 0.6417 - g_loss: 0.9493
# Epoch 274/300
# 13/13 [==============================] - 1s 93ms/step - d_loss: 0.6455 - g_loss: 0.9479
# Epoch 275/300
# 13/13 [==============================] - 1s 94ms/step - d_loss: 0.6402 - g_loss: 0.9480
# Epoch 276/300
# 13/13 [==============================] - 1s 94ms/step - d_loss: 0.6414 - g_loss: 0.9468
# Epoch 277/300
# 13/13 [==============================] - 1s 94ms/step - d_loss: 0.6378 - g_loss: 0.9472
# Epoch 278/300
# 13/13 [==============================] - 1s 94ms/step - d_loss: 0.6475 - g_loss: 0.9474
# Epoch 279/300
# 13/13 [==============================] - 1s 97ms/step - d_loss: 0.6391 - g_loss: 0.9458
# Epoch 280/300
# 13/13 [==============================] - 1s 93ms/step - d_loss: 0.6412 - g_loss: 0.9468
# Epoch 281/300
# 13/13 [==============================] - 1s 97ms/step - d_loss: 0.6440 - g_loss: 0.9467
# Epoch 282/300
# 13/13 [==============================] - 1s 84ms/step - d_loss: 0.6417 - g_loss: 0.9473
# Epoch 283/300
# 13/13 [==============================] - 1s 105ms/step - d_loss: 0.6408 - g_loss: 0.9493
# Epoch 284/300
# 13/13 [==============================] - 1s 112ms/step - d_loss: 0.6406 - g_loss: 0.9480
# Epoch 285/300
# 13/13 [==============================] - 1s 96ms/step - d_loss: 0.6427 - g_loss: 0.9487
# Epoch 286/300
# 13/13 [==============================] - 1s 111ms/step - d_loss: 0.6404 - g_loss: 0.9479
# Epoch 287/300
# 13/13 [==============================] - 1s 114ms/step - d_loss: 0.6439 - g_loss: 0.9457
# Epoch 288/300
# 13/13 [==============================] - 1s 98ms/step - d_loss: 0.6464 - g_loss: 0.9456
# Epoch 289/300
# 13/13 [==============================] - 1s 95ms/step - d_loss: 0.6458 - g_loss: 0.9447
# Epoch 290/300
# 13/13 [==============================] - 2s 121ms/step - d_loss: 0.6489 - g_loss: 0.9450
# Epoch 291/300
# 13/13 [==============================] - 1s 100ms/step - d_loss: 0.6431 - g_loss: 0.9431
# Epoch 292/300
# 13/13 [==============================] - 1s 105ms/step - d_loss: 0.6446 - g_loss: 0.9421
# Epoch 293/300
# 13/13 [==============================] - 1s 105ms/step - d_loss: 0.6456 - g_loss: 0.9404
# Epoch 294/300
# 13/13 [==============================] - 1s 113ms/step - d_loss: 0.6458 - g_loss: 0.9402
# Epoch 295/300
# 13/13 [==============================] - 1s 109ms/step - d_loss: 0.6437 - g_loss: 0.9428
# Epoch 296/300
# 13/13 [==============================] - 1s 96ms/step - d_loss: 0.6520 - g_loss: 0.9390
# Epoch 297/300
# 13/13 [==============================] - 2s 123ms/step - d_loss: 0.6477 - g_loss: 0.9363
# Epoch 298/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6536 - g_loss: 0.9375
# Epoch 299/300
# 13/13 [==============================] - 1s 106ms/step - d_loss: 0.6488 - g_loss: 0.9381
# Epoch 300/300
# 13/13 [==============================] - 1s 103ms/step - d_loss: 0.6541 - g_loss: 0.9361

# %%
if True:
    scenario_size = 30
    normal_noise = tf.random.normal((scenario_size, batch_size, 1))
    n = [np.random.normal() for _ in range(scenario_size)]
    series = np.multiply(generator.predict(normal_noise), max)
    resolution = 24

    probabilities = []
    ranges = np.linspace(-3.5, 3.5, 8)
    intervals = np.linspace(-3, 3, 7)
    probs = [stats.norm.cdf(i) for i in n]
    prob_ranges = {intervals[i]: [stats.norm.cdf(ranges[i]), stats.norm.cdf(ranges[i+1])] for i in range(len(intervals))}
    for i in probs:
        for key in intervals:
            if prob_ranges[key][0]<= i <=prob_ranges[key][1]:
                probabilities.append(prob_ranges[key][1]-prob_ranges[key][0])
                break
    scenarios = {'probs': probabilities}
    for j in range(resolution):
        scenarios[j] = []
    for i in range(scenario_size):
        s = series[i].reshape([resolution])
        for j in range(resolution):
            scenarios[j].append(s[j])
pd.DataFrame(scenarios).to_csv(f'PVscenario-{month_name}.csv')
if True:
    ticks = [i for i in range(resolution)]
    fig, ax = plt.subplots(1, 2, figsize=(15, 4), dpi=200)
    for s in series[:12]:
        ax[0].plot(range(resolution), s.reshape([resolution]), linewidth=1)
    ax[0].set_xlabel('Timestamp (15 min)')
    ax[0].set_ylabel('Generated Power Consumption')
    ax[0].set_xticks(ticks, ticks)
    ax[0].grid(color='#666362', linestyle='-', linewidth=0.1)

    ax[1].plot(my_data[[c for c in my_data.columns][4:15]], linewidth=1)
    ax[1].set_xlabel('Timestamp (15 min)')
    ax[1].set_ylabel('Historical Power Consumption')
    ax[1].set_xticks(ticks, ticks)
    ax[1].grid(color='#666362', linestyle='-', linewidth=0.1)
    plt.subplots_adjust(wspace=0.1)
#plt.savefig(f'PV GAN {month_name}.jpg', bbox_inches='tight')
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %% [markdown]
# ### Save models

# %%
plt.figure(figsize=(7, 3), dpi=300)
plt.plot(hist.history['d_loss'], label='Generator Loss')
plt.plot(hist.history['g_loss'], label='Discriminator Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(color='#666362', linestyle='-', linewidth=0.1)
plt.savefig(f'IMG/{month_name}-{day_type}-loss.jpg', bbox_inches='tight')

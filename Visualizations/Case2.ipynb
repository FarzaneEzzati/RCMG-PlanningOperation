# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from operator import add
_c = pd.read_csv('color.csv')['color'].values

# %%
DS = pd.read_csv('ES-PV-DRP Case 2 - Dove Springs.csv')
SS = pd.read_csv('ES-PV-DRP Case 2 - Sunnyside.csv')
RW = pd.read_csv('ES-PV-DRP Case 2 - Rogers Washington.csv')

# %%
data = DS
rng = [1,2,3]
PV = np.add(DS['PV1'], data['PV2'])
ES = np.add(data['ES1'], data['ES2'])
DG = np.add(data['DG1'], data['DG2'])
res = [data[mask][RM1], data[mask][RM2], data[mask][RM3], data[mask][RM4]]

plt.bar(rng, PV, width=0.6, align='center', color=_c[0], label='PV', alpha=0.7)
plt.bar(rng, ES, bottom=PV, width=0.6, align='center', color=_c[1], label='ES', alpha=0.6)
plt.bar(rng, DG, width=0.6, align='center', color=_c[7], label='DG', alpha=0.6)

ax = plt.twinx()
ax.plot(rng, data[[0], c=_c[1], label='RM-IE', linestyle='--')
ax.plot(rng, _res[1], c=_c[2], label='RM-SA', linestyle='--')
ax.plot(rng, _res[2], c=_c[3], label='RM-DA', linestyle='--')
ax.plot(rng, _res[3], c=_c[5], label='RM-PA', linestyle='--')
plt.xticks(rng)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 12
#       9 plt.bar(rng, DG, width=0.6, align='center', color=_c[7], label='DG', alpha=0.6)
#      11 ax = plt.twinx()
# ---> 12 ax.plt(rng, np.add(data['Investment'], data['Reinvestment']))
#      13 plt.xticks(rng)
#
# AttributeError: 'Axes' object has no attribute 'plt'
